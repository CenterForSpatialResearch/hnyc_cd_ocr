# %%
from cdparser import Classifier, Features, LabeledEntry, Utils
import json
import ast
import numpy as np

# %%
## Create a classifier object and load some labeled data from a CSV
classifier = Classifier.Classifier()
classifier.load_training("1850_train_bk.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-dc7360cba1c0> in <module>
#       1 ## Create a classifier object and load some labeled data from a CSV
#       2 classifier = Classifier.Classifier()
# ----> 3 classifier.load_training("1850_train_bk.csv")
#
# ~\Documents\summer2020\RA_HNYC\work_files\parsing-folder\cdparser\Classifier.py in load_training(self, path_to_csv, rows_to_ignore)
#      49
#      50     def load_training(self, path_to_csv, rows_to_ignore=0):
# ---> 51         self.training_set_labeled = self.load_labeled_data(path_to_csv, rows_to_ignore)
#      52         self.__process_training_data()
#      53
#
# ~\Documents\summer2020\RA_HNYC\work_files\parsing-folder\cdparser\Classifier.py in load_labeled_data(self, path_to_csv, rows_to_ignore)
#      31         example = None
#      32         for row in rows:
# ---> 33             sentence_number = int(row[0])
#      34             if sentence_number > example_number:
#      35                 example_number = sentence_number
#
# ValueError: invalid literal for int() with base 10: 'number'

# %%
## Optionally, load validation dataset
# classifier.load_validation("/full/path/to/validation/nypl-labeled-validate.csv")

## Train your classifier (with default settings)
classifier.train()

# %%
#read cleaned data
with open(r"MN_1850-51_cleaned.txt","r",encoding = "utf-8") as f:
    lines = f.readlines()

# %%
#remove newlines
lines = [x.strip() for x in lines]

# %%
entry_dict = {}
for i in range(len(lines)):
## Create an entry object from string
    entry = LabeledEntry.LabeledEntry(lines[i])

    ## Pass the entry to the classifier
    classifier.label(entry)

    ## Export the labeled entry as JSON
    entry_dict[str(i+1)] = json.dumps(entry.categories)
# with open('CRF_output.txt', 'a') as fout:
#         json.dump(entry_dict,fout)

# %%
with open('entry_dict.txt', 'w',encoding="utf-8") as f:
        f.write(str(entry_dict))

# %%
entry_dict
# Out:
# {'1': '{"subjects": ["Ackley Addison"], "occupations": ["clerk"], "locations": [{"value": "47 Broadway"}, {"value": "39 Pearl", "labels": ["h"]}]}',
#  '2': '{"subjects": ["Adams William"], "occupations": ["weigher"], "locations": [{"value": "20 Washington & 13 West"}, {"value": "170 Clinton , Brooklyn", "labels": ["h"]}]}',
#  '3': '{"subjects": ["Aitkin Thomas"], "occupations": ["stonecutter"], "locations": [{"value": "601 Washington"}]}',
#  '4': '{"subjects": ["Albro Benjamin"], "occupations": ["sen"], "locations": [{"value": "328 Bowery"}]}',
#  '5': '{"subjects": ["Allen E . W"], "occupations": ["publisher"], "locations": [{"value": "42 Orange"}]}',
#  '6': '{"subjects": ["Anderson Frederick R"], "occupations": ["com", "mer"], "locations": [{"value": "13 Front"}, {"value": "77 Barrow", "labels": ["h"]}]}',
#  '7': '{"subjects": ["Anderson John R"], "occupations": ["seaman"], "locations": [{"value": "586 E , 4th"}]}',
#  '8': '{"subjects": ["Anthes Peter"], "occupations": [], "locations": [{"value": "34 Av . C", "labels": ["barbex"]}]}',
#  '9': '{"subjects": ["Anthes & Eckardt"], "occupations": ["barbers"], "locations": [{"value": "34 Av . C"}]}',
#  '10': '{"subjects": ["Appell John"], "occupations": ["tailor"], "locations": [{"value": "40 Av . C"}]}',
#  '11': '{"subjects": ["Arcularius Jacob S"], "occupations": [], "locations": [{"value": "175 Canal", "labels": ["h"]}]}',
#  '12': '{"subjects": ["Arenfred George"], "occupations": [], "locations": [{"value": "137 Norfolk"}]}',
#  '13': '{"subjects": ["Armstrong George"], "occupations": ["shoemaker"], "locations": [{"value": "53 Av . D"}]}',
#  '14': '{"subjects": ["Armstrong John D"], "occupations": ["coachmaker"], "locations": [{"value": "5 Ludlow"}]}',
#  '15': '{"subjects": ["Arnold Henry"], "occupations": ["drygoods"], "locations": [{"value": "1 Av . D"}, {"value": "1 Av . D", "labels": ["h", " r"]}]}',
#  '16': '{"subjects": ["Ash William A"], "occupations": ["saloon", "way"], "locations": [{"value": "413 B"}, {"value": "Morrisania", "labels": ["h"]}]}',
#  '17': '{"subjects": ["Auchincloss John T"], "occupations": ["com", "mer"], "locations": [{"value": "192 Fulton"}, {"value": "7 Murray", "labels": ["h"]}]}',
#  '18': '{"subjects": ["Auchincloss & Croxon"], "occupations": ["com", "mers"], "locations": [{"value": "192 Fulton"}]}',
#  '19': '{"subjects": ["Bagley William"], "occupations": ["clerk", "bank"], "locations": [{"value": "50 Wall"}, {"value": "91 Henry , Brooklyn", "labels": ["h"]}]}',
#  '20': '{"subjects": ["BAIN ALEXANDER"], "occupations": [], "locations": [{"value": "181 inventor ,", "labels": ["telegraph"]}]}',
#  '21': '{"subjects": ["Baldwin Ezekiel"], "occupations": ["shoemaker"], "locations": [{"value": "79 Av . B"}]}',
#  '22': '{"subjects": ["Ball Isaac"], "occupations": ["pedler"], "locations": [{"value": "66 Mangin"}]}',
#  '23': '{"subjects": ["Bannon Michael"], "occupations": ["cooper"], "locations": [{"value": "304 Ninth"}]}',
#  '24': '{"subjects": ["Barmore Christopher"], "occupations": ["shoes"], "locations": [{"value": "E . 18th n . Av . A"}]}',
#  '25': '{"subjects": ["Barratt Thomas"], "occupations": ["carman"], "locations": [{"value": "605 Fourth"}]}',
#  '26': '{"subjects": ["Barrowclough James , E"], "occupations": [], "locations": [{"value": "24th c . Av . 3"}]}',
#  '27': '{"subjects": ["Barry James"], "occupations": ["marblepolisher"], "locations": [{"value": "294 Eleventh"}]}',
#  '28': '{"subjects": ["Barry John"], "occupations": ["carpenter"], "locations": [{"value": "60 Av . C"}]}',
#  '29': '{"subjects": ["Bates John C"], "occupations": ["sarsaparilla"], "locations": [{"value": "82 Nassau"}, {"value": "Brooklyn", "labels": ["h"]}]}',
#  '30': '{"subjects": ["Beach John T"], "occupations": ["paper"], "locations": [{"value": "43 Fulton"}, {"value": "22 Vesey", "labels": ["h"]}]}',
#  '31': '{"subjects": ["Bear Isaac"], "occupations": ["drygoods"], "locations": [{"value": "105 Av . D"}, {"value": "105 Av . D", "labels": ["h"]}]}',
#  '32': '{"subjects": ["Beard William"], "occupations": ["carpenter"], "locations": [{"value": "89 E . 11th"}]}',
#  '33': '{"subjects": ["Becom John J"], "occupations": ["sawyer"], "locations": [{"value": "Av . C n . Eleventh"}]}',
#  '34': '{"subjects": ["Beebe Joseph D"], "occupations": ["rigger"], "locations": [{"value": "350 Tenth"}]}',
#  '35': '{"subjects": ["Beebe & Co"], "occupations": ["builders"], "locations": [{"value": "W . 24th n . Ay . 10"}]}',
#  '36': '{"subjects": ["Beers William P"], "occupations": ["butcher"], "locations": [{"value": "69 Orange"}, {"value": "77 Third", "labels": ["h"]}]}',
#  '37': '{"subjects": ["Bender George W"], "occupations": ["tailor"], "locations": [{"value": "27 Av . A"}]}',
#  '38': '{"subjects": ["Benneit Cornelius"], "occupations": ["carman"], "locations": [{"value": "400 Tenth"}]}',
#  '39': '{"subjects": ["Bennett George"], "occupations": ["shoemaker"], "locations": [{"value": "131 Av . C"}]}',
#  '40': '{"subjects": ["Bennett William"], "occupations": ["carman"], "locations": [{"value": "245 E . 13th"}]}',
#  '41': '{"subjects": ["Bernhard Gustavus"], "occupations": ["teacher"], "locations": [{"value": "18 Av , C"}]}',
#  '42': '{"subjects": ["Bernz John"], "occupations": ["tailor"], "locations": [{"value": "306 Av . 1"}]}',
#  '43': '{"subjects": ["Berrian Burr"], "occupations": ["fish"], "locations": [{"value": "89 Pitt"}]}',
#  '44': '{"subjects": ["Bird George L"], "occupations": ["clerk"], "locations": [{"value": "45 Norfolk"}]}',
#  '45': '{"subjects": ["Bill Hannah"], "occupations": ["tailoress"], "locations": [{"value": "46 Amos"}]}',
#  '46': '{"subjects": ["Birmingham David"], "occupations": ["police"], "locations": [{"value": "W . 26th n . Av . 7"}]}',
#  '47': '{"subjects": ["Boole Thomas B"], "occupations": [], "locations": [{"value": "107 Av . B"}]}',
#  '48': '{"subjects": ["Borman Eckhard"], "occupations": ["tailor"], "locations": [{"value": "5 Av . B"}]}',
#  '49': '{"subjects": ["Bott John"], "occupations": ["tailor"], "locations": [{"value": "299 Av . A"}]}',
#  '50': '{"subjects": ["Botz Louis"], "occupations": ["pedler"], "locations": [{"value": "48 Av . 1"}]}',
#  '51': '{"subjects": ["Bouton Gilbert"], "occupations": ["carman"], "locations": [{"value": "51 Norfolk"}]}',
#  '52': '{"subjects": ["Bowen John"], "occupations": ["plumber"], "locations": [{"value": "268 EF . 13th"}]}',
#  '53': '{"subjects": ["Boyd John jr"], "occupations": ["mer"], "locations": [{"value": "149 & 151 Front"}, {"value": "92 Madison", "labels": ["h"]}]}',
#  '54': '{"subjects": ["Boyle John"], "occupations": ["liquors"], "locations": [{"value": "W . 25th n . Av . 10"}]}',
#  '55': '{"subjects": ["Boynton Ray"], "occupations": ["com", "mer", "pl"], "locations": [{"value": "51 Exch"}, {"value": "31 W . 15th", "labels": ["h"]}]}',
#  '56': '{"subjects": ["Brady John"], "occupations": ["school"], "locations": [{"value": "219 E . 13th"}, {"value": "217 E , 13th", "labels": ["h"]}]}',
#  '57': '{"subjects": ["Bramley Patrick"], "occupations": ["boilermaker"], "locations": [{"value": "319 Ninth"}]}',
#  '58': '{"subjects": ["Bramwell Joseph"], "occupations": ["mer"], "locations": [{"value": "101 Henry , Brooklyn", "labels": ["h"]}]}',
#  '59': '{"subjects": ["Brant Theophilus"], "occupations": ["shipjoiner"], "locations": [{"value": "Ay . D c . Fourth"}]}',
#  '60': '{"subjects": ["Breasted John"], "occupations": ["allaire works"], "locations": [{"value": "464 Cherry"}]}',
#  '61': '{"subjects": ["Brennan Joseph"], "occupations": ["mason"], "locations": [{"value": "312 Av . 1"}]}',
#  '62': '{"subjects": ["Brennen James H"], "occupations": ["hatter"], "locations": [{"value": "7 Av . D"}, {"value": "7 Av . D", "labels": ["h"]}]}',
#  '63': '{"subjects": ["Breuninger Henry"], "occupations": ["tailot"], "locations": [{"value": "25 Av . A"}]}',
#  '64': '{"subjects": ["Brice Henry"], "occupations": ["silkweaver"], "locations": [{"value": "143 W . 28th"}]}',
#  '65': '{"subjects": ["Brincker William"], "occupations": ["carpenter"], "locations": [{"value": "Third n . Av . A"}]}',
#  '66': '{"subjects": ["Brodhead John R"], "occupations": [], "locations": [{"value": "32 Bond"}]}',
#  '67': '{"subjects": ["Brooks Brothers"], "occupations": ["clothing"], "locations": [{"value": "116 & 118 Cherry"}]}',
#  '68': '{"subjects": ["Brouard Peter"], "occupations": [], "locations": [{"value": "83 Leonard"}, {"value": "143 Reade", "labels": ["h"]}]}',
#  '69': '{"subjects": ["Brough William"], "occupations": [], "locations": [{"value": "117 Fulton"}, {"value": "4 Beach ,", "labels": ["h"]}]}',
#  '70': '{"subjects": ["Brouner Joseph P"], "occupations": ["drygoods"], "locations": [{"value": "707 Greenwich"}, {"value": "529 Hudson", "labels": ["h"]}]}',
#  '71': '{"subjects": ["Brouwer Saml"], "occupations": ["crockery"], "locations": [{"value": "72 Vesey"}, {"value": "173 Wooster", "labels": ["h"]}]}',
#  '72': '{"subjects": ["Brown Charles P"], "occupations": [], "locations": [{"value": "290 West"}, {"value": "95 W . 13th", "labels": ["h"]}]}',
#  '73': '{"subjects": ["Brown Robert"], "occupations": ["physician"], "locations": [{"value": "174 Chambers"}]}',
#  '74': '{"subjects": ["Brown Thomas H"], "occupations": ["hosiery"], "locations": [{"value": "34 Liberty"}]}',
#  '75': '{"subjects": ["Brown & Englis"], "occupations": ["shipwrights"], "locations": [{"value": "Twelfth c . Dry Dock"}]}',
#  '76': '{"subjects": ["Brownrse Jolin \\u00c2\\u00a78"], "occupations": ["carver"], "locations": [{"value": "53 Monroe", "labels": ["h"]}]}',
#  '77': '{"subjects": ["Bruggemann Diedrich"], "occupations": ["grocer"], "locations": [{"value": "72 Lewis", "labels": ["h"]}]}',
#  '78': '{"subjects": ["Brummell Adonijah"], "occupations": ["confectioner"], "locations": [{"value": "141 Norfolk", "labels": ["h"]}]}',
#  '79': '{"subjects": ["Budd Thomas S"], "occupations": ["shipmaster"], "locations": [{"value": "166 E . 20th"}]}',
#  '80': '{"subjects": ["Bunce William C"], "occupations": ["carman"], "locations": [{"value": "201 Av . 3"}]}',
#  '81': '{"subjects": ["Bunzel Gottlieb"], "occupations": ["whitewasher"], "locations": [{"value": "93 Ridge"}]}',
#  '82': '{"subjects": ["Burket James E"], "occupations": ["porterhouse"], "locations": [{"value": "433 Tenth"}]}',
#  '83': '{"subjects": ["Camp Benjamin F"], "occupations": ["builder"], "locations": [{"value": "86 Av . 2"}]}',
#  '84': '{"subjects": ["Campbell John"], "occupations": ["blacksmith"], "locations": [{"value": "180 Av . C"}]}',
#  '85': '{"subjects": ["Campbell Peter"], "occupations": ["boatman"], "locations": [{"value": "128 Charlton"}]}',
#  '86': '{"subjects": ["Campbell William S"], "occupations": ["printer"], "locations": [{"value": "180 Grand"}]}',
#  '87': '{"subjects": ["Campbell & Moody"], "occupations": ["lumber", "steam saw mill , foot 36th"], "locations": [{"value": "7 Broad"}, {"value": ".", "labels": ["n", " r"]}]}',
#  '88': '{"subjects": ["Cunham Wm"], "occupations": ["carputer"], "locations": [{"value": "16 Clarkson"}, {"value": "14 Clarkson", "labels": ["h"]}]}',
#  '89': '{"subjects": ["Cannon Cornelius"], "occupations": ["tinner"], "locations": [{"value": "176 Wooster"}, {"value": "2 Congress", "labels": ["h"]}]}',
#  '90': '{"subjects": ["Carey Thomas"], "occupations": ["carpenter"], "locations": [{"value": "104 FE . 11th"}]}',
#  '91': '{"subjects": ["Carlisle George"], "occupations": ["mer"], "locations": [{"value": "165 Pearl"}, {"value": "Cincinnati , O", "labels": ["h"]}]}',
#  '92': '{"subjects": ["Carlisle & Stedman"], "occupations": ["mers"], "locations": [{"value": "165 Pearl :"}]}',
#  '93': '{"subjects": ["Carrington Z . E"], "occupations": ["salesman"], "locations": [{"value": "13 William"}, {"value": "Court n . Degraw , Brooklyn", "labels": ["h"]}]}',
#  '94': '{"subjects": ["Carroll D . J"], "occupations": ["physician"], "locations": [{"value": "400 Broadway :"}]}',
#  '95': '{"subjects": ["Case George"], "occupations": ["sashmaker"], "locations": [{"value": "W . 25th n . Av . 8 , h . W 2th n . Av . 8"}]}',
#  '96': '{"subjects": ["Castle Charles H"], "occupations": ["com", "mer"], "locations": [{"value": "121 Pearl"}]}',
#  '97': '{"subjects": ["Carlough George"], "occupations": ["carman"], "locations": [{"value": "746 Washington"}]}',
#  '98': '{"subjects": ["Channing William"], "occupations": ["physician"], "locations": [{"value": "88 White"}]}',
#  '99': '{"subjects": ["Chapin R . Spencer"], "occupations": ["physician"], "locations": [{"value": "305 Third"}]}',
#  '100': '{"subjects": ["Charcin John"], "occupations": ["carpenter"], "locations": [{"value": "W . 28th n . Av . 7"}]}',
#  '101': '{"subjects": ["Clarke William"], "occupations": ["brassfounder"], "locations": [{"value": "41 Sheriff"}]}',
#  '102': '{"subjects": ["Clarke & Dougherty"], "occupations": ["morocco"], "locations": [{"value": "29 Ferry"}]}',
#  '103': '{"subjects": ["Clary Philip"], "occupations": ["livery stables"], "locations": [{"value": "193 Ninth"}]}',
#  '104': '{"subjects": ["Clausen & Suhr"], "occupations": ["boarding , Peck slip"], "locations": [{"value": "Pearl", "labels": ["c"]}]}',
#  '105': '{"subjects": ["Claussen John"], "occupations": ["grocer"], "locations": [{"value": "160 Church"}]}',
#  '106': '{"subjects": ["Clayton John"], "occupations": ["carpenter"], "locations": [{"value": "63 Factory"}]}',
#  '107': '{"subjects": ["Clear Edward"], "occupations": ["boxes"], "locations": [{"value": "73 Maiden la"}, {"value": "43 Elm", "labels": ["h"]}]}',
#  '108': '{"subjects": ["Collins Joseph B"], "occupations": ["pres", "ins"], "locations": [{"value": "1", "labels": ["m"]}, {"value": "co . 35 Wall"}, {"value": "415 Broome", "labels": ["h"]}]}',
#  '109': '{"subjects": ["Cooper Thos"], "occupations": ["grocer"], "locations": [{"value": "8"}, {"value": "104 Broad"}, {"value": "23 Whitehall", "labels": ["h"]}]}',
#  '110': '{"subjects": ["Cooper , Storm & Smith"], "occupations": ["grocers"], "locations": [{"value": "104 Broad"}]}',
#  '111': '{"subjects": ["Corell Peter"], "occupations": [], "locations": [{"value": "20 Hamersley place"}]}',
#  '112': '{"subjects": ["Cosgrove Henry"], "occupations": [], "locations": [{"value": "7 Chrystie", "labels": ["h"]}]}',
#  '113': '{"subjects": ["Crawford George W"], "occupations": ["carman"], "locations": [{"value": "650 Fourth"}]}',
#  '114': '{"subjects": ["Crawford Susannah"], "occupations": ["widow of David"], "locations": [{"value": "650 Fourth"}]}',
#  '115': '{"subjects": ["Croxon H . Thomas"], "occupations": ["com", "mer"], "locations": [{"value": "192 Fulton ,"}]}',
#  '116': '{"subjects": ["Curtis Joseph T"], "occupations": ["physician"], "locations": [{"value": "609 Broadway"}]}',
#  '117': '{"subjects": ["Cushman J . Newland"], "occupations": ["lawyer"], "locations": [{"value": "118 William"}]}',
#  '118': '{"subjects": ["Daniel Joseph P"], "occupations": ["sodawater"], "locations": [{"value": "118 Fulton"}, {"value": "76 Mott", "labels": ["h"]}]}',
#  '119': '{"subjects": ["Darling Wm"], "occupations": ["physician", "way"], "locations": [{"value": "645 B"}, {"value": "226 Wooster", "labels": ["h"]}]}',
#  '120': '{"subjects": ["Davis Edwin"], "occupations": ["com", "mer"], "locations": [{"value": "16 Burling slip"}, {"value": "Brookla", "labels": ["h"]}]}',
#  '121': '{"subjects": ["Deafenbuck Henry"], "occupations": ["butcher"], "locations": [{"value": "465 Fourth"}]}',
#  '122': '{"subjects": ["Deery Dennis"], "occupations": ["late porterhouse"], "locations": [{"value": "623 Washington"}]}',
#  '123': '{"subjects": ["Delavan James"], "occupations": ["secretary"], "locations": [{"value": "25 Nassau"}]}',
#  '124': '{"subjects": ["Denison Charles S"], "occupations": ["liquors"], "locations": [{"value": "267 Washington"}, {"value": "5 Charlton", "labels": ["h"]}]}',
#  '125': '{"subjects": ["Derickson Kinlock S"], "occupations": ["com", "mer"], "locations": [{"value": "87 Beaver"}, {"value": "2 College pl", "labels": ["h"]}]}',
#  '126': '{"subjects": ["Devermaun Hammond"], "occupations": ["grocer"], "locations": [{"value": "45 Ridge"}, {"value": "Clinton c . Delancy", "labels": ["h"]}]}',
#  '127': '{"subjects": ["Devoe John C"], "occupations": ["saddler"], "locations": [{"value": "184 Ludlow", "labels": ["h"]}]}',
#  '128': '{"subjects": ["Diederich Charles"], "occupations": ["coppersmith"], "locations": [{"value": "101 Av . C"}]}',
#  '129': '{"subjects": ["Donnely Edward C"], "occupations": ["mer"], "locations": [{"value": "7S . William"}, {"value": "102 Av . 2", "labels": ["h"]}]}',
#  '130': '{"subjects": ["Duffey James"], "occupations": ["carpenter"], "locations": [{"value": "200 Av , 1"}]}',
#  '131': '{"subjects": ["Duffy John"], "occupations": ["surgeon"], "locations": [{"value": "12 Sixth"}, {"value": "30 Bleecker", "labels": ["h"]}]}',
#  '132': '{"subjects": ["Duffy Bernard G"], "occupations": ["grocer"], "locations": [{"value": "560 Fourth"}, {"value": "660 Fourth", "labels": ["h"]}]}',
#  '133': '{"subjects": ["Duignan Peter"], "occupations": ["carman"], "locations": [{"value": "110 Av . 7"}]}',
#  '134': '{"subjects": ["Dumont John"], "occupations": ["shipcarpenter"], "locations": [{"value": "686 Fourth"}]}',
#  '135': '{"subjects": ["Duncan Francis"], "occupations": ["stonecutter"], "locations": [{"value": "291 Seventh", "labels": ["h"]}]}',
#  '136': '{"subjects": ["Duncan George"], "occupations": ["painter"], "locations": [{"value": "105 E . lth"}]}',
#  '137': '{"subjects": ["Dunn Benjamin"], "occupations": ["late carman"], "locations": [{"value": "156 Av . 6"}]}',
#  '138': '{"subjects": ["Dunn William"], "occupations": ["tailor"], "locations": [{"value": "27 Sheriff"}]}',
#  '139': '{"subjects": ["Dunning Moses"], "occupations": ["tailor"], "locations": [{"value": "67 James", "labels": ["r"]}]}',
#  '140': '{"subjects": ["Dupuy Henry"], "occupations": [], "locations": [{"value": "19 Clif"}, {"value": "Williamsburg", "labels": ["h"]}]}',
#  '141': '{"subjects": ["Durst Gottleb"], "occupations": ["butcher"], "locations": [{"value": "E . 16th n . Av . 1"}]}',
#  '142': '{"subjects": ["Dwinett Andrew A"], "occupations": ["printer"], "locations": [{"value": "460 Washington"}]}',
#  '143': '{"subjects": ["Dyckman States"], "occupations": ["carman"], "locations": [{"value": "648 Fourth"}]}',
#  '144': '{"subjects": ["Dyer James"], "occupations": ["cabinetmaker"], "locations": [{"value": "6 Goerck"}]}',
#  '145': '{"subjects": ["Doane A . Sidney"], "occupations": ["health officer"], "locations": [{"value": "5 City Hall"}]}',
#  '146': '{"subjects": ["Doney Thomas"], "occupations": ["engraver"], "locations": [{"value": "16 Burling sl"}, {"value": "New J", "labels": ["h"]}]}',
#  '147': '{"subjects": ["Donnell James"], "occupations": ["lime"], "locations": [{"value": "500 West"}, {"value": "727 Washington", "labels": ["h"]}]}',
#  '148': '{"subjects": ["Donnell John"], "occupations": ["restaurant"], "locations": [{"value": "249 Wooster"}, {"value": "154 Sullivan", "labels": ["h"]}]}',
#  '149': '{"subjects": ["Dougherty Richard"], "occupations": ["mason"], "locations": [{"value": "185 Laurens", "labels": ["r"]}]}',
#  '150': '{"subjects": ["Dougherty William"], "occupations": ["carman"], "locations": [{"value": "W . 29th n , Av . 11"}]}',
#  '151': '{"subjects": ["Doughty Leonard D"], "occupations": ["varnisher"], "locations": [{"value": "669 Fourth"}]}',
#  '152': '{"subjects": ["Douglas Thomas"], "occupations": ["tailor"], "locations": [{"value": "658 Fourth"}]}',
#  '153': '{"subjects": ["Dow & Burdi"], "occupations": ["paperhangers"], "locations": [{"value": "151 Broadway"}]}',
#  '154': '{"subjects": ["Downie James"], "occupations": ["laces"], "locations": [{"value": "W . 27th b . Avs"}, {"value": "9 & 10"}]}',
#  '155': '{"subjects": ["Doyle Thomas"], "occupations": ["blacksmith"], "locations": [{"value": "5 Weehawken"}]}',
#  '156': '{"subjects": ["Dredger Jacob W"], "occupations": ["carman"], "locations": [{"value": "16 Christopher"}]}',
#  '157': '{"subjects": ["Ebbets Edward A"], "occupations": ["baker"], "locations": [{"value": "319 Hudson"}, {"value": "319 Hudson", "labels": ["h"]}]}',
#  '158': '{"subjects": ["Eckardt Philip"], "occupations": ["barber"], "locations": [{"value": "34 Av . C"}, {"value": "34 Av C", "labels": ["h"]}]}',
#  '159': '{"subjects": ["Engel Edward"], "occupations": ["frescopainter"], "locations": [{"value": "22 Market"}]}',
#  '160': '{"subjects": ["Fagan Edmund W"], "occupations": ["engraver"], "locations": [{"value": "333 Broadway"}]}',
#  '161': '{"subjects": ["Farley Thomas"], "occupations": ["shoemaker"], "locations": [{"value": "616 Broadway", "labels": ["y"]}]}',
#  '162': '{"subjects": ["Farrington Joseph T"], "occupations": ["clerk"], "locations": [{"value": "100 Sullivan"}]}',
#  '163': '{"subjects": ["Felkar George"], "occupations": ["malster"], "locations": [{"value": "281 E . 13th"}]}',
#  '164': '{"subjects": ["Fenning Michael"], "occupations": ["shoemaker"], "locations": [{"value": "398 West"}]}',
#  '165': '{"subjects": ["Fenton David"], "occupations": ["cooper"], "locations": [{"value": "34 Elizabeth"}]}',
#  '166': '{"subjects": ["Ferguson John C"], "occupations": ["shoemaker"], "locations": [{"value": "119 Lewis"}]}',
#  '167': '{"subjects": ["Ferris George S"], "occupations": ["clerk"], "locations": [{"value": "30 Fifth"}]}',
#  '168': '{"subjects": ["Ferris John M"], "occupations": ["lumber", "boards"], "locations": [{"value": "457 West"}, {"value": "95 Bank"}]}',
#  '169': '{"subjects": ["Ferris S . A"], "occupations": ["mer"], "locations": [{"value": "33 Front"}]}',
#  '170': '{"subjects": ["Ferris Thomas T"], "occupations": [], "locations": [{"value": "129 Charles"}]}',
#  '171': '{"subjects": ["Ferris Thomas"], "occupations": ["carpets"], "locations": [{"value": "159 Chatham"}]}',
#  '172': '{"subjects": ["Ferry Edward"], "occupations": ["weigher"], "locations": [{"value": "76 Mulberry", "labels": ["r"]}]}',
#  '173': '{"subjects": ["Ferry Eli"], "occupations": ["police"], "locations": [{"value": "391 Broome"}]}',
#  '174': '{"subjects": ["Fessenden William W"], "occupations": ["clerk", "boards"], "locations": [{"value": "45 Broadway"}, {"value": "16 State"}]}',
#  '175': '{"subjects": ["Fetters John"], "occupations": ["tobacconist"], "locations": [{"value": "54 Av . C"}]}',
#  '176': '{"subjects": ["Fick Eliza", "S"], "occupations": ["widow of David", "confectionery"], "locations": [{"value": "588 Fourth"}]}',
#  '177': '{"subjects": ["Fick & Kucharski"], "occupations": ["trunkmakers"], "locations": [{"value": "2 Bowery"}]}',
#  '178': '{"subjects": ["Fickett Hart"], "occupations": ["shipcarpenter"], "locations": [{"value": "Ninth c . Av . C"}]}',
#  '179': '{"subjects": ["Fiedo William"], "occupations": ["carman"], "locations": [{"value": "208 Elm", "labels": ["r"]}]}',
#  '180': '{"subjects": ["Field Edward"], "occupations": ["druggist"], "locations": [{"value": "279 Delancy"}]}',
#  '181': '{"subjects": ["Field Edward"], "occupations": ["late hardware"], "locations": [{"value": "1 Platt"}, {"value": "35 Clinton place", "labels": ["h"]}]}',
#  '182': '{"subjects": ["Field Franklin C"], "occupations": [], "locations": [{"value": "721 Broadway"}]}',
#  '183': '{"subjects": ["Fieselmann Stephen"], "occupations": ["brassfounder"], "locations": [{"value": "25 Av . B"}]}',
#  '184': '{"subjects": ["Fiettretch William"], "occupations": ["mason"], "locations": [{"value": "49 Av . B"}]}',
#  '185': '{"subjects": ["Fiken Richard"], "occupations": ["late grocer"], "locations": [{"value": "529 Greenwich", "labels": ["h"]}]}',
#  '186': '{"subjects": ["Finch Joseph"], "occupations": ["teacher"], "locations": [{"value": "215 W . 18th"}]}',
#  '187': '{"subjects": ["Finch John"], "occupations": ["painter"], "locations": [{"value": "62 Sixth"}]}',
#  '188': '{"subjects": ["Fink Conrad"], "occupations": ["clerk"], "locations": [{"value": "151 W . Broadway"}]}',
#  '189': '{"subjects": ["Fink Joseph"], "occupations": ["shipjoiner"], "locations": [{"value": "367 Sixth"}]}',
#  '190': '{"subjects": ["Fink Lewis"], "occupations": ["grocer"], "locations": [{"value": "536 Pearl"}]}',
#  '191': '{"subjects": ["Finley Joseph"], "occupations": ["upholsterer"], "locations": [{"value": "134 Broome"}]}',
#  '192': '{"subjects": ["Fisher Peter G"], "occupations": ["carver"], "locations": [{"value": "241 Mott"}]}',
#  '193': '{"subjects": ["Fitch Asa"], "occupations": ["mer"], "locations": [{"value": "43 New"}, {"value": "8 University place", "labels": ["h"]}]}',
#  '194': '{"subjects": ["Fitch William"], "occupations": ["merchant"], "locations": [{"value": "43 New"}]}',
#  '195': '{"subjects": ["Fitz John"], "occupations": ["foundry"], "locations": [{"value": "149 Bowery"}]}',
#  '196': '{"subjects": ["Fitzgerald Edward"], "occupations": ["mason"], "locations": [{"value": "E . 22d n . Av . 3"}]}',
#  '197': '{"subjects": ["Fletcher John W"], "occupations": ["smith"], "locations": [{"value": "92 Delancy"}]}',
#  '198': '{"subjects": ["Flood James"], "occupations": ["grocer"], "locations": [{"value": "346 Sixth"}, {"value": "346 Sixth", "labels": ["h"]}]}',
#  '199': '{"subjects": ["Flowers George"], "occupations": ["machinist"], "locations": [{"value": "6 Columbia place"}]}',
#  '200': '{"subjects": ["Folkes Thomas"], "occupations": ["caulker"], "locations": [{"value": "153 Goerck"}]}',
#  '201': '{"subjects": ["Ford Augustus"], "occupations": ["furrier"], "locations": [{"value": "184 Spring"}]}',
#  '202': '{"subjects": ["Forrest James"], "occupations": ["hatter"], "locations": [{"value": "22 Mulberry"}]}',
#  '203': '{"subjects": ["Forrester Charles"], "occupations": ["lettercarrier"], "locations": [{"value": "27 Columbia"}]}',
#  '204': '{"subjects": ["Foster Charles R"], "occupations": ["carman"], "locations": [{"value": "214 E . 11th"}]}',
#  '205': '{"subjects": ["Foster James"], "occupations": ["joiner"], "locations": [{"value": "Twelfth n . Dry dock"}]}',
#  '206': '{"subjects": ["Foster Joseph A"], "occupations": ["bookkeeper"], "locations": [{"value": "75 Varick"}]}',
#  '207': '{"subjects": ["Foster Samuel"], "occupations": ["carriagemaker"], "locations": [{"value": "203 Mercer"}, {"value": "203 Mercer", "labels": ["h"]}]}',
#  '208': '{"subjects": ["Foster 8 . R"], "occupations": ["broker"], "locations": [{"value": "166 Greenwich"}, {"value": "Harlem", "labels": ["h"]}]}',
#  '209': '{"subjects": ["Fotzlen Adam"], "occupations": ["segars"], "locations": [{"value": "34 Av , B"}]}',
#  '210': '{"subjects": ["Fountain Garret W"], "occupations": ["chairs"], "locations": [{"value": "284 E . 13th"}]}',
#  '211': '{"subjects": ["Fountain Henry K"], "occupations": ["lighter"], "locations": [{"value": "61 Whitehall"}, {"value": "Starr", "labels": ["h"]}]}',
#  '212': '{"subjects": ["Francis J . M"], "occupations": ["telegraph agent", "way"], "locations": [{"value": "181 B"}, {"value": "46 Hudson", "labels": ["h"]}]}',
#  '213': '{"subjects": ["Gerdeng Ludowick"], "occupations": ["cabinetmaker"], "locations": [{"value": "18 Doyer"}]}',
#  '214': '{"subjects": ["Gerdes Martin"], "occupations": ["grocer"], "locations": [{"value": "19 Pell"}]}',
#  '215': '{"subjects": ["Gerety Francis"], "occupations": ["clerk"], "locations": [{"value": "31 Old slip"}, {"value": "5 State", "labels": ["h"]}]}',
#  '216': '{"subjects": ["Gerety Michael"], "occupations": ["stonecutter"], "locations": [{"value": "192 Av . 1"}]}',
#  '217': '{"subjects": ["Gerger Valentine"], "occupations": ["porterhouse"], "locations": [{"value": "127 Ridge"}]}',
#  '218': '{"subjects": ["Gerhard Baltzel"], "occupations": ["grocer"], "locations": [{"value": "115 Delancy"}]}',
#  '219': '{"subjects": ["Germer Ludolph"], "occupations": ["cabinetmaker"], "locations": [{"value": "65 Beekman"}, {"value": "0 Beekman", "labels": ["h"]}]}',
#  '220': '{"subjects": ["Gerry James M"], "occupations": ["shoes"], "locations": [{"value": "564 Grand"}, {"value": "564 Grand", "labels": ["h"]}]}',
#  '221': '{"subjects": ["Gildmeister Charles"], "occupations": ["artist"], "locations": [{"value": "200 Fulton"}]}',
#  '222': '{"subjects": ["Gregory Stephen B"], "occupations": ["crockery"], "locations": [{"value": "115 Pearl"}, {"value": "113 Clinton , Brooklyn", "labels": ["h"]}]}',
#  '223': '{"subjects": ["Gregory & Co"], "occupations": ["crockery"], "locations": [{"value": "115 Pearl"}]}',
#  '224': '{"subjects": ["Gruby William"], "occupations": ["Albany ale"], "locations": [{"value": "254 Washington"}, {"value": "Jersey City", "labels": ["bh"]}]}',
#  '225': '{"subjects": ["Hall William"], "occupations": ["grocer"], "locations": [{"value": "195 Monroe", "labels": ["h", " r"]}]}',
#  '226': '{"subjects": ["Halsted Richard F"], "occupations": [], "locations": [{"value": "217 W . 18th", "labels": ["h"]}]}',
#  '227': '{"subjects": ["Harmer Charles G"], "occupations": ["imp"], "locations": [{"value": "161 Madison", "labels": ["h"]}]}',
#  '228': '{"subjects": ["Harmon Philip C"], "occupations": ["brewer"], "locations": [{"value": "6 Sheriff"}, {"value": "65 S . Fifth , Williamsburg", "labels": ["h"]}]}',
#  '229': '{"subjects": ["Harney John"], "occupations": ["machinist", "Jane c . Greenwich"], "locations": [{"value": "687 Hudson", "labels": ["h"]}]}',
#  '230': '{"subjects": ["Hendrickson & Pearsall"], "occupations": ["stables"], "locations": [{"value": "675 Fourth"}]}',
#  '231': '{"subjects": ["Herman Jacob"], "occupations": ["segars"], "locations": [{"value": "21 Av . C"}]}',
#  '232': '{"subjects": ["Hickok William", "G"], "occupations": ["agent", "wich c . Dey"], "locations": [{"value": "B\'klyn", "labels": ["h"]}]}',
#  '233': '{"subjects": ["Hillsburgh Charles"], "occupations": [], "locations": [{"value": "65 Monroe", "labels": ["h"]}]}',
#  '234': '{"subjects": ["Hirschland Isaac"], "occupations": ["butcher"], "locations": [{"value": "263 Third"}]}',
#  '235': '{"subjects": ["Hopkins George W"], "occupations": ["butcher"], "locations": [{"value": "128 Suffolk"}]}',
#  '236': '{"subjects": ["Hoppin Hamilton"], "occupations": ["mer", "Centre c . Duane"], "locations": [{"value": "12 Washington square ,", "labels": ["h"]}]}',
#  '237': '{"subjects": ["Horton Franklin"], "occupations": ["shipcarpenter"], "locations": [{"value": "674 Fourth"}]}',
#  '238': '{"subjects": ["Howe Smith"], "occupations": ["cooper"], "locations": [{"value": "660 Water"}, {"value": "90 Essex", "labels": ["h"]}]}',
#  '239': '{"subjects": ["Hoyt William"], "occupations": ["leather"], "locations": [{"value": "40 Spruce"}, {"value": "82 E . B . way", "labels": ["h"]}]}',
#  '240': '{"subjects": ["Hubbs Scott"], "occupations": ["stagedriver"], "locations": [{"value": "600 Fourth"}]}',
#  '241': '{"subjects": ["Hugel Adolphus D"], "occupations": ["mer"], "locations": [{"value": "58 Cedar"}]}',
#  '242': '{"subjects": ["Jackson Lorig"], "occupations": ["shipcarpenter"], "locations": [{"value": "297 Third"}]}',
#  '243': '{"subjects": ["Jacobson John C"], "occupations": ["com", "mer"], "locations": [{"value": "121 Water"}]}',
#  '244': '{"subjects": ["Jenings Chester"], "occupations": ["late City Hotel"], "locations": [{"value": "Astor House", "labels": ["h"]}]}',
#  '245': '{"subjects": ["Keily Joseph H"], "occupations": ["saddler"], "locations": [{"value": "552 Broadway"}]}',
#  '246': '{"subjects": ["Kinsela Michael"], "occupations": ["shoemaker"], "locations": [{"value": "302 Third"}]}',
#  '247': '{"subjects": ["Kolb Christian"], "occupations": ["tailor"], "locations": [{"value": "350 Av . 1"}]}',
#  '248': '{"subjects": ["Lamb John"], "occupations": [], "locations": [{"value": "$4 Broadway"}, {"value": "Brooklyn", "labels": ["h"]}]}',
#  '249': '{"subjects": ["Lannon Matthew"], "occupations": ["liquors"], "locations": [{"value": "37 Av . D"}]}',
#  '250': '{"subjects": ["Lawrance F . C . & Co"], "occupations": ["auctioneers"], "locations": [{"value": "12 Wall"}]}',
#  '251': '{"subjects": ["LEFMAN HENRY & CO"], "occupations": ["mers"], "locations": [{"value": "232 Washington"}, {"value": "15 Union pl . Hoboken", "labels": ["h"]}]}',
#  '252': '{"subjects": ["Lindeman John G"], "occupations": ["grocer"], "locations": [{"value": "449 W . 29th", "labels": ["h"]}]}',
#  '253': '{"subjects": ["Lockwood Delia"], "occupations": ["widow of Alen"], "locations": [{"value": "650 Fourth"}]}',
#  '254': '{"subjects": ["Lockwood Henrietta"], "occupations": ["school"], "locations": [{"value": "650 Fourth"}]}',
#  '255': '{"subjects": ["Loder Mrs"], "occupations": ["Edward"], "locations": [{"value": "EF . 23d n . Av . 4"}]}',
#  '256': '{"subjects": ["Loebenstein Moses A"], "occupations": ["musician"], "locations": [{"value": "263 Third"}]}',
#  '257': '{"subjects": ["M\'Carty Daniol"], "occupations": ["smith"], "locations": [{"value": "303 Elizabeth", "labels": ["r"]}]}',
#  '258': '{"subjects": ["Mandeville Henry"], "occupations": ["stairbuilder"], "locations": [{"value": "E . 19th n . Beway"}, {"value": "95 Greenwich Ay", "labels": ["h"]}]}',
#  '259': '{"subjects": ["Manhertz William"], "occupations": ["tailor"], "locations": [{"value": "233 William"}, {"value": "238 Wm", "labels": ["h"]}]}',
#  '260': '{"subjects": ["Markart Casper"], "occupations": ["porterhouse"], "locations": [{"value": "205 Third"}]}',
#  '261': '{"subjects": ["Marshall George"], "occupations": ["clothier"], "locations": [{"value": "354 Grand"}, {"value": "107 Allen", "labels": ["h"]}]}',
#  '262': '{"subjects": ["Maurer Henrich"], "occupations": ["publichouse"], "locations": [{"value": "243 Third"}]}',
#  '263': '{"subjects": ["Mohr Peter"], "occupations": ["grocer"], "locations": [{"value": "213 Third"}]}',
#  '264': '{"subjects": ["Moore Jacob"], "occupations": ["tailor"], "locations": [{"value": "592 Fourth"}]}',
#  '265': '{"subjects": ["Morell Tunis"], "occupations": ["furniture"], "locations": [{"value": "374 Broadway"}, {"value": "12 Union place", "labels": ["h"]}, {"value": "S . Brooklyn"}]}',
#  '266': '{"subjects": ["Moser John"], "occupations": ["butcher"], "locations": [{"value": "617 Fourth"}]}',
#  '267': '{"subjects": ["Murphy Thomas"], "occupations": ["shoemkr"], "locations": [{"value": "346 Av . 4"}, {"value": "241 E . 25th", "labels": ["h"]}]}',
#  '268': '{"subjects": ["Nagel John P"], "occupations": ["books"], "locations": [{"value": "102 Nassau"}]}',
#  '269': '{"subjects": ["Newman John"], "occupations": ["music printer"], "locations": [{"value": "16 Spruce"}, {"value": "13 Fifth", "labels": ["h"]}]}',
#  '270': '{"subjects": ["Newsom Eli"], "occupations": ["grocer"], "locations": [{"value": "629 Fourth"}]}',
#  '271': '{"subjects": ["O\'Carroll Mathew F"], "occupations": ["drygoods"], "locations": [{"value": "39 Walker"}]}',
#  '272': '{"subjects": ["Paten Jonathan"], "occupations": ["merchant"], "locations": [{"value": "192 Pearl"}, {"value": "9 Warren pl", "labels": ["h"]}]}',
#  '273': '{"subjects": ["Penniston Charles"], "occupations": ["carman"], "locations": [{"value": "55 Cannon"}]}',
#  '274': '{"subjects": ["Perkins Dennis"], "occupations": ["dry goods", "way"], "locations": [{"value": "39 B"}, {"value": "Brooklyn", "labels": ["h"]}]}',
#  '275': '{"subjects": ["PERKINS , WARREN & CO"], "occupations": ["drygds"], "locations": [{"value": "39 Broadway"}]}',
#  '276': '{"subjects": ["Persiani Ann"], "occupations": ["widow Richard"], "locations": [{"value": "291 Third"}]}',
#  '277': '{"subjects": ["Portington Anthony"], "occupations": ["cabinetmaker"], "locations": [{"value": "396 Hudson"}, {"value": "114 Varick", "labels": ["h"]}]}',
#  '278': '{"subjects": ["Portington Edward"], "occupations": ["cabinetmaker"], "locations": [{"value": "396 Hudson"}, {"value": "65 Sullivan", "labels": ["h"]}]}',
#  '279': '{"subjects": ["Raynor William H"], "occupations": ["agent"], "locations": [{"value": "Broadway c . W . 33d"}, {"value": "Broadway n . W . 32d", "labels": ["h"]}]}',
#  '280': '{"subjects": ["Sayre Samuel A"], "occupations": ["joiner"], "locations": [{"value": "299 W . 25th"}]}',
#  '281': '{"subjects": ["Shepard Elliot F"], "occupations": [], "locations": [{"value": "76 Broad"}]}',
#  '282': '{"subjects": ["Shepard Fitch"], "occupations": [], "locations": [{"value": "1 Wall"}]}',
#  '283': '{"subjects": ["Stroit John"], "occupations": ["ice"], "locations": [{"value": "651 Washington"}]}',
#  '284': '{"subjects": ["Totten Samuel"], "occupations": ["shoemaker"], "locations": [{"value": "67 Hamersly"}]}',
#  '285': '{"subjects": ["Aaron Elias E"], "occupations": ["late com", "mer"], "locations": [{"value": "214 Tenth", "labels": ["h"]}]}',
#  '286': '{"subjects": ["Abbott Theodore H"], "occupations": ["toolmaker"], "locations": [{"value": "120 Columbia"}]}',
#  '287': '{"subjects": ["Aarons Barnett"], "occupations": ["segars"], "locations": [{"value": "260 Grand"}, {"value": "260 Grand", "labels": ["h"]}]}',
#  '288': '{"subjects": ["AARONS & MYERS"], "occupations": ["segars"], "locations": [{"value": "260 Grand"}]}',
#  '289': '{"subjects": ["Abb John"], "occupations": ["blinds"], "locations": [{"value": "129 Third"}]}',
#  '290': '{"subjects": ["Abbatt Isaac"], "occupations": ["secy", "mut", "life ins"], "locations": [{"value": "co . 35 Wall"}, {"value": "120", "labels": ["h"]}]}',
#  '291': '{"subjects": ["Abbatt Wm . D . & Co"], "occupations": ["clothiers"], "locations": [{"value": "163 William"}, {"value": "71", "labels": ["h"]}]}',
#  '292': '{"subjects": ["ABBATT WILLIAM M"], "occupations": ["mer"], "locations": [{"value": "29 Burling sl"}, {"value": "72", "labels": ["h"]}]}',
#  '293': '{"subjects": ["Abbe George W"], "occupations": ["mer"], "locations": [{"value": "43 John"}, {"value": "37 E . 20th", "labels": ["h"]}]}',
#  '294': '{"subjects": ["Abbe Joshua G"], "occupations": ["clerk"], "locations": [{"value": "43 John"}, {"value": "Taylor\'s hotel", "labels": ["h"]}]}',
#  '295': '{"subjects": ["Abbenseth John A"], "occupations": ["grocer"], "locations": [{"value": "280 Av . 8"}, {"value": "280 Av . 3", "labels": ["h"]}]}',
#  '296': '{"subjects": ["Abberley Jno"], "occupations": ["jr", "painter"], "locations": [{"value": "37 Madsn"}, {"value": "124E . B . way", "labels": ["h"]}]}',
#  '297': '{"subjects": ["Abberley Thomas"], "occupations": ["shipjoiner"], "locations": [{"value": "225 Lewis"}, {"value": "Green", "labels": ["h"]}]}',
#  '298': '{"subjects": ["Abbets John"], "occupations": ["mason"], "locations": [{"value": "110 Twelfth", "labels": ["r"]}]}',
#  '299': '{"subjects": ["Abbey Westminster S"], "occupations": ["mer"], "locations": [{"value": "61 Front"}, {"value": "Brooklyn", "labels": ["h"]}]}',
#  '300': '{"subjects": ["ABBOT ABIEL & SON"], "occupations": ["pianofortes"], "locations": [{"value": "2974 Broadway"}, {"value": "100 York , Jersey City", "labels": ["h"]}]}',
#  '301': '{"subjects": ["Abbot Abijah"], "occupations": ["carman"], "locations": [{"value": "4 Tompkins"}]}',
#  '302': '{"subjects": ["Abbot Clarissa"], "occupations": ["widow of Abijah"], "locations": [{"value": "471 Grand", "labels": ["h"]}]}',
#  '303': '{"subjects": ["Abbot Dani"], "occupations": ["jr", "beer"], "locations": [{"value": "103 Anthony"}, {"value": "47 N . Moore", "labels": ["h"]}]}',
#  '304': '{"subjects": ["Abbot Francis H"], "occupations": ["mer"], "locations": [{"value": "141 Front"}, {"value": "Court c . Jora-", "labels": ["h"]}]}',
#  '305': '{"subjects": ["Abbot James P"], "occupations": ["cooper"], "locations": [{"value": "20 Norfolk"}]}',
#  '306': '{"subjects": ["Abbot John D"], "occupations": ["com", "mer"], "locations": [{"value": "29534 Pearl"}, {"value": "Brooklyn", "labels": ["h"]}]}',
#  '307': '{"subjects": ["Abbot John M"], "occupations": ["pianos"], "locations": [{"value": "29734 Broadway"}, {"value": "100", "labels": ["h"]}]}',
#  '308': '{"subjects": ["Abbot & Wilcomb"], "occupations": ["com", "mers"], "locations": [{"value": "29534 Pearl"}]}',
#  '309': '{"subjects": ["ABBOT , DODGE & CO"], "occupations": ["com", "mers"], "locations": [{"value": "141 Front"}]}',
#  '310': '{"subjects": ["Abbott Asel B"], "occupations": ["coals", "wich"], "locations": [{"value": "833 G"}, {"value": "790 Washgtn", "labels": ["h"]}]}',
#  '311': '{"subjects": ["Abbott Benjamin V . C"], "occupations": ["carman"], "locations": [{"value": "42 Essex"}]}',
#  '312': '{"subjects": ["Abbott Charles"], "occupations": ["chairmaker"], "locations": [{"value": "250 Stanton"}]}',
#  '313': '{"subjects": ["Abbott Evander D"], "occupations": ["books"], "locations": [{"value": "84 Ludlow", "labels": ["h"]}]}',
#  '314': '{"subjects": ["Abbott Francis"], "occupations": ["telgrph"], "locations": [{"value": "5 Hanover"}, {"value": "254E . B . way", "labels": ["h"]}]}',
#  '315': '{"subjects": ["ABBOTT GORHAM D . (Rev"], "occupations": [], "locations": [{"value": "Abbott\'s collegiate", "labels": [")"]}]}',
#  '316': '{"subjects": ["Abbott Homer B"], "occupations": ["porter"], "locations": [{"value": "543 Laight", "labels": ["h"]}]}',
#  '317': '{"subjects": ["Abbott Jacob (Rev"], "occupations": [], "locations": [{"value": "260 Greene .", "labels": [")"]}]}',
#  '318': '{"subjects": ["ABBOTT JOHN S . C . (Rev"], "occupations": [], "locations": [{"value": "institution for young", "labels": [")"]}]}',
#  '319': '{"subjects": ["Abbott Joseph"], "occupations": ["u . s . inspector"], "locations": [{"value": "170 Attorney"}]}',
#  '320': '{"subjects": ["Abbott Mary Ann", "wid . Merrick"], "occupations": ["sewing"], "locations": [{"value": "158W . 20th"}]}',
#  '321': '{"subjects": ["Abbott N"], "occupations": ["physician"], "locations": [{"value": "349 Cherry"}]}',
#  '322': '{"subjects": ["Abbott Nathaniel B"], "occupations": ["policeman"], "locations": [{"value": "E . 30th n . Av . 3"}]}',
#  '323': '{"subjects": ["Abbott Samuel"], "occupations": ["scales"], "locations": [{"value": "7 Nassau"}, {"value": "Philadelphia", "labels": ["h"]}]}',
#  '324': '{"subjects": ["Abbott Samuel P"], "occupations": ["inspector"], "locations": [{"value": "75 Montgomery"}]}',
#  '325': '{"subjects": ["Abbott Sarah M . wid . Samuel"], "occupations": [], "locations": [{"value": "W . 40th c . B . way", "labels": ["h"]}]}',
#  '326': '{"subjects": ["Abbott Thomas 3"], "occupations": ["carrier"], "locations": [{"value": "\\u00c2\\u00a74 Ludlow"}]}',
#  '327': '{"subjects": ["ABBOTT TIMOTHY B"], "occupations": ["coals"], "locations": [{"value": "833 Greenwich , and"}]}',
#  '328': '{"subjects": ["Abbott Walter S"], "occupations": ["saddler"], "locations": [{"value": "273 Bowery"}, {"value": "187 Forsyth", "labels": ["h"]}]}',
#  '329': '{"subjects": ["Abbott William"], "occupations": ["portrh"], "locations": [{"value": "117 Cedar"}, {"value": "117 Cedar", "labels": ["h"]}]}',
#  '330': '{"subjects": ["Abbott William"], "occupations": ["weaver"], "locations": [{"value": "W . 29th n . Av . 8"}]}',
#  '331': '{"subjects": ["Abbott & Watt"], "occupations": ["porterhouse"], "locations": [{"value": "117 Cedar"}]}',
#  '332': '{"subjects": ["Abbs Thomas"], "occupations": ["butcher"], "locations": [{"value": "94 Lewis"}]}',
#  '333': '{"subjects": ["Abeal Sarah"], "occupations": ["widow of Peter"], "locations": [{"value": "584 Houston"}]}',
#  '334': '{"subjects": ["Abeel Abby"], "occupations": ["widow of Elisha"], "locations": [{"value": "24 Second", "labels": ["h"]}]}',
#  '335': '{"subjects": ["Abeel Cath"], "occupations": ["fancy store"], "locations": [{"value": "37734 Grand"}, {"value": "37734 Grand", "labels": ["h"]}]}',
#  '336': '{"subjects": ["Abeel George"], "occupations": ["late iron mer"], "locations": [{"value": "125 Av . 2 ."}]}',
#  '337': '{"subjects": ["Abeel John H . & CO"], "occupations": ["iron"], "locations": [{"value": "190 South & 365 Water ,"}]}',
#  '338': '{"subjects": ["Abel Charles A"], "occupations": ["public house"], "locations": [{"value": "474 Broadway"}]}',
#  '339': '{"subjects": ["Abel Charles H"], "occupations": ["public house"], "locations": [{"value": "City Hotel", "labels": ["h"]}]}',
#  '340': '{"subjects": ["Abel Christian"], "occupations": ["porter"], "locations": [{"value": "152 Norfolk ."}]}',
#  '341': '{"subjects": ["Abel Edwin L"], "occupations": ["bookkeeper"], "locations": [{"value": "161 Maiden lane"}, {"value": ".", "labels": ["h"]}]}',
#  '342': '{"subjects": ["Abel Jacob R"], "occupations": ["cooper"], "locations": [{"value": "32 Clarkson"}]}',
#  '343': '{"subjects": ["Abel Martin"], "occupations": ["baker"], "locations": [{"value": "71 Cannon"}]}',
#  '344': '{"subjects": ["Abel P . Henry"], "occupations": ["dentist"], "locations": [{"value": "37 Wooster"}]}',
#  '345': '{"subjects": ["Abel Simon C"], "occupations": ["drygds"], "locations": [{"value": "15 Catherine"}, {"value": "103 Monroe", "labels": ["h"]}]}',
#  '346': '{"subjects": ["Abel Theodore"], "occupations": ["butcher"], "locations": [{"value": "359 Rivington"}]}',
#  '347': '{"subjects": ["Abell Charles D"], "occupations": ["druggist"], "locations": [{"value": "1 Hammond"}]}',
#  '348': '{"subjects": ["Abell Harriet"], "occupations": ["boarding"], "locations": [{"value": "40 Greene"}]}',
#  '349': '{"subjects": ["Abell Henry"], "occupations": [], "locations": [{"value": "77 Av . 4 ."}]}',
#  '350': '{"subjects": ["Abell John \'W"], "occupations": ["hosiery", "way", "bds"], "locations": [{"value": "140 B"}, {"value": "Rathbun\'s"}]}',
#  '351': '{"subjects": ["Abell Thomas M"], "occupations": ["physician"], "locations": [{"value": "47 Cherry"}, {"value": "47 Cherry", "labels": ["h"]}]}',
#  '352': '{"subjects": ["Abendroth Aug"], "occupations": ["stoves"], "locations": [{"value": "117 Bkman"}, {"value": "Portchester", "labels": ["h"]}]}',
#  '353': '{"subjects": ["Abendroth John"], "occupations": ["stoves"], "locations": [{"value": "117 Bkman"}, {"value": "Portchester", "labels": ["h"]}]}',
#  '354': '{"subjects": ["Abendroth Wm . P"], "occupations": ["stoves"], "locations": [{"value": "117 Bkmn"}, {"value": "Portchester", "labels": ["h"]}]}',
#  '355': '{"subjects": ["Abendroth Brothers"], "occupations": ["stoves"], "locations": [{"value": "117 Bkmn"}, {"value": "Ptchester", "labels": ["h"]}]}',
#  '356': '{"subjects": ["Abercrombie Chas"], "occupations": ["teacher"], "locations": [{"value": "429 Avy"}, {"value": "6"}, {"value": "136W . 28th", "labels": ["h ,"]}]}',
#  '357': '{"subjects": ["Abercrombie John"], "occupations": ["pianoforte mkr"], "locations": [{"value": "W . 27th n . Av . 6"}]}',
#  '358': '{"subjects": ["Abercromby Andrew"], "occupations": ["tinsmith"], "locations": [{"value": "333 Av . 6", "labels": ["h"]}]}',
#  '359': '{"subjects": ["Aberham Jacob"], "occupations": ["tailor"], "locations": [{"value": "90 Ridge"}]}',
#  '360': '{"subjects": ["Abernethy Charles"], "occupations": ["mer"], "locations": [{"value": "47 Liberty"}, {"value": "10 E . 14th", "labels": ["h"]}]}',
#  '361': '{"subjects": ["Abernethy Richard"], "occupations": ["mats"], "locations": [{"value": "199 W 24th"}]}',
#  '362': '{"subjects": ["Abers Frederick"], "occupations": ["sugarbaker"], "locations": [{"value": "96 Charlton"}]}',
#  '363': '{"subjects": ["Abig Adolphus"], "occupations": ["carver"], "locations": [{"value": "98 First :", "labels": ["r"]}]}',
#  '364': '{"subjects": ["Aborn Charles B"], "occupations": ["com", "mer"], "locations": [{"value": "108 Broad"}, {"value": "Brooklyn", "labels": ["h"]}]}',
#  '365': '{"subjects": ["Aborn Robt . W"], "occupations": ["mer"], "locations": [{"value": "11 Nassau"}, {"value": "180 Henry , BAlyn \\u00e2\\u20ac\\u201d", "labels": ["h"]}]}',
#  '366': '{"subjects": ["Abrahall Samuel"], "occupations": ["oil"], "locations": [{"value": "73 Broome"}]}',
#  '367': '{"subjects": ["Abrahall William A"], "occupations": ["boarding"], "locations": [{"value": "2 Lewis"}]}',
#  '368': '{"subjects": ["Abraham Benjamin"], "occupations": ["tailor"], "locations": [{"value": "165 Second"}]}',
#  '369': '{"subjects": ["Abraham Henry"], "occupations": ["jewlr"], "locations": [{"value": "124 Stanton"}, {"value": "124 Stanton", "labels": ["h"]}]}',
#  '370': '{"subjects": ["Abraham Jacob"], "occupations": ["boots", "shoes", "bh"], "locations": [{"value": "185 Clinton"}, {"value": "185 Cla"}]}',
#  '371': '{"subjects": ["Abraham Jacob"], "occupations": ["boots"], "locations": [{"value": "185 Rivington :"}]}',
#  '372': '{"subjects": ["Abraham Judah"], "occupations": ["drygds"], "locations": [{"value": "102 Clmbia"}, {"value": "102 Columbia", "labels": ["h"]}]}',
#  '373': '{"subjects": ["Abraham Morris"], "occupations": ["caps"], "locations": [{"value": "455 Pearl"}, {"value": "455 Pearl", "labels": ["h"]}]}',
#  '374': '{"subjects": ["Abraham Samuel"], "occupations": ["tailor"], "locations": [{"value": "225 Seventh"}]}',
# ...
#  '881': '{"subjects": ["\'Aldrich John H"], "occupations": ["carpets"], "locations": [{"value": "440 Pearl"}, {"value": "172 Av . A", "labels": ["h"]}]}',
#  '882': '{"subjects": ["\'Aldrich Lewis P"], "occupations": ["com", "mer"], "locations": [{"value": "66 Broad"}, {"value": "99 Prince", "labels": ["h"]}]}',
#  '883': '{"subjects": ["\'Aldrich Moses B"], "occupations": ["machinist"], "locations": [{"value": "117 Attorney"}, {"value": "205 Stanton :", "labels": ["h"]}]}',
#  '884': '{"subjects": ["ALDRICH & BURTON"], "occupations": ["drygds"], "locations": [{"value": "67 Liberty"}]}',
#  '885': '{"subjects": ["Aldridge Esther"], "occupations": ["widow of Joshua"], "locations": [{"value": "314 Rivington"}]}',
#  '886': '{"subjects": ["Aldridge John"], "occupations": ["bricklayer"], "locations": [{"value": "260 E . 25th"}]}',
#  '887': '{"subjects": ["Aldridge Samuel"], "occupations": ["(col\'d) waiter"], "locations": [{"value": "36 Bedford"}]}',
#  '888': '{"subjects": ["\'Alexander Alexander"], "occupations": ["stonecutter"], "locations": [{"value": "\\u00c2\\u00a300 W , 20th"}]}',
#  '889': '{"subjects": ["Alexander Alex"], "occupations": ["grocer"], "locations": [{"value": "663 Houston"}, {"value": "663 Houstn", "labels": ["h"]}]}',
#  '890': '{"subjects": ["\'Alexander Andrew"], "occupations": ["laborer"], "locations": [{"value": "W . 31st"}, {"value": "Av . 9", "labels": ["n"]}]}',
#  '891': '{"subjects": ["\'Alexander Cesar"], "occupations": ["(col\'d) waiter"], "locations": [{"value": "74 Reade", "labels": ["r"]}]}',
#  '892': '{"subjects": ["Alexander David"], "occupations": ["milkman"], "locations": [{"value": "19 Prince", "labels": ["h"]}]}',
#  '893': '{"subjects": ["\'Alexander David"], "occupations": ["carpenter"], "locations": [{"value": "188 Ludlow"}]}',
#  '894': '{"subjects": ["Alexander Egbert"], "occupations": ["music teacher"], "locations": [{"value": "87 Essex"}]}',
#  '895': '{"subjects": ["Alexander Emanuel"], "occupations": ["pedler"], "locations": [{"value": "229 Second"}]}',
#  '896': '{"subjects": ["Alexander Francis"], "occupations": ["whalebone"], "locations": [{"value": "80 Nassau", "labels": ["r"]}]}',
#  '897': '{"subjects": ["\'Alexander George"], "occupations": ["blacksmith"], "locations": [{"value": "299 Sixth"}]}',
#  '898': '{"subjects": ["Alexander George"], "occupations": ["engineer"], "locations": [{"value": "298 Seventh h . 128"}]}',
#  '899': '{"subjects": ["Alexander George W"], "occupations": ["binder"], "locations": [{"value": "7 Spruce , Prospect , Brooklyn"}]}',
#  '900': '{"subjects": ["Alexander Henry"], "occupations": ["jr . sec\'y atlantic dock co"], "locations": [{"value": "74 Broadway"}, {"value": "Hicks n . Sackett , Brooklyn", "labels": ["h"]}]}',
#  '901': '{"subjects": ["Alexander Henry M"], "occupations": ["lawyer"], "locations": [{"value": "11 Nassau"}, {"value": "77 E . 27th", "labels": ["h"]}]}',
#  '902': '{"subjects": ["Alexander Isaac"], "occupations": ["jeweller"], "locations": [{"value": "422 Grand <~"}]}',
#  '903': '{"subjects": ["Alexander Israel"], "occupations": ["jeweller"], "locations": [{"value": "25 Attorne"}]}',
#  '904': '{"subjects": ["Alexander Jacob"], "occupations": ["watchmkr"], "locations": [{"value": "12 Fulton"}, {"value": "244 Secnd", "labels": ["h"]}]}',
#  '905': '{"subjects": ["Alexander James"], "occupations": ["laborer"], "locations": [{"value": "503 Houston", "labels": ["r"]}]}',
#  '906': '{"subjects": ["Alexander James"], "occupations": ["dry goods"], "locations": [{"value": "164 Canal"}, {"value": "164 Canal", "labels": ["h"]}]}',
#  '907': '{"subjects": ["Alexander James"], "occupations": ["plasterer"], "locations": [{"value": "6 W . 27th"}]}',
#  '908': '{"subjects": ["Alexander James"], "occupations": ["boatman"], "locations": [{"value": "83 Hester"}]}',
#  '909': '{"subjects": ["Alexander James G"], "occupations": ["segar maker"], "locations": [{"value": "131 Goerck"}]}',
#  '910': '{"subjects": ["Alexander James K"], "occupations": ["clerk"], "locations": [{"value": "65 Pine"}, {"value": "Brooklyn", "labels": ["h"]}]}',
#  '911': '{"subjects": ["Alexander John ,"], "occupations": ["plasterer"], "locations": [{"value": "350 Av . 6"}]}',
#  '912': '{"subjects": ["Alexander John"], "occupations": ["clerk"], "locations": [{"value": "24 Rivington", "labels": ["h", " r"]}]}',
#  '913': '{"subjects": ["Alexander John"], "occupations": ["moulder"], "locations": [{"value": "378 Ninth"}]}',
#  '914': '{"subjects": ["Alexander John"], "occupations": ["coffeeroaster"], "locations": [{"value": "69 Cannon"}]}',
#  '915': '{"subjects": ["Alexander John"], "occupations": ["agent"], "locations": [{"value": "5 Av . 3", "labels": ["h"]}]}',
#  '916': '{"subjects": ["Alexander John W"], "occupations": ["machinist"], "locations": [{"value": "150 Lewis", "labels": ["h"]}]}',
#  '917': '{"subjects": ["Alexander Joseph"], "occupations": ["machinist"], "locations": [{"value": "380 Tenth"}]}',
#  '918': '{"subjects": ["Alexander Mendel"], "occupations": ["needles"], "locations": [{"value": "119 Third"}]}',
#  '919': '{"subjects": ["Alexander Oscar W"], "occupations": ["shipcarpenter"], "locations": [{"value": "32 Lewis"}]}',
#  '920': '{"subjects": ["Alexander Robert H"], "occupations": ["hardware"], "locations": [{"value": "88 John"}]}',
#  '921': '{"subjects": ["Alexander William"], "occupations": ["carpenter"], "locations": [{"value": "271 Monroe", "labels": ["h"]}]}',
#  '922': '{"subjects": ["Alexander William"], "occupations": ["seaman"], "locations": [{"value": "91 Oliver"}]}',
#  '923': '{"subjects": ["Alexander William"], "occupations": ["whipmaker"], "locations": [{"value": "7 Anthony", "labels": ["h"]}]}',
#  '924': '{"subjects": ["Alexander William"], "occupations": ["carman"], "locations": [{"value": "122 W . 19th"}]}',
#  '925': '{"subjects": ["Alexander William"], "occupations": ["smith"], "locations": [{"value": "98 Grand"}, {"value": "551 Broome", "labels": ["h"]}]}',
#  '926': '{"subjects": ["Alexander Willgam"], "occupations": ["tailor"], "locations": [{"value": "60 Henry", "labels": ["r"]}]}',
#  '927': '{"subjects": ["Alexander & Barton"], "occupations": ["hardware"], "locations": [{"value": "88 John"}]}',
#  '928': '{"subjects": ["Alexandre Francis"], "occupations": ["mer"], "locations": [{"value": "28 South"}, {"value": "14 E . 18th", "labels": ["h"]}]}',
#  '929': '{"subjects": ["Alexandre Lambert"], "occupations": ["engineer"], "locations": [{"value": "23 Maiden Lane"}, {"value": "5 Chambers . -", "labels": ["h"]}]}',
#  '930': '{"subjects": ["Alfaya Francisco"], "occupations": ["Spanish hotel"], "locations": [{"value": "65 Fulton"}]}',
#  '931': '{"subjects": ["Alfka John"], "occupations": ["grer"], "locations": [{"value": "104 Grand & 251 Av . 6"}, {"value": "104 Grnd", "labels": ["h"]}]}',
#  '932': '{"subjects": ["Alfonce Joseph E"], "occupations": ["manf"], "locations": [{"value": "47 Ann"}, {"value": "198 William", "labels": ["h ,"]}]}',
#  '933': '{"subjects": ["ALFONCE & CO"], "occupations": ["manf"], "locations": [{"value": "47 Ann"}]}',
#  '934': '{"subjects": ["Alford Edwin M"], "occupations": ["paints"], "locations": [{"value": "550 Grand"}, {"value": "14 Cannon", "labels": ["h ,"]}]}',
#  '935': '{"subjects": ["Alford Lydia"], "occupations": ["(col\'d) widow of Benj"], "locations": [{"value": "174 Essex", "labels": ["r"]}]}',
#  '936': '{"subjects": ["Alford Samuel M"], "occupations": ["clerk"], "locations": [{"value": "5 Platt"}, {"value": "21 Hammond", "labels": ["h"]}]}',
#  '937': '{"subjects": ["Alford & Dash"], "occupations": ["hardware"], "locations": [{"value": "5 Platt"}]}',
#  '938': '{"subjects": ["Alfred John"], "occupations": ["locksmith"], "locations": [{"value": "41 Allen"}]}',
#  '939': '{"subjects": ["Alger Addison"], "occupations": ["mason"], "locations": [{"value": "58 Stanton"}]}',
#  '940': '{"subjects": ["Alger Andrew J"], "occupations": ["bookkeeper"], "locations": [{"value": "94 W . Broadway"}]}',
#  '941': '{"subjects": ["Alger Charles C"], "occupations": ["clerk"], "locations": [{"value": "127 Franklin"}]}',
#  '942': '{"subjects": ["Alger Daniel B"], "occupations": ["grocer"], "locations": [{"value": "85 Dey"}, {"value": "Harsimus", "labels": ["h"]}]}',
#  '943': '{"subjects": ["Alger Seneca"], "occupations": ["grocer"], "locations": [{"value": "85 Dey"}, {"value": "Jersey city", "labels": ["h"]}]}',
#  '944': '{"subjects": ["Alger & Brothers"], "occupations": ["grocers"], "locations": [{"value": "85 Dey"}]}',
#  '945': '{"subjects": ["Alheit Adam"], "occupations": ["baker"], "locations": [{"value": "72 Pike"}]}',
#  '946': '{"subjects": ["Alhiet Adam"], "occupations": ["bootmaker", "27th"], "locations": [{"value": "107E"}, {"value": "107 E . 27th", "labels": ["h"]}]}',
#  '947': '{"subjects": ["Alicotis John M"], "occupations": ["carman"], "locations": [{"value": "10 Lewis"}]}',
#  '948': '{"subjects": ["Alingren Andrew G"], "occupations": ["boarding"], "locations": [{"value": "100 Oliver"}]}',
#  '949': '{"subjects": ["Aliot Jacob"], "occupations": ["tailor"], "locations": [{"value": "29 Av . A"}]}',
#  '950': '{"subjects": ["Alker Adolphus L"], "occupations": ["dentist"], "locations": [{"value": "341 Fourth"}]}',
#  '951': '{"subjects": ["Alker George"], "occupations": ["Apollo rooms"], "locations": [{"value": "410 Broadway and 33 Canal"}, {"value": "33 Canal ~ .", "labels": ["h"]}]}',
#  '952': '{"subjects": ["Alker Henry"], "occupations": ["lawyer"], "locations": [{"value": "27 Beekman"}, {"value": "504 Hudson", "labels": ["h"]}]}',
#  '953': '{"subjects": ["Alker James"], "occupations": ["carman"], "locations": [{"value": "248 Rivington"}]}',
#  '954': '{"subjects": ["Allabern Almeru W"], "occupations": ["feed", "bds"], "locations": [{"value": "523 Hdsn"}, {"value": "15 Morton"}]}',
#  '955': '{"subjects": ["Allaird Palmon"], "occupations": ["carpenter"], "locations": [{"value": "214 Broome"}]}',
#  '956': '{"subjects": ["Allaire Alexander"], "occupations": ["carman"], "locations": [{"value": "636 Greenwich"}]}',
#  '957': '{"subjects": ["Allaire Alexander"], "occupations": ["jr", "teller"], "locations": [{"value": "40 Wall"}, {"value": "Wmsburg", "labels": ["h"]}]}',
#  '958': '{"subjects": ["Allaire Andrew"], "occupations": [], "locations": [{"value": "266 Monroe", "labels": ["h"]}]}',
#  '959': '{"subjects": ["Allaire Anthny M"], "occupations": ["butcher"], "locations": [{"value": "462 Hudsn"}, {"value": "10 Morton", "labels": ["h"]}]}',
#  '960': '{"subjects": ["ALLAIRE ANTHONY J . & CO"], "occupations": ["coppersmith"], "locations": [{"value": "618 Waiter"}, {"value": "169 Henry", "labels": ["h"]}]}',
#  '961': '{"subjects": ["Allaire Charles"], "occupations": ["butcher"], "locations": [{"value": "2 Clinton mkt"}, {"value": "164 Christopher", "labels": ["h"]}]}',
#  '962': '{"subjects": ["Allaire Daniel D"], "occupations": ["butcher"], "locations": [{"value": "534 Hudson"}]}',
#  '963': '{"subjects": ["Allaire Ewd . C"], "occupations": ["manhattan bk"], "locations": [{"value": "40 Wall"}, {"value": "Wmsbg . Cherry", "labels": ["h"]}]}',
#  '964': '{"subjects": ["Allaire Jane"], "occupations": ["widow of Charles D"], "locations": [{"value": "203 W . 24th"}]}',
#  '965': '{"subjects": ["Allaire Margaret"], "occupations": ["widow of Samuel Y"], "locations": [{"value": "161 Mott"}]}',
#  '966': '{"subjects": ["Allaire Maria"], "occupations": ["widow of Edwin"], "locations": [{"value": "22 Morton"}]}',
#  '967': '{"subjects": ["Allaire Mary"], "occupations": ["widow of William"], "locations": [{"value": "468 Houston", "labels": ["h"]}]}',
#  '968': '{"subjects": ["Allaire Philip"], "occupations": ["carpenter"], "locations": [{"value": "22 Morton"}]}',
#  '969': '{"subjects": ["Allaire Robert"], "occupations": ["bookkeeper"], "locations": [{"value": "262 Seventh"}]}',
#  '970': '{"subjects": ["Allaire Seaman"], "occupations": ["butcher"], "locations": [{"value": "301 Bleecker"}, {"value": "61 Leroy", "labels": ["h"]}]}',
#  '971': '{"subjects": ["Allaire Thomas H"], "occupations": ["fancy goods", "and custom house"], "locations": [{"value": "419 Broadway"}, {"value": "93 Morton", "labels": ["h ,"]}]}',
#  '972': '{"subjects": ["Allaire Wilmot D"], "occupations": ["coppersmith"], "locations": [{"value": "44 Broome"}]}',
#  '973': '{"subjects": ["Allan Alexander"], "occupations": ["jeweller"], "locations": [{"value": "111 Division and r . 276 Bowery"}, {"value": "149 Wooster . :", "labels": ["h"]}]}',
#  '974': '{"subjects": ["Allan Andrew"], "occupations": ["engineer"], "locations": [{"value": "Av . 9 \\u00c2\\u00a2 . W . 37th", "labels": ["h"]}]}',
#  '975': '{"subjects": ["Allan George"], "occupations": ["tailor"], "locations": [{"value": "113 Cherry ."}]}',
#  '976': '{"subjects": ["Allan John"], "occupations": [], "locations": [{"value": "17 Vandewater"}]}',
#  '977': '{"subjects": ["Allan Robt"], "occupations": ["provisions"], "locations": [{"value": "226 Washington"}, {"value": "53 Watts", "labels": ["h"]}]}',
#  '978': '{"subjects": ["Allan & Rose"], "occupations": ["butter\'and provisions"], "locations": [{"value": "226 Washgtn"}]}',
#  '979': '{"subjects": ["Allard Andrew"], "occupations": ["clerk"], "locations": [{"value": "E , 42d"}, {"value": "Av . 3 ,", "labels": ["n"]}]}',
#  '980': '{"subjects": ["Allard Nahun W"], "occupations": ["butcher"], "locations": [{"value": "154 Varick"}, {"value": "152 Varick", "labels": ["h"]}]}',
#  '981': '{"subjects": ["Allari Joseph"], "occupations": ["boarding"], "locations": [{"value": "37 Rose"}]}',
#  '982': '{"subjects": ["Allas Joseph A"], "occupations": ["tailor"], "locations": [{"value": "27 Ridge"}]}',
#  '983': '{"subjects": ["Allason W"], "occupations": ["salesman"], "locations": [{"value": "117 Pearl"}, {"value": "Wyck\'ff , Brklyn", "labels": ["h"]}]}',
#  '984': '{"subjects": ["Allason Frances"], "occupations": ["wid . of Thos", "boarding"], "locations": [{"value": "70 G . wich"}]}',
#  '985': '{"subjects": ["Allcock Hugh"], "occupations": ["silver ware", "way"], "locations": [{"value": "341 B"}, {"value": "18 White", "labels": ["h"]}]}',
#  '986': '{"subjects": ["Allcock Thomas"], "occupations": ["chemist"], "locations": [{"value": "24 Perry"}]}',
#  '987': '{"subjects": ["ALLCOCK & ALLEN"], "occupations": ["silverware & furnishing articles"], "locations": [{"value": "341 Broadway"}]}',
#  '988': '{"subjects": ["Allegri Joseph"], "occupations": ["artist"], "locations": [{"value": "131 E . 21st", "labels": ["h"]}]}',
#  '989': '{"subjects": ["Alleh Christopher"], "occupations": ["soap"], "locations": [{"value": "E . 41st n . Av . 1", "labels": ["h"]}]}',
#  '990': '{"subjects": ["Allen A . B"], "occupations": [], "locations": [{"value": "Co . 189 and 191 Water", "labels": ["&"]}]}',
#  '991': '{"subjects": ["Allen Abraham"], "occupations": ["porterh"], "locations": [{"value": "248 West"}, {"value": "44 Hubert", "labels": ["h"]}]}',
#  '992': '{"subjects": ["Allen Abraham"], "occupations": ["carman"], "locations": [{"value": "46 Hubert"}]}',
#  '993': '{"subjects": ["Allen Abraham & Co"], "occupations": ["grocers"], "locations": [{"value": "Av . 8 c . W . 29th & 30 Av . 8"}, {"value": "Av . 8c . W . 29th", "labels": ["h"]}]}',
#  '994': '{"subjects": ["Allen Albert G"], "occupations": ["furnaces"], "locations": [{"value": "351 Broadway; h . 44 Sidney pl . Brooklyn"}]}',
#  '995': '{"subjects": ["Allen Alexander"], "occupations": ["carman"], "locations": [{"value": "W . 18th n . Av . 6", "labels": ["r"]}]}',
#  '996': '{"subjects": ["Allen Andrew"], "occupations": ["machinist"], "locations": [{"value": "W . 37th n . Av . 9"}]}',
#  '997': '{"subjects": ["Allen Andrew"], "occupations": ["cagemaker"], "locations": [{"value": "37 First"}, {"value": "267 Av . 3", "labels": ["h"]}]}',
#  '998': '{"subjects": ["Alen Andrew"], "occupations": ["police"], "locations": [{"value": "564 Grand"}]}',
#  '999': '{"subjects": ["Allen Andrew J"], "occupations": ["costumer"], "locations": [{"value": "37 Bowery"}]}',
#  '1000': '{"subjects": ["Allen Andrew J"], "occupations": ["cagemaker"], "locations": [{"value": "37 First", "labels": ["r"]}, {"value": "267 Av . 3", "labels": ["h"]}]}',
#  ...}

# %%
cities = ['Hoboken', 'N. J.', 'Spain', 'B’klyn', 'Mt. Vernon', 'Jersey City', 'Brooklyn', 'New J','WILLIAMSBURG', 'BUSHWICK', 'GREENPOINT',  'FLATBUSH', 'RAVENSWOOD','CAMPTOWN','CARMANSVLLE', 'WMSBURG','WULIAMSBURG', 'WMBURG','WMSBG','WMSBURGH', 'HOBOKEN', 'N. J.', 'S. ISLAND','SPAIN', 'B’KLYN', 'MT. VERNON','BROOKLYN','JERSEY CITY', 'N. JERSEY', 'CINCINNATI', 'GERMANY', 'STNTN', 'JERSEY C.', 'HOBOK', 'CONNECTICUT','BLYN',"JERSY CTY",'BRKLYN','NEW JERSEY','LONG ISLAND', 'N. ORLEANS', 'BKLYN','BROOKLYR','B.KLYN','JER. C.','CONN', 'L. I.', 'L.I.', 'L. I','L.I','L I','L I.', 'PTCHESTER', "B'KLYN",'J. C.','N.J.','S. I.','S.I.', 'NEW J']
def has_city(address, cities = cities): #returns city if present
    for city in cities:
#         print(city.upper(), [name.upper() for name in address.split()],city.upper() in [name.upper() for name in address])
        if city.capitalize() in address:
              return city
    return ''

# %%
full_entry =[]
for i in range(len(lines)):
    full_entry.append(str(i+1)+ ' '+lines[i])
# full_entry

# %%
address_list = ast.literal_eval(entry_dict[str(1)])['locations']
address_list[1]
# Out:
# {'value': '39 Pearl', 'labels': ['h']}

# %%
n = len(entry_dict)
final_output = {}
# generate fields
for i in range(1,n+1):
    cd = {}
    cd['Full Name'] = ''
    cd['First Name'] = ''
    cd['Last Name'] = ''
    cd['Middle Name'] = ''
    cd['Widow-flag'] = 'False'
    cd['Widow Of'] = ''
    cd['Title'] = ''
    cd['Occupation'] = ''
    cd['Full Address'] = ''
    cd['H Status-flag'] = ''
    cd['H Address'] = ''
    cd['H House Number'] = ''
    cd['H Street Name'] = ''
    cd['H City'] = ''
    cd['Address 2'] = ''
    cd['Address 2 House Number'] = ''
    cd['Address 2 Street Name'] = ''
    cd['Address 2 City'] = ''
#     full_entry_ls = full_entry[i-1].split()
#     cd['Index'] = full_entry_ls[0]
#     cd['Full Entry'] = ' '.join(full_entry_ls[1:])

    record = entry_dict[str(i)]
    # name
    try:
        fullname = ast.literal_eval(entry_dict[str(i)])['subjects'][0]
        fullname_list = fullname.split()
        cd['Full Name'] = fullname
        if(len(fullname_list) == 2):
            cd['Last Name'] = fullname_list[0]
            cd['First Name'] = fullname_list[1]
        elif(len(fullname_list) >= 3):
            cd['Last Name'] = fullname_list[0]
            cd['First Name'] = fullname_list[1]
            cd['Middle Name'] = fullname_list[2]
#         elif(fullname_list[2] == '.' or fullname_list[2] == ','):
#             cd['Last Name'] = fullname_list[0]
#             cd['First Name'] = fullname_list[1]
#             cd['Middle Name'] = fullname_list[3]
            
        
        if(len(ast.literal_eval(entry_dict[str(i)])['occupations'])):
            occupation_to_check_for_widows =  ast.literal_eval(entry_dict[str(i)])['occupations'][0]
            if('wid' in occupation_to_check_for_widows):
                cd['Widow-flag'] = 'True'
                cd['Widow Of'] = fullname_list[0]
                

    #widow flag
        if('wid' in ast.literal_eval(entry_dict[str(i)])['subjects'][-1]):
                cd['Widow-flag'] = 'True'
                cd['Widow Of'] = fullname_list[0]

    except:
        pass
  
  #occupation
    try:
        occupation_list =  ast.literal_eval(entry_dict[str(i)])['occupations']
        if(len(occupation_list) == 1):
            cd['Occupation'] = occupation_list[0]
        else:
            cd['Occupation'] = occupation_list[1]
    except:
        pass
  
#   #address
    try:
#         len(ast.literal_eval(entry_dict['3'])['locations'])
        address = ast.literal_eval(entry_dict[str(i)])['locations']
        full_add = ''
        for item in address:
            if('labels' in item.keys()):
                if('h' in item['labels']):
                    full_add += 'h. '
            full_add += item['value']
            full_add += ', '
        full_add = full_add[:-2]
        cd['Full Address'] = full_add
        if(len(address) == 1): #this means it is house address
            address_1 = address[0]['value'].split()
            cd['H Address'] = address[0]['value']
            if ('labels' in address[0].keys()):
                if('h' in address[0]['labels']):
                    cd['H Status-flag'] = 'True'
            else:
                cd['H Status-flag'] = 'Assume'
#                 start = 0 #index if string where address starts
#         elif(len(address) == 2):
#             if ('labels' in address[0].keys()):
#                 if('h' in address[0]['labels']):
#                     cd['H Status-flag'] = 'True'
#                     cd['H Address'] = address[0]['value']
#                     cd['H House Number'] = ''
#                     cd['H Street Name'] = ''
#                     cd['H City'] = ''
            house_num = False #finds starting of house nmber
            for item in address[0]['value'].split():
                if(item.isdigit()):
                    house_num = True
                    break
            if(house_num):
                cd['H House Number'] = item
        #city
                city = has_city(cities, address[0]['value'])
                if(city):
                    cd['H City'] = city
                    cd['H Street Name'] = ' '.join(address_1).replace(city,'').strip() #everythign except the city 
                else:
                    cd['H Street Name'] = ' '.join(address_1)
            else: #everything goes into city
                cd['H City'] = address_1

        else: #len of address >1, then 2nd add is house. 1st is other address.
            add = ast.literal_eval(entry_dict[str(i)])['locations'][0]['value']
            add_ls = add.split()
            cd['Address 2'] = add
            house_num = False
            if(add_ls[0].isdigit()):
                house_num = True
            if(house_num):
                cd['Address 2 House Number'] = add_ls[0]
            #city
                city = has_city(add)
                if(city):
                    cd['Address 2 City'] = city
                    cd['Address 2 Street Name'] = ' '.join(add_ls).replace(city, '').strip()
                else:
                    cd['Address 2 Street Name'] = ' '.join(add_ls)
            else:
                cd['Address 2 City'] = ' '.join(add_ls)
      
            add_1 =ast.literal_eval(entry_dict[str(i)])['locations'][1]['value']
            add_ls = add_1.split()
            if ('labels' in ast.literal_eval(entry_dict[str(140)])['locations'][1].keys()):
                if('h' in ast.literal_eval(entry_dict[str(140)])['locations'][1]['labels']):
                    cd['H Address'] = add_1
                    cd['H Status-flag'] = 'True'
            else:
                    cd['H Status-flag'] = 'Assume'

            house_num = False
            if(add_ls[0].isdigit()):
                house_num = True
            if(house_num):
                cd['H House Number'] = add_ls[0]
          #city
                city = has_city(add_1)
                if(city):
                    cd['H City'] = city
                    cd['H Street Name'] = ' '.join(add_ls).replace(city, '').strip()
                else:
                    cd['H Street Name'] = ' '.join(add_ls)
            else:
                cd['H City'] = ' '.join(add_ls)

    except:
        print('error in:', i+1)

    final_output[str(i)] = cd
# Out:
# error in: 1557
# error in: 3103
# error in: 3110
# error in: 3111
# error in: 3137
# error in: 3198
# error in: 3537
# error in: 4434
# error in: 5034
# error in: 5987
# error in: 5994
# error in: 7421
# error in: 8347
# error in: 9199
# error in: 10430
# error in: 11849
# error in: 11852
# error in: 11876
# error in: 11907
# error in: 12180
# error in: 12620
# error in: 12671
# error in: 12928
# error in: 12992
# error in: 13009
# error in: 13173
# error in: 13236
# error in: 13279
# error in: 13488
# error in: 13902
# error in: 13982
# error in: 14371
# error in: 14376
# error in: 14845
# error in: 14891
# error in: 14902
# error in: 14910
# error in: 15170
# error in: 15243
# error in: 15412
# error in: 15584
# error in: 15708
# error in: 15932
# error in: 15978
# error in: 16030
# error in: 16067
# error in: 16231
# error in: 16232
# error in: 16233
# error in: 16359
# error in: 16551
# error in: 16641
# error in: 16673
# error in: 16840
# error in: 16949
# error in: 16970
# error in: 16976
# error in: 17008
# error in: 17036
# error in: 17164
# error in: 17294
# error in: 17663
# error in: 17665
# error in: 18311
# error in: 18412
# error in: 18442
# error in: 18444
# error in: 18467
# error in: 18479
# error in: 18484
# error in: 18650
# error in: 18707
# error in: 18940
# error in: 19010
# error in: 19157
# error in: 19172
# error in: 19179
# error in: 19181
# error in: 19213
# error in: 19214
# error in: 19291
# error in: 19313
# error in: 19535
# error in: 19614
# error in: 19763
# error in: 19764
# error in: 19793
# error in: 19949
# error in: 19968
# error in: 19993
# error in: 20017
# error in: 20082
# error in: 20097
# error in: 20117
# error in: 20144
# error in: 20442
# error in: 20453
# error in: 20467
# error in: 20617
# error in: 20761
# error in: 20994
# error in: 21135
# error in: 21188
# error in: 21266
# error in: 21283
# error in: 21327
# error in: 21400
# error in: 21469
# error in: 21573
# error in: 21621
# error in: 21673
# error in: 21711
# error in: 21726
# error in: 21773
# error in: 22186
# error in: 22519
# error in: 22580
# error in: 22836
# error in: 22920
# error in: 23018
# error in: 23034
# error in: 23041
# error in: 23055
# error in: 23129
# error in: 23252
# error in: 23361
# error in: 23366
# error in: 23434
# error in: 23693
# error in: 23698
# error in: 23731
# error in: 24119
# error in: 24297
# error in: 24392
# error in: 24782
# error in: 25204
# error in: 25242
# error in: 25251
# error in: 25280
# error in: 25314
# error in: 25330
# error in: 25414
# error in: 25427
# error in: 25470
# error in: 25496
# error in: 25544
# error in: 25547
# error in: 25550
# error in: 25764
# error in: 25781
# error in: 25803
# error in: 25884
# error in: 25916
# error in: 25957
# error in: 26120
# error in: 26182
# error in: 26206
# error in: 26252
# error in: 26261
# error in: 26262
# error in: 26511
# error in: 26793
# error in: 26905
# error in: 26932
# error in: 26933
# error in: 26946
# error in: 26956
# error in: 27061
# error in: 27443
# error in: 27508
# error in: 27516
# error in: 27629
# error in: 27804
# error in: 27925
# error in: 28044
# error in: 28377
# error in: 28591
# error in: 28797
# error in: 28879
# error in: 29005
# error in: 29037
# error in: 29093
# error in: 29124
# error in: 29130
# error in: 29132
# error in: 29139
# error in: 29158
# error in: 29218
# error in: 29509
# error in: 29717
# error in: 29719
# error in: 30088
# error in: 30258
# error in: 30570
# error in: 30699
# error in: 30798
# error in: 30817
# error in: 30860
# error in: 30867
# error in: 30968
# error in: 30973
# error in: 30999
# error in: 31050
# error in: 31104
# error in: 31108
# error in: 31202
# error in: 31490
# error in: 31593
# error in: 31638
# error in: 31718
# error in: 31724
# error in: 31739
# error in: 31770
# error in: 31923
# error in: 31936
# error in: 32004
# error in: 32185
# error in: 32191
# error in: 32195
# error in: 32207
# error in: 32208
# error in: 32244
# error in: 32250
# error in: 32701
# error in: 32759
# error in: 32774
# error in: 32835
# error in: 33187
# error in: 33276
# error in: 33349
# error in: 33738
# error in: 33899
# error in: 33922
# error in: 34059
# error in: 34279
# error in: 34302
# error in: 34408
# error in: 34427
# error in: 34497
# error in: 34611
# error in: 34659
# error in: 34989
# error in: 34999
# error in: 35052
# error in: 35160
# error in: 35300
# error in: 35301
# error in: 35355
# error in: 35358
# error in: 35467
# error in: 35742
# error in: 35784
# error in: 36311
# error in: 36743
# error in: 36745
# error in: 36751
# error in: 36809
# error in: 36899
# error in: 37045
# error in: 37046
# error in: 37249
# error in: 37432
# error in: 37576
# error in: 37661
# error in: 37663
# error in: 37682
# error in: 37683
# error in: 37735
# error in: 37840
# error in: 38276
# error in: 38576
# error in: 38583
# error in: 38609
# error in: 38697
# error in: 39345
# error in: 39383
# error in: 39437
# error in: 39596
# error in: 39690
# error in: 40079
# error in: 40089
# error in: 40177
# error in: 40184
# error in: 40198
# error in: 40323
# error in: 40442
# error in: 41334
# error in: 41517
# error in: 41777
# error in: 41884
# error in: 41921
# error in: 42007
# error in: 42153
# error in: 42859
# error in: 42892
# error in: 42900
# error in: 43130
# error in: 43274
# error in: 43355
# error in: 43434
# error in: 43471
# error in: 44488
# error in: 44491
# error in: 44515
# error in: 44546
# error in: 44819
# error in: 45259
# error in: 45310
# error in: 45567
# error in: 45631
# error in: 45648
# error in: 45812
# error in: 45875
# error in: 45918
# error in: 46127
# error in: 46541
# error in: 46621
# error in: 47010
# error in: 47015
# error in: 47484
# error in: 47530
# error in: 47541
# error in: 47549
# error in: 47809
# error in: 47882
# error in: 48051
# error in: 48223
# error in: 48347
# error in: 48571
# error in: 48617
# error in: 48669
# error in: 48706
# error in: 48870
# error in: 48871
# error in: 48872
# error in: 48998
# error in: 49190
# error in: 49280
# error in: 49312
# error in: 49479
# error in: 49588
# error in: 49609
# error in: 49615
# error in: 49647
# error in: 49675
# error in: 49803
# error in: 49933
# error in: 50302
# error in: 50304
# error in: 50950
# error in: 51051
# error in: 51081
# error in: 51083
# error in: 51106
# error in: 51118
# error in: 51123
# error in: 51289
# error in: 51346
# error in: 51579
# error in: 51649
# error in: 51796
# error in: 51811
# error in: 51818
# error in: 51820
# error in: 51852
# error in: 51853
# error in: 51930
# error in: 51952
# error in: 52174
# error in: 52253
# error in: 52402
# error in: 52403
# error in: 52432
# error in: 52588
# error in: 52607
# error in: 52632
# error in: 52656
# error in: 52721
# error in: 52736
# error in: 52756
# error in: 52783
# error in: 53081
# error in: 53092
# error in: 53106
# error in: 53256
# error in: 53400
# error in: 53633
# error in: 53774
# error in: 53827
# error in: 53905
# error in: 53922
# error in: 53966
# error in: 54039
# error in: 54108
# error in: 54212
# error in: 54260
# error in: 54312
# error in: 54350
# error in: 54365
# error in: 54412
# error in: 54825
# error in: 55158
# error in: 55219
# error in: 55475
# error in: 55559
# error in: 55657
# error in: 55673
# error in: 55680
# error in: 55694
# error in: 55768
# error in: 55891
# error in: 56000
# error in: 56005
# error in: 56073
# error in: 56332
# error in: 56337
# error in: 56370
# error in: 56758
# error in: 56936
# error in: 57031
# error in: 57421
# error in: 57843
# error in: 57881
# error in: 57890
# error in: 57919
# error in: 57953
# error in: 57969
# error in: 58053
# error in: 58066
# error in: 58109
# error in: 58135
# error in: 58183
# error in: 58186
# error in: 58189
# error in: 58403
# error in: 58420
# error in: 58442
# error in: 58523
# error in: 58555
# error in: 58596
# error in: 58759
# error in: 58821
# error in: 58845
# error in: 58891
# error in: 58900
# error in: 58901
# error in: 59150
# error in: 59432
# error in: 59544
# error in: 59571
# error in: 59572
# error in: 59585
# error in: 59595
# error in: 59700
# error in: 60082
# error in: 60147
# error in: 60155
# error in: 60268
# error in: 60443
# error in: 60564
# error in: 60683
# error in: 61016
# error in: 61230
# error in: 61436
# error in: 61518
# error in: 61644
# error in: 61676
# error in: 61732
# error in: 61763
# error in: 61769
# error in: 61771
# error in: 61778
# error in: 61797
# error in: 61857
# error in: 62148
# error in: 62356
# error in: 62358
# error in: 62727
# error in: 62897
# error in: 63209
# error in: 63338
# error in: 63437
# error in: 63456
# error in: 63499
# error in: 63506
# error in: 63607
# error in: 63612
# error in: 63638
# error in: 63689
# error in: 63743
# error in: 63747
# error in: 63841
# error in: 64129
# error in: 64232
# error in: 64277
# error in: 64357
# error in: 64363
# error in: 64378
# error in: 64409
# error in: 64562
# error in: 64575
# error in: 64643
# error in: 64824
# error in: 64830
# error in: 64834
# error in: 64846
# error in: 64847
# error in: 64883
# error in: 64889
# error in: 65340
# error in: 65398
# error in: 65413
# error in: 65474
# error in: 65826
# error in: 65915
# error in: 65988
# error in: 66377
# error in: 66538
# error in: 66561
# error in: 66698
# error in: 66918
# error in: 66941
# error in: 67047
# error in: 67066
# error in: 67136
# error in: 67250
# error in: 67298
# error in: 67628
# error in: 67638
# error in: 67691
# error in: 67799
# error in: 67939
# error in: 67940
# error in: 67994
# error in: 67997
# error in: 68106
# error in: 68381
# error in: 68423
# error in: 68950
# error in: 69382
# error in: 69384
# error in: 69390
# error in: 69448
# error in: 69538
# error in: 69684
# error in: 69685
# error in: 69888
# error in: 70179
# error in: 70321
# error in: 70492
# error in: 70634
# error in: 70704
# error in: 70875
# error in: 70961
# error in: 71105
# error in: 71471
# error in: 71508
# error in: 71529
# error in: 71550
# error in: 71884
# error in: 71885
# error in: 71894
# error in: 72076
# error in: 72138
# error in: 72152
# error in: 72330
# error in: 72342
# error in: 72344
# error in: 72684
# error in: 72821
# error in: 72832
# error in: 72935
# error in: 72946
# error in: 72998
# error in: 73011
# error in: 73027
# error in: 73036
# error in: 73092
# error in: 73621
# error in: 73793
# error in: 74785
# error in: 75042
# error in: 75081
# error in: 75093
# error in: 75246
# error in: 75404
# error in: 75698
# error in: 75699
# error in: 75701
# error in: 76404
# error in: 76556
# error in: 76566
# error in: 76856
# error in: 77344
# error in: 77345
# error in: 77346
# error in: 77388
# error in: 77649
# error in: 77704
# error in: 78236
# error in: 78410
# error in: 78774
# error in: 78963
# error in: 79028
# error in: 79055
# error in: 79056
# error in: 79073
# error in: 79079
# error in: 79081
# error in: 79104
# error in: 79240
# error in: 79259
# error in: 79308
# error in: 79329
# error in: 79750
# error in: 79768
# error in: 79853
# error in: 79993
# error in: 80039
# error in: 80064
# error in: 80155
# error in: 80223
# error in: 80279
# error in: 80499
# error in: 80512
# error in: 80513
# error in: 80514
# error in: 80515
# error in: 80668
# error in: 80670
# error in: 80679
# error in: 80750
# error in: 80751
# error in: 80763
# error in: 80777
# error in: 80961
# error in: 81012
# error in: 81019
# error in: 81052
# error in: 81089
# error in: 81090
# error in: 81153
# error in: 81210
# error in: 81217
# error in: 81218
# error in: 81219
# error in: 81220
# error in: 81222
# error in: 81224
# error in: 81226
# error in: 81227
# error in: 81228
# error in: 81231
# error in: 81232
# error in: 81233
# error in: 81235
# error in: 81421
# error in: 81750
# error in: 81773
# error in: 81900
# error in: 82101
# error in: 82103
# error in: 82106
# error in: 82182
# error in: 82255
# error in: 82364
# error in: 82472
# error in: 82484
# error in: 82531
# error in: 82540
# error in: 82841
# error in: 82998
# error in: 83000
# error in: 83009
# error in: 83010
# error in: 83012
# error in: 83017
# error in: 83021
# error in: 83028
# error in: 83234
# error in: 83265
# error in: 83268
# error in: 83270
# error in: 83863
# error in: 83888
# error in: 83943
# error in: 83967
# error in: 84209
# error in: 84273
# error in: 84313
# error in: 84414
# error in: 84662
# error in: 84696
# error in: 84697
# error in: 84698
# error in: 85080
# error in: 85081
# error in: 85092
# error in: 85165
# error in: 85191
# error in: 85238
# error in: 85278
# error in: 85281
# error in: 85599
# error in: 85676
# error in: 85782
# error in: 85801
# error in: 85873
# error in: 86155
# error in: 86685
# error in: 86686
# error in: 86742
# error in: 86744
# error in: 86959
# error in: 86986
# error in: 87772
# error in: 87805
# error in: 87806
# error in: 88000
# error in: 88115
# error in: 88233
# error in: 88246
# error in: 88277
# error in: 88343
# error in: 88398
# error in: 88462
# error in: 88493
# error in: 88499
# error in: 88516
# error in: 89151
# error in: 89168
# error in: 89297
# error in: 89316
# error in: 89406
# error in: 89631
# error in: 89734
# error in: 89742
# error in: 89802
# error in: 89843
# error in: 89918
# error in: 89920
# error in: 89932
# error in: 90014
# error in: 90048
# error in: 90289
# error in: 90297
# error in: 90324
# error in: 90416
# error in: 90943
# error in: 91062
# error in: 91145
# error in: 91153
# error in: 91313
# error in: 91377
# error in: 91464
# error in: 91521
# error in: 91775
# error in: 91877
# error in: 91882
# error in: 92060
# error in: 92066
# error in: 92075
# error in: 92076
# error in: 92091
# error in: 92098
# error in: 92102
# error in: 92114
# error in: 92319
# error in: 92383
# error in: 92392
# error in: 92464
# error in: 92470
# error in: 92620
# error in: 92648
# error in: 92650
# error in: 92652
# error in: 92653
# error in: 92656
# error in: 92662
# error in: 92722
# error in: 92743
# error in: 93026
# error in: 93052
# error in: 93092
# error in: 93107
# error in: 93110
# error in: 93113
# error in: 93356
# error in: 93372
# error in: 93504
# error in: 93599
# error in: 93603
# error in: 93740
# error in: 93939
# error in: 93984
# error in: 93986
# error in: 93995
# error in: 94013
# error in: 94031
# error in: 94061
# error in: 94072
# error in: 94217
# error in: 94399
# error in: 94877
# error in: 95045
# error in: 95205
# error in: 95424
# error in: 95881
# error in: 96023
# error in: 96044
# error in: 96227
# error in: 96239
# error in: 96299
# error in: 96401
# error in: 96408
# error in: 96619
# error in: 97402
# error in: 97405
# error in: 97430
# error in: 97469
# error in: 97692
# error in: 97702
# error in: 97849
# error in: 97853
# error in: 97926
# error in: 97935
# error in: 97944
# error in: 97979
# error in: 98012
# error in: 98103
# error in: 98648
# error in: 99058
# error in: 99069
# error in: 99124
# error in: 99183
# error in: 99326
# error in: 99360
# error in: 99476
# error in: 99505
# error in: 99528
# error in: 99545
# error in: 99557
# error in: 99610
# error in: 99612
# error in: 99690
# error in: 99909
# error in: 99913
# error in: 99918
# error in: 100088
# error in: 100445
# error in: 100477
# error in: 100751
# error in: 100907
# error in: 100986
# error in: 100990
# error in: 101116
# error in: 101302
# error in: 101441
# error in: 101460
# error in: 101654
# error in: 101688
# error in: 101689
# error in: 101690
# error in: 101704
# error in: 101705
# error in: 101706
# error in: 101707
# error in: 101708
# error in: 101716
# error in: 101761
# error in: 101762
# error in: 101763
# error in: 102225
# error in: 102306
# error in: 102370
# error in: 102402
# error in: 102456
# error in: 102471
# error in: 102692
# error in: 103006
# error in: 103440
# error in: 103573
# error in: 103867
# error in: 103959
# error in: 104267
# error in: 104276
# error in: 104280
# error in: 104362
# error in: 104389
# error in: 104913
# error in: 104914
# error in: 105573
# error in: 105598
# error in: 105655
# error in: 105713
# error in: 105714
# error in: 105921
# error in: 106120
# error in: 106832
# error in: 106878
# error in: 107052
# error in: 107179
# error in: 107399
# error in: 107408
# error in: 107441
# error in: 107494
# error in: 107798
# error in: 108334
# error in: 108486
# error in: 108698
# error in: 108815
# error in: 108940
# error in: 108942
# error in: 108986
# error in: 109067
# error in: 109177
# error in: 109261
# error in: 109356
# error in: 109594
# error in: 109647
# error in: 109650
# error in: 109758
# error in: 109858
# error in: 109883
# error in: 109914
# error in: 109949
# error in: 109955
# error in: 110265
# error in: 110282
# error in: 110284
# error in: 110755
# error in: 111493
# error in: 111645
# error in: 111908
# error in: 112009
# error in: 112306
# error in: 112356
# error in: 112358
# error in: 112392
# error in: 112777
# error in: 112862
# error in: 112893
# error in: 112938
# error in: 113005
# error in: 113225
# error in: 113235
# error in: 113245
# error in: 113248

# %%
final_output
# Out:
# {'1': {'Full Name': 'Ackley Addison',
#   'First Name': 'Addison',
#   'Last Name': 'Ackley',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'clerk',
#   'Full Address': '47 Broadway, h. 39 Pearl',
#   'H Status-flag': 'True',
#   'H Address': '39 Pearl',
#   'H House Number': '39',
#   'H Street Name': '39 Pearl',
#   'H City': '',
#   'Address 2': '47 Broadway',
#   'Address 2 House Number': '47',
#   'Address 2 Street Name': '47 Broadway',
#   'Address 2 City': ''},
#  '2': {'Full Name': 'Adams William',
#   'First Name': 'William',
#   'Last Name': 'Adams',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'weigher',
#   'Full Address': '20 Washington & 13 West, h. 170 Clinton , Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': '170 Clinton , Brooklyn',
#   'H House Number': '170',
#   'H Street Name': '170 Clinton ,',
#   'H City': 'Brooklyn',
#   'Address 2': '20 Washington & 13 West',
#   'Address 2 House Number': '20',
#   'Address 2 Street Name': '20 Washington & 13 West',
#   'Address 2 City': ''},
#  '3': {'Full Name': 'Aitkin Thomas',
#   'First Name': 'Thomas',
#   'Last Name': 'Aitkin',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'stonecutter',
#   'Full Address': '601 Washington',
#   'H Status-flag': 'Assume',
#   'H Address': '601 Washington',
#   'H House Number': '601',
#   'H Street Name': '601 Washington',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '4': {'Full Name': 'Albro Benjamin',
#   'First Name': 'Benjamin',
#   'Last Name': 'Albro',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'sen',
#   'Full Address': '328 Bowery',
#   'H Status-flag': 'Assume',
#   'H Address': '328 Bowery',
#   'H House Number': '328',
#   'H Street Name': '328 Bowery',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '5': {'Full Name': 'Allen E . W',
#   'First Name': 'E',
#   'Last Name': 'Allen',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'publisher',
#   'Full Address': '42 Orange',
#   'H Status-flag': 'Assume',
#   'H Address': '42 Orange',
#   'H House Number': '42',
#   'H Street Name': '42 Orange',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '6': {'Full Name': 'Anderson Frederick R',
#   'First Name': 'Frederick',
#   'Last Name': 'Anderson',
#   'Middle Name': 'R',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '13 Front, h. 77 Barrow',
#   'H Status-flag': 'True',
#   'H Address': '77 Barrow',
#   'H House Number': '77',
#   'H Street Name': '77 Barrow',
#   'H City': '',
#   'Address 2': '13 Front',
#   'Address 2 House Number': '13',
#   'Address 2 Street Name': '13 Front',
#   'Address 2 City': ''},
#  '7': {'Full Name': 'Anderson John R',
#   'First Name': 'John',
#   'Last Name': 'Anderson',
#   'Middle Name': 'R',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'seaman',
#   'Full Address': '586 E , 4th',
#   'H Status-flag': 'Assume',
#   'H Address': '586 E , 4th',
#   'H House Number': '586',
#   'H Street Name': '586 E , 4th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '8': {'Full Name': 'Anthes Peter',
#   'First Name': 'Peter',
#   'Last Name': 'Anthes',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '34 Av . C',
#   'H Status-flag': '',
#   'H Address': '34 Av . C',
#   'H House Number': '34',
#   'H Street Name': '34 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '9': {'Full Name': 'Anthes & Eckardt',
#   'First Name': '&',
#   'Last Name': 'Anthes',
#   'Middle Name': 'Eckardt',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'barbers',
#   'Full Address': '34 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '34 Av . C',
#   'H House Number': '34',
#   'H Street Name': '34 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '10': {'Full Name': 'Appell John',
#   'First Name': 'John',
#   'Last Name': 'Appell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '40 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '40 Av . C',
#   'H House Number': '40',
#   'H Street Name': '40 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '11': {'Full Name': 'Arcularius Jacob S',
#   'First Name': 'Jacob',
#   'Last Name': 'Arcularius',
#   'Middle Name': 'S',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': 'h. 175 Canal',
#   'H Status-flag': 'True',
#   'H Address': '175 Canal',
#   'H House Number': '175',
#   'H Street Name': '175 Canal',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '12': {'Full Name': 'Arenfred George',
#   'First Name': 'George',
#   'Last Name': 'Arenfred',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '137 Norfolk',
#   'H Status-flag': 'Assume',
#   'H Address': '137 Norfolk',
#   'H House Number': '137',
#   'H Street Name': '137 Norfolk',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '13': {'Full Name': 'Armstrong George',
#   'First Name': 'George',
#   'Last Name': 'Armstrong',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shoemaker',
#   'Full Address': '53 Av . D',
#   'H Status-flag': 'Assume',
#   'H Address': '53 Av . D',
#   'H House Number': '53',
#   'H Street Name': '53 Av . D',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '14': {'Full Name': 'Armstrong John D',
#   'First Name': 'John',
#   'Last Name': 'Armstrong',
#   'Middle Name': 'D',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'coachmaker',
#   'Full Address': '5 Ludlow',
#   'H Status-flag': 'Assume',
#   'H Address': '5 Ludlow',
#   'H House Number': '5',
#   'H Street Name': '5 Ludlow',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '15': {'Full Name': 'Arnold Henry',
#   'First Name': 'Henry',
#   'Last Name': 'Arnold',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'drygoods',
#   'Full Address': '1 Av . D, h. 1 Av . D',
#   'H Status-flag': 'True',
#   'H Address': '1 Av . D',
#   'H House Number': '1',
#   'H Street Name': '1 Av . D',
#   'H City': '',
#   'Address 2': '1 Av . D',
#   'Address 2 House Number': '1',
#   'Address 2 Street Name': '1 Av . D',
#   'Address 2 City': ''},
#  '16': {'Full Name': 'Ash William A',
#   'First Name': 'William',
#   'Last Name': 'Ash',
#   'Middle Name': 'A',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'way',
#   'Full Address': '413 B, h. Morrisania',
#   'H Status-flag': 'True',
#   'H Address': 'Morrisania',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Morrisania',
#   'Address 2': '413 B',
#   'Address 2 House Number': '413',
#   'Address 2 Street Name': '413 B',
#   'Address 2 City': ''},
#  '17': {'Full Name': 'Auchincloss John T',
#   'First Name': 'John',
#   'Last Name': 'Auchincloss',
#   'Middle Name': 'T',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '192 Fulton, h. 7 Murray',
#   'H Status-flag': 'True',
#   'H Address': '7 Murray',
#   'H House Number': '7',
#   'H Street Name': '7 Murray',
#   'H City': '',
#   'Address 2': '192 Fulton',
#   'Address 2 House Number': '192',
#   'Address 2 Street Name': '192 Fulton',
#   'Address 2 City': ''},
#  '18': {'Full Name': 'Auchincloss & Croxon',
#   'First Name': '&',
#   'Last Name': 'Auchincloss',
#   'Middle Name': 'Croxon',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mers',
#   'Full Address': '192 Fulton',
#   'H Status-flag': 'Assume',
#   'H Address': '192 Fulton',
#   'H House Number': '192',
#   'H Street Name': '192 Fulton',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '19': {'Full Name': 'Bagley William',
#   'First Name': 'William',
#   'Last Name': 'Bagley',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'bank',
#   'Full Address': '50 Wall, h. 91 Henry , Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': '91 Henry , Brooklyn',
#   'H House Number': '91',
#   'H Street Name': '91 Henry ,',
#   'H City': 'Brooklyn',
#   'Address 2': '50 Wall',
#   'Address 2 House Number': '50',
#   'Address 2 Street Name': '50 Wall',
#   'Address 2 City': ''},
#  '20': {'Full Name': 'BAIN ALEXANDER',
#   'First Name': 'ALEXANDER',
#   'Last Name': 'BAIN',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '181 inventor ,',
#   'H Status-flag': '',
#   'H Address': '181 inventor ,',
#   'H House Number': '181',
#   'H Street Name': '181 inventor ,',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '21': {'Full Name': 'Baldwin Ezekiel',
#   'First Name': 'Ezekiel',
#   'Last Name': 'Baldwin',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shoemaker',
#   'Full Address': '79 Av . B',
#   'H Status-flag': 'Assume',
#   'H Address': '79 Av . B',
#   'H House Number': '79',
#   'H Street Name': '79 Av . B',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '22': {'Full Name': 'Ball Isaac',
#   'First Name': 'Isaac',
#   'Last Name': 'Ball',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'pedler',
#   'Full Address': '66 Mangin',
#   'H Status-flag': 'Assume',
#   'H Address': '66 Mangin',
#   'H House Number': '66',
#   'H Street Name': '66 Mangin',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '23': {'Full Name': 'Bannon Michael',
#   'First Name': 'Michael',
#   'Last Name': 'Bannon',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'cooper',
#   'Full Address': '304 Ninth',
#   'H Status-flag': 'Assume',
#   'H Address': '304 Ninth',
#   'H House Number': '304',
#   'H Street Name': '304 Ninth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '24': {'Full Name': 'Barmore Christopher',
#   'First Name': 'Christopher',
#   'Last Name': 'Barmore',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shoes',
#   'Full Address': 'E . 18th n . Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': 'E . 18th n . Av . A',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['E', '.', '18th', 'n', '.', 'Av', '.', 'A'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '25': {'Full Name': 'Barratt Thomas',
#   'First Name': 'Thomas',
#   'Last Name': 'Barratt',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '605 Fourth',
#   'H Status-flag': 'Assume',
#   'H Address': '605 Fourth',
#   'H House Number': '605',
#   'H Street Name': '605 Fourth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '26': {'Full Name': 'Barrowclough James , E',
#   'First Name': 'James',
#   'Last Name': 'Barrowclough',
#   'Middle Name': ',',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '24th c . Av . 3',
#   'H Status-flag': 'Assume',
#   'H Address': '24th c . Av . 3',
#   'H House Number': '3',
#   'H Street Name': '24th c . Av . 3',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '27': {'Full Name': 'Barry James',
#   'First Name': 'James',
#   'Last Name': 'Barry',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'marblepolisher',
#   'Full Address': '294 Eleventh',
#   'H Status-flag': 'Assume',
#   'H Address': '294 Eleventh',
#   'H House Number': '294',
#   'H Street Name': '294 Eleventh',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '28': {'Full Name': 'Barry John',
#   'First Name': 'John',
#   'Last Name': 'Barry',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': '60 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '60 Av . C',
#   'H House Number': '60',
#   'H Street Name': '60 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '29': {'Full Name': 'Bates John C',
#   'First Name': 'John',
#   'Last Name': 'Bates',
#   'Middle Name': 'C',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'sarsaparilla',
#   'Full Address': '82 Nassau, h. Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': 'Brooklyn',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Brooklyn',
#   'Address 2': '82 Nassau',
#   'Address 2 House Number': '82',
#   'Address 2 Street Name': '82 Nassau',
#   'Address 2 City': ''},
#  '30': {'Full Name': 'Beach John T',
#   'First Name': 'John',
#   'Last Name': 'Beach',
#   'Middle Name': 'T',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'paper',
#   'Full Address': '43 Fulton, h. 22 Vesey',
#   'H Status-flag': 'True',
#   'H Address': '22 Vesey',
#   'H House Number': '22',
#   'H Street Name': '22 Vesey',
#   'H City': '',
#   'Address 2': '43 Fulton',
#   'Address 2 House Number': '43',
#   'Address 2 Street Name': '43 Fulton',
#   'Address 2 City': ''},
#  '31': {'Full Name': 'Bear Isaac',
#   'First Name': 'Isaac',
#   'Last Name': 'Bear',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'drygoods',
#   'Full Address': '105 Av . D, h. 105 Av . D',
#   'H Status-flag': 'True',
#   'H Address': '105 Av . D',
#   'H House Number': '105',
#   'H Street Name': '105 Av . D',
#   'H City': '',
#   'Address 2': '105 Av . D',
#   'Address 2 House Number': '105',
#   'Address 2 Street Name': '105 Av . D',
#   'Address 2 City': ''},
#  '32': {'Full Name': 'Beard William',
#   'First Name': 'William',
#   'Last Name': 'Beard',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': '89 E . 11th',
#   'H Status-flag': 'Assume',
#   'H Address': '89 E . 11th',
#   'H House Number': '89',
#   'H Street Name': '89 E . 11th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '33': {'Full Name': 'Becom John J',
#   'First Name': 'John',
#   'Last Name': 'Becom',
#   'Middle Name': 'J',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'sawyer',
#   'Full Address': 'Av . C n . Eleventh',
#   'H Status-flag': 'Assume',
#   'H Address': 'Av . C n . Eleventh',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['Av', '.', 'C', 'n', '.', 'Eleventh'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '34': {'Full Name': 'Beebe Joseph D',
#   'First Name': 'Joseph',
#   'Last Name': 'Beebe',
#   'Middle Name': 'D',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'rigger',
#   'Full Address': '350 Tenth',
#   'H Status-flag': 'Assume',
#   'H Address': '350 Tenth',
#   'H House Number': '350',
#   'H Street Name': '350 Tenth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '35': {'Full Name': 'Beebe & Co',
#   'First Name': '&',
#   'Last Name': 'Beebe',
#   'Middle Name': 'Co',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'builders',
#   'Full Address': 'W . 24th n . Ay . 10',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 24th n . Ay . 10',
#   'H House Number': '10',
#   'H Street Name': 'W . 24th n . Ay . 10',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '36': {'Full Name': 'Beers William P',
#   'First Name': 'William',
#   'Last Name': 'Beers',
#   'Middle Name': 'P',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'butcher',
#   'Full Address': '69 Orange, h. 77 Third',
#   'H Status-flag': 'True',
#   'H Address': '77 Third',
#   'H House Number': '77',
#   'H Street Name': '77 Third',
#   'H City': '',
#   'Address 2': '69 Orange',
#   'Address 2 House Number': '69',
#   'Address 2 Street Name': '69 Orange',
#   'Address 2 City': ''},
#  '37': {'Full Name': 'Bender George W',
#   'First Name': 'George',
#   'Last Name': 'Bender',
#   'Middle Name': 'W',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '27 Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': '27 Av . A',
#   'H House Number': '27',
#   'H Street Name': '27 Av . A',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '38': {'Full Name': 'Benneit Cornelius',
#   'First Name': 'Cornelius',
#   'Last Name': 'Benneit',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '400 Tenth',
#   'H Status-flag': 'Assume',
#   'H Address': '400 Tenth',
#   'H House Number': '400',
#   'H Street Name': '400 Tenth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '39': {'Full Name': 'Bennett George',
#   'First Name': 'George',
#   'Last Name': 'Bennett',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shoemaker',
#   'Full Address': '131 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '131 Av . C',
#   'H House Number': '131',
#   'H Street Name': '131 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '40': {'Full Name': 'Bennett William',
#   'First Name': 'William',
#   'Last Name': 'Bennett',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '245 E . 13th',
#   'H Status-flag': 'Assume',
#   'H Address': '245 E . 13th',
#   'H House Number': '245',
#   'H Street Name': '245 E . 13th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '41': {'Full Name': 'Bernhard Gustavus',
#   'First Name': 'Gustavus',
#   'Last Name': 'Bernhard',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'teacher',
#   'Full Address': '18 Av , C',
#   'H Status-flag': 'Assume',
#   'H Address': '18 Av , C',
#   'H House Number': '18',
#   'H Street Name': '18 Av , C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '42': {'Full Name': 'Bernz John',
#   'First Name': 'John',
#   'Last Name': 'Bernz',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '306 Av . 1',
#   'H Status-flag': 'Assume',
#   'H Address': '306 Av . 1',
#   'H House Number': '306',
#   'H Street Name': '306 Av . 1',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '43': {'Full Name': 'Berrian Burr',
#   'First Name': 'Burr',
#   'Last Name': 'Berrian',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'fish',
#   'Full Address': '89 Pitt',
#   'H Status-flag': 'Assume',
#   'H Address': '89 Pitt',
#   'H House Number': '89',
#   'H Street Name': '89 Pitt',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '44': {'Full Name': 'Bird George L',
#   'First Name': 'George',
#   'Last Name': 'Bird',
#   'Middle Name': 'L',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'clerk',
#   'Full Address': '45 Norfolk',
#   'H Status-flag': 'Assume',
#   'H Address': '45 Norfolk',
#   'H House Number': '45',
#   'H Street Name': '45 Norfolk',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '45': {'Full Name': 'Bill Hannah',
#   'First Name': 'Hannah',
#   'Last Name': 'Bill',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailoress',
#   'Full Address': '46 Amos',
#   'H Status-flag': 'Assume',
#   'H Address': '46 Amos',
#   'H House Number': '46',
#   'H Street Name': '46 Amos',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '46': {'Full Name': 'Birmingham David',
#   'First Name': 'David',
#   'Last Name': 'Birmingham',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'police',
#   'Full Address': 'W . 26th n . Av . 7',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 26th n . Av . 7',
#   'H House Number': '7',
#   'H Street Name': 'W . 26th n . Av . 7',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '47': {'Full Name': 'Boole Thomas B',
#   'First Name': 'Thomas',
#   'Last Name': 'Boole',
#   'Middle Name': 'B',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '107 Av . B',
#   'H Status-flag': 'Assume',
#   'H Address': '107 Av . B',
#   'H House Number': '107',
#   'H Street Name': '107 Av . B',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '48': {'Full Name': 'Borman Eckhard',
#   'First Name': 'Eckhard',
#   'Last Name': 'Borman',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '5 Av . B',
#   'H Status-flag': 'Assume',
#   'H Address': '5 Av . B',
#   'H House Number': '5',
#   'H Street Name': '5 Av . B',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '49': {'Full Name': 'Bott John',
#   'First Name': 'John',
#   'Last Name': 'Bott',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '299 Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': '299 Av . A',
#   'H House Number': '299',
#   'H Street Name': '299 Av . A',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '50': {'Full Name': 'Botz Louis',
#   'First Name': 'Louis',
#   'Last Name': 'Botz',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'pedler',
#   'Full Address': '48 Av . 1',
#   'H Status-flag': 'Assume',
#   'H Address': '48 Av . 1',
#   'H House Number': '48',
#   'H Street Name': '48 Av . 1',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '51': {'Full Name': 'Bouton Gilbert',
#   'First Name': 'Gilbert',
#   'Last Name': 'Bouton',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '51 Norfolk',
#   'H Status-flag': 'Assume',
#   'H Address': '51 Norfolk',
#   'H House Number': '51',
#   'H Street Name': '51 Norfolk',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '52': {'Full Name': 'Bowen John',
#   'First Name': 'John',
#   'Last Name': 'Bowen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'plumber',
#   'Full Address': '268 EF . 13th',
#   'H Status-flag': 'Assume',
#   'H Address': '268 EF . 13th',
#   'H House Number': '268',
#   'H Street Name': '268 EF . 13th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '53': {'Full Name': 'Boyd John jr',
#   'First Name': 'John',
#   'Last Name': 'Boyd',
#   'Middle Name': 'jr',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '149 & 151 Front, h. 92 Madison',
#   'H Status-flag': 'True',
#   'H Address': '92 Madison',
#   'H House Number': '92',
#   'H Street Name': '92 Madison',
#   'H City': '',
#   'Address 2': '149 & 151 Front',
#   'Address 2 House Number': '149',
#   'Address 2 Street Name': '149 & 151 Front',
#   'Address 2 City': ''},
#  '54': {'Full Name': 'Boyle John',
#   'First Name': 'John',
#   'Last Name': 'Boyle',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'liquors',
#   'Full Address': 'W . 25th n . Av . 10',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 25th n . Av . 10',
#   'H House Number': '10',
#   'H Street Name': 'W . 25th n . Av . 10',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '55': {'Full Name': 'Boynton Ray',
#   'First Name': 'Ray',
#   'Last Name': 'Boynton',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '51 Exch, h. 31 W . 15th',
#   'H Status-flag': 'True',
#   'H Address': '31 W . 15th',
#   'H House Number': '31',
#   'H Street Name': '31 W . 15th',
#   'H City': '',
#   'Address 2': '51 Exch',
#   'Address 2 House Number': '51',
#   'Address 2 Street Name': '51 Exch',
#   'Address 2 City': ''},
#  '56': {'Full Name': 'Brady John',
#   'First Name': 'John',
#   'Last Name': 'Brady',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'school',
#   'Full Address': '219 E . 13th, h. 217 E , 13th',
#   'H Status-flag': 'True',
#   'H Address': '217 E , 13th',
#   'H House Number': '217',
#   'H Street Name': '217 E , 13th',
#   'H City': '',
#   'Address 2': '219 E . 13th',
#   'Address 2 House Number': '219',
#   'Address 2 Street Name': '219 E . 13th',
#   'Address 2 City': ''},
#  '57': {'Full Name': 'Bramley Patrick',
#   'First Name': 'Patrick',
#   'Last Name': 'Bramley',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'boilermaker',
#   'Full Address': '319 Ninth',
#   'H Status-flag': 'Assume',
#   'H Address': '319 Ninth',
#   'H House Number': '319',
#   'H Street Name': '319 Ninth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '58': {'Full Name': 'Bramwell Joseph',
#   'First Name': 'Joseph',
#   'Last Name': 'Bramwell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': 'h. 101 Henry , Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': '101 Henry , Brooklyn',
#   'H House Number': '101',
#   'H Street Name': '101 Henry , Brooklyn',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '59': {'Full Name': 'Brant Theophilus',
#   'First Name': 'Theophilus',
#   'Last Name': 'Brant',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shipjoiner',
#   'Full Address': 'Ay . D c . Fourth',
#   'H Status-flag': 'Assume',
#   'H Address': 'Ay . D c . Fourth',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['Ay', '.', 'D', 'c', '.', 'Fourth'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '60': {'Full Name': 'Breasted John',
#   'First Name': 'John',
#   'Last Name': 'Breasted',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'allaire works',
#   'Full Address': '464 Cherry',
#   'H Status-flag': 'Assume',
#   'H Address': '464 Cherry',
#   'H House Number': '464',
#   'H Street Name': '464 Cherry',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '61': {'Full Name': 'Brennan Joseph',
#   'First Name': 'Joseph',
#   'Last Name': 'Brennan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mason',
#   'Full Address': '312 Av . 1',
#   'H Status-flag': 'Assume',
#   'H Address': '312 Av . 1',
#   'H House Number': '312',
#   'H Street Name': '312 Av . 1',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '62': {'Full Name': 'Brennen James H',
#   'First Name': 'James',
#   'Last Name': 'Brennen',
#   'Middle Name': 'H',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'hatter',
#   'Full Address': '7 Av . D, h. 7 Av . D',
#   'H Status-flag': 'True',
#   'H Address': '7 Av . D',
#   'H House Number': '7',
#   'H Street Name': '7 Av . D',
#   'H City': '',
#   'Address 2': '7 Av . D',
#   'Address 2 House Number': '7',
#   'Address 2 Street Name': '7 Av . D',
#   'Address 2 City': ''},
#  '63': {'Full Name': 'Breuninger Henry',
#   'First Name': 'Henry',
#   'Last Name': 'Breuninger',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailot',
#   'Full Address': '25 Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': '25 Av . A',
#   'H House Number': '25',
#   'H Street Name': '25 Av . A',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '64': {'Full Name': 'Brice Henry',
#   'First Name': 'Henry',
#   'Last Name': 'Brice',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'silkweaver',
#   'Full Address': '143 W . 28th',
#   'H Status-flag': 'Assume',
#   'H Address': '143 W . 28th',
#   'H House Number': '143',
#   'H Street Name': '143 W . 28th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '65': {'Full Name': 'Brincker William',
#   'First Name': 'William',
#   'Last Name': 'Brincker',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': 'Third n . Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': 'Third n . Av . A',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['Third', 'n', '.', 'Av', '.', 'A'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '66': {'Full Name': 'Brodhead John R',
#   'First Name': 'John',
#   'Last Name': 'Brodhead',
#   'Middle Name': 'R',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '32 Bond',
#   'H Status-flag': 'Assume',
#   'H Address': '32 Bond',
#   'H House Number': '32',
#   'H Street Name': '32 Bond',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '67': {'Full Name': 'Brooks Brothers',
#   'First Name': 'Brothers',
#   'Last Name': 'Brooks',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'clothing',
#   'Full Address': '116 & 118 Cherry',
#   'H Status-flag': 'Assume',
#   'H Address': '116 & 118 Cherry',
#   'H House Number': '116',
#   'H Street Name': '116 & 118 Cherry',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '68': {'Full Name': 'Brouard Peter',
#   'First Name': 'Peter',
#   'Last Name': 'Brouard',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '83 Leonard, h. 143 Reade',
#   'H Status-flag': 'True',
#   'H Address': '143 Reade',
#   'H House Number': '143',
#   'H Street Name': '143 Reade',
#   'H City': '',
#   'Address 2': '83 Leonard',
#   'Address 2 House Number': '83',
#   'Address 2 Street Name': '83 Leonard',
#   'Address 2 City': ''},
#  '69': {'Full Name': 'Brough William',
#   'First Name': 'William',
#   'Last Name': 'Brough',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '117 Fulton, h. 4 Beach ,',
#   'H Status-flag': 'True',
#   'H Address': '4 Beach ,',
#   'H House Number': '4',
#   'H Street Name': '4 Beach ,',
#   'H City': '',
#   'Address 2': '117 Fulton',
#   'Address 2 House Number': '117',
#   'Address 2 Street Name': '117 Fulton',
#   'Address 2 City': ''},
#  '70': {'Full Name': 'Brouner Joseph P',
#   'First Name': 'Joseph',
#   'Last Name': 'Brouner',
#   'Middle Name': 'P',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'drygoods',
#   'Full Address': '707 Greenwich, h. 529 Hudson',
#   'H Status-flag': 'True',
#   'H Address': '529 Hudson',
#   'H House Number': '529',
#   'H Street Name': '529 Hudson',
#   'H City': '',
#   'Address 2': '707 Greenwich',
#   'Address 2 House Number': '707',
#   'Address 2 Street Name': '707 Greenwich',
#   'Address 2 City': ''},
#  '71': {'Full Name': 'Brouwer Saml',
#   'First Name': 'Saml',
#   'Last Name': 'Brouwer',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'crockery',
#   'Full Address': '72 Vesey, h. 173 Wooster',
#   'H Status-flag': 'True',
#   'H Address': '173 Wooster',
#   'H House Number': '173',
#   'H Street Name': '173 Wooster',
#   'H City': '',
#   'Address 2': '72 Vesey',
#   'Address 2 House Number': '72',
#   'Address 2 Street Name': '72 Vesey',
#   'Address 2 City': ''},
#  '72': {'Full Name': 'Brown Charles P',
#   'First Name': 'Charles',
#   'Last Name': 'Brown',
#   'Middle Name': 'P',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '290 West, h. 95 W . 13th',
#   'H Status-flag': 'True',
#   'H Address': '95 W . 13th',
#   'H House Number': '95',
#   'H Street Name': '95 W . 13th',
#   'H City': '',
#   'Address 2': '290 West',
#   'Address 2 House Number': '290',
#   'Address 2 Street Name': '290 West',
#   'Address 2 City': ''},
#  '73': {'Full Name': 'Brown Robert',
#   'First Name': 'Robert',
#   'Last Name': 'Brown',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'physician',
#   'Full Address': '174 Chambers',
#   'H Status-flag': 'Assume',
#   'H Address': '174 Chambers',
#   'H House Number': '174',
#   'H Street Name': '174 Chambers',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '74': {'Full Name': 'Brown Thomas H',
#   'First Name': 'Thomas',
#   'Last Name': 'Brown',
#   'Middle Name': 'H',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'hosiery',
#   'Full Address': '34 Liberty',
#   'H Status-flag': 'Assume',
#   'H Address': '34 Liberty',
#   'H House Number': '34',
#   'H Street Name': '34 Liberty',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '75': {'Full Name': 'Brown & Englis',
#   'First Name': '&',
#   'Last Name': 'Brown',
#   'Middle Name': 'Englis',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shipwrights',
#   'Full Address': 'Twelfth c . Dry Dock',
#   'H Status-flag': 'Assume',
#   'H Address': 'Twelfth c . Dry Dock',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['Twelfth', 'c', '.', 'Dry', 'Dock'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '76': {'Full Name': 'Brownrse Jolin Â§8',
#   'First Name': 'Jolin',
#   'Last Name': 'Brownrse',
#   'Middle Name': 'Â§8',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carver',
#   'Full Address': 'h. 53 Monroe',
#   'H Status-flag': 'True',
#   'H Address': '53 Monroe',
#   'H House Number': '53',
#   'H Street Name': '53 Monroe',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '77': {'Full Name': 'Bruggemann Diedrich',
#   'First Name': 'Diedrich',
#   'Last Name': 'Bruggemann',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'grocer',
#   'Full Address': 'h. 72 Lewis',
#   'H Status-flag': 'True',
#   'H Address': '72 Lewis',
#   'H House Number': '72',
#   'H Street Name': '72 Lewis',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '78': {'Full Name': 'Brummell Adonijah',
#   'First Name': 'Adonijah',
#   'Last Name': 'Brummell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'confectioner',
#   'Full Address': 'h. 141 Norfolk',
#   'H Status-flag': 'True',
#   'H Address': '141 Norfolk',
#   'H House Number': '141',
#   'H Street Name': '141 Norfolk',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '79': {'Full Name': 'Budd Thomas S',
#   'First Name': 'Thomas',
#   'Last Name': 'Budd',
#   'Middle Name': 'S',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shipmaster',
#   'Full Address': '166 E . 20th',
#   'H Status-flag': 'Assume',
#   'H Address': '166 E . 20th',
#   'H House Number': '166',
#   'H Street Name': '166 E . 20th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '80': {'Full Name': 'Bunce William C',
#   'First Name': 'William',
#   'Last Name': 'Bunce',
#   'Middle Name': 'C',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '201 Av . 3',
#   'H Status-flag': 'Assume',
#   'H Address': '201 Av . 3',
#   'H House Number': '201',
#   'H Street Name': '201 Av . 3',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '81': {'Full Name': 'Bunzel Gottlieb',
#   'First Name': 'Gottlieb',
#   'Last Name': 'Bunzel',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'whitewasher',
#   'Full Address': '93 Ridge',
#   'H Status-flag': 'Assume',
#   'H Address': '93 Ridge',
#   'H House Number': '93',
#   'H Street Name': '93 Ridge',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '82': {'Full Name': 'Burket James E',
#   'First Name': 'James',
#   'Last Name': 'Burket',
#   'Middle Name': 'E',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'porterhouse',
#   'Full Address': '433 Tenth',
#   'H Status-flag': 'Assume',
#   'H Address': '433 Tenth',
#   'H House Number': '433',
#   'H Street Name': '433 Tenth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '83': {'Full Name': 'Camp Benjamin F',
#   'First Name': 'Benjamin',
#   'Last Name': 'Camp',
#   'Middle Name': 'F',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'builder',
#   'Full Address': '86 Av . 2',
#   'H Status-flag': 'Assume',
#   'H Address': '86 Av . 2',
#   'H House Number': '86',
#   'H Street Name': '86 Av . 2',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '84': {'Full Name': 'Campbell John',
#   'First Name': 'John',
#   'Last Name': 'Campbell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'blacksmith',
#   'Full Address': '180 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '180 Av . C',
#   'H House Number': '180',
#   'H Street Name': '180 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '85': {'Full Name': 'Campbell Peter',
#   'First Name': 'Peter',
#   'Last Name': 'Campbell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'boatman',
#   'Full Address': '128 Charlton',
#   'H Status-flag': 'Assume',
#   'H Address': '128 Charlton',
#   'H House Number': '128',
#   'H Street Name': '128 Charlton',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '86': {'Full Name': 'Campbell William S',
#   'First Name': 'William',
#   'Last Name': 'Campbell',
#   'Middle Name': 'S',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'printer',
#   'Full Address': '180 Grand',
#   'H Status-flag': 'Assume',
#   'H Address': '180 Grand',
#   'H House Number': '180',
#   'H Street Name': '180 Grand',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '87': {'Full Name': 'Campbell & Moody',
#   'First Name': '&',
#   'Last Name': 'Campbell',
#   'Middle Name': 'Moody',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'steam saw mill , foot 36th',
#   'Full Address': '7 Broad, .',
#   'H Status-flag': 'True',
#   'H Address': '.',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': '.',
#   'Address 2': '7 Broad',
#   'Address 2 House Number': '7',
#   'Address 2 Street Name': '7 Broad',
#   'Address 2 City': ''},
#  '88': {'Full Name': 'Cunham Wm',
#   'First Name': 'Wm',
#   'Last Name': 'Cunham',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carputer',
#   'Full Address': '16 Clarkson, h. 14 Clarkson',
#   'H Status-flag': 'True',
#   'H Address': '14 Clarkson',
#   'H House Number': '14',
#   'H Street Name': '14 Clarkson',
#   'H City': '',
#   'Address 2': '16 Clarkson',
#   'Address 2 House Number': '16',
#   'Address 2 Street Name': '16 Clarkson',
#   'Address 2 City': ''},
#  '89': {'Full Name': 'Cannon Cornelius',
#   'First Name': 'Cornelius',
#   'Last Name': 'Cannon',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tinner',
#   'Full Address': '176 Wooster, h. 2 Congress',
#   'H Status-flag': 'True',
#   'H Address': '2 Congress',
#   'H House Number': '2',
#   'H Street Name': '2 Congress',
#   'H City': '',
#   'Address 2': '176 Wooster',
#   'Address 2 House Number': '176',
#   'Address 2 Street Name': '176 Wooster',
#   'Address 2 City': ''},
#  '90': {'Full Name': 'Carey Thomas',
#   'First Name': 'Thomas',
#   'Last Name': 'Carey',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': '104 FE . 11th',
#   'H Status-flag': 'Assume',
#   'H Address': '104 FE . 11th',
#   'H House Number': '104',
#   'H Street Name': '104 FE . 11th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '91': {'Full Name': 'Carlisle George',
#   'First Name': 'George',
#   'Last Name': 'Carlisle',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '165 Pearl, h. Cincinnati , O',
#   'H Status-flag': 'True',
#   'H Address': 'Cincinnati , O',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Cincinnati , O',
#   'Address 2': '165 Pearl',
#   'Address 2 House Number': '165',
#   'Address 2 Street Name': '165 Pearl',
#   'Address 2 City': ''},
#  '92': {'Full Name': 'Carlisle & Stedman',
#   'First Name': '&',
#   'Last Name': 'Carlisle',
#   'Middle Name': 'Stedman',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mers',
#   'Full Address': '165 Pearl :',
#   'H Status-flag': 'Assume',
#   'H Address': '165 Pearl :',
#   'H House Number': '165',
#   'H Street Name': '165 Pearl :',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '93': {'Full Name': 'Carrington Z . E',
#   'First Name': 'Z',
#   'Last Name': 'Carrington',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'salesman',
#   'Full Address': '13 William, h. Court n . Degraw , Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': 'Court n . Degraw , Brooklyn',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Court n . Degraw , Brooklyn',
#   'Address 2': '13 William',
#   'Address 2 House Number': '13',
#   'Address 2 Street Name': '13 William',
#   'Address 2 City': ''},
#  '94': {'Full Name': 'Carroll D . J',
#   'First Name': 'D',
#   'Last Name': 'Carroll',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'physician',
#   'Full Address': '400 Broadway :',
#   'H Status-flag': 'Assume',
#   'H Address': '400 Broadway :',
#   'H House Number': '400',
#   'H Street Name': '400 Broadway :',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '95': {'Full Name': 'Case George',
#   'First Name': 'George',
#   'Last Name': 'Case',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'sashmaker',
#   'Full Address': 'W . 25th n . Av . 8 , h . W 2th n . Av . 8',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 25th n . Av . 8 , h . W 2th n . Av . 8',
#   'H House Number': '8',
#   'H Street Name': 'W . 25th n . Av . 8 , h . W 2th n . Av . 8',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '96': {'Full Name': 'Castle Charles H',
#   'First Name': 'Charles',
#   'Last Name': 'Castle',
#   'Middle Name': 'H',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '121 Pearl',
#   'H Status-flag': 'Assume',
#   'H Address': '121 Pearl',
#   'H House Number': '121',
#   'H Street Name': '121 Pearl',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '97': {'Full Name': 'Carlough George',
#   'First Name': 'George',
#   'Last Name': 'Carlough',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '746 Washington',
#   'H Status-flag': 'Assume',
#   'H Address': '746 Washington',
#   'H House Number': '746',
#   'H Street Name': '746 Washington',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '98': {'Full Name': 'Channing William',
#   'First Name': 'William',
#   'Last Name': 'Channing',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'physician',
#   'Full Address': '88 White',
#   'H Status-flag': 'Assume',
#   'H Address': '88 White',
#   'H House Number': '88',
#   'H Street Name': '88 White',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '99': {'Full Name': 'Chapin R . Spencer',
#   'First Name': 'R',
#   'Last Name': 'Chapin',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'physician',
#   'Full Address': '305 Third',
#   'H Status-flag': 'Assume',
#   'H Address': '305 Third',
#   'H House Number': '305',
#   'H Street Name': '305 Third',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '100': {'Full Name': 'Charcin John',
#   'First Name': 'John',
#   'Last Name': 'Charcin',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': 'W . 28th n . Av . 7',
# ...
#   'H Street Name': '22 Morton',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '969': {'Full Name': 'Allaire Robert',
#   'First Name': 'Robert',
#   'Last Name': 'Allaire',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'bookkeeper',
#   'Full Address': '262 Seventh',
#   'H Status-flag': 'Assume',
#   'H Address': '262 Seventh',
#   'H House Number': '262',
#   'H Street Name': '262 Seventh',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '970': {'Full Name': 'Allaire Seaman',
#   'First Name': 'Seaman',
#   'Last Name': 'Allaire',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'butcher',
#   'Full Address': '301 Bleecker, h. 61 Leroy',
#   'H Status-flag': 'True',
#   'H Address': '61 Leroy',
#   'H House Number': '61',
#   'H Street Name': '61 Leroy',
#   'H City': '',
#   'Address 2': '301 Bleecker',
#   'Address 2 House Number': '301',
#   'Address 2 Street Name': '301 Bleecker',
#   'Address 2 City': ''},
#  '971': {'Full Name': 'Allaire Thomas H',
#   'First Name': 'Thomas',
#   'Last Name': 'Allaire',
#   'Middle Name': 'H',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'and custom house',
#   'Full Address': '419 Broadway, 93 Morton',
#   'H Status-flag': 'True',
#   'H Address': '93 Morton',
#   'H House Number': '93',
#   'H Street Name': '93 Morton',
#   'H City': '',
#   'Address 2': '419 Broadway',
#   'Address 2 House Number': '419',
#   'Address 2 Street Name': '419 Broadway',
#   'Address 2 City': ''},
#  '972': {'Full Name': 'Allaire Wilmot D',
#   'First Name': 'Wilmot',
#   'Last Name': 'Allaire',
#   'Middle Name': 'D',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'coppersmith',
#   'Full Address': '44 Broome',
#   'H Status-flag': 'Assume',
#   'H Address': '44 Broome',
#   'H House Number': '44',
#   'H Street Name': '44 Broome',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '973': {'Full Name': 'Allan Alexander',
#   'First Name': 'Alexander',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'jeweller',
#   'Full Address': '111 Division and r . 276 Bowery, h. 149 Wooster . :',
#   'H Status-flag': 'True',
#   'H Address': '149 Wooster . :',
#   'H House Number': '149',
#   'H Street Name': '149 Wooster . :',
#   'H City': '',
#   'Address 2': '111 Division and r . 276 Bowery',
#   'Address 2 House Number': '111',
#   'Address 2 Street Name': '111 Division and r . 276 Bowery',
#   'Address 2 City': ''},
#  '974': {'Full Name': 'Allan Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'engineer',
#   'Full Address': 'h. Av . 9 Â¢ . W . 37th',
#   'H Status-flag': 'True',
#   'H Address': 'Av . 9 Â¢ . W . 37th',
#   'H House Number': '9',
#   'H Street Name': 'Av . 9 Â¢ . W . 37th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '975': {'Full Name': 'Allan George',
#   'First Name': 'George',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '113 Cherry .',
#   'H Status-flag': 'Assume',
#   'H Address': '113 Cherry .',
#   'H House Number': '113',
#   'H Street Name': '113 Cherry .',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '976': {'Full Name': 'Allan John',
#   'First Name': 'John',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '17 Vandewater',
#   'H Status-flag': 'Assume',
#   'H Address': '17 Vandewater',
#   'H House Number': '17',
#   'H Street Name': '17 Vandewater',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '977': {'Full Name': 'Allan Robt',
#   'First Name': 'Robt',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'provisions',
#   'Full Address': '226 Washington, h. 53 Watts',
#   'H Status-flag': 'True',
#   'H Address': '53 Watts',
#   'H House Number': '53',
#   'H Street Name': '53 Watts',
#   'H City': '',
#   'Address 2': '226 Washington',
#   'Address 2 House Number': '226',
#   'Address 2 Street Name': '226 Washington',
#   'Address 2 City': ''},
#  '978': {'Full Name': 'Allan & Rose',
#   'First Name': '&',
#   'Last Name': 'Allan',
#   'Middle Name': 'Rose',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': "butter'and provisions",
#   'Full Address': '226 Washgtn',
#   'H Status-flag': 'Assume',
#   'H Address': '226 Washgtn',
#   'H House Number': '226',
#   'H Street Name': '226 Washgtn',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '979': {'Full Name': 'Allard Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Allard',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'clerk',
#   'Full Address': 'E , 42d, Av . 3 ,',
#   'H Status-flag': 'True',
#   'H Address': 'Av . 3 ,',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Av . 3 ,',
#   'Address 2': 'E , 42d',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': 'E , 42d'},
#  '980': {'Full Name': 'Allard Nahun W',
#   'First Name': 'Nahun',
#   'Last Name': 'Allard',
#   'Middle Name': 'W',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'butcher',
#   'Full Address': '154 Varick, h. 152 Varick',
#   'H Status-flag': 'True',
#   'H Address': '152 Varick',
#   'H House Number': '152',
#   'H Street Name': '152 Varick',
#   'H City': '',
#   'Address 2': '154 Varick',
#   'Address 2 House Number': '154',
#   'Address 2 Street Name': '154 Varick',
#   'Address 2 City': ''},
#  '981': {'Full Name': 'Allari Joseph',
#   'First Name': 'Joseph',
#   'Last Name': 'Allari',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'boarding',
#   'Full Address': '37 Rose',
#   'H Status-flag': 'Assume',
#   'H Address': '37 Rose',
#   'H House Number': '37',
#   'H Street Name': '37 Rose',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '982': {'Full Name': 'Allas Joseph A',
#   'First Name': 'Joseph',
#   'Last Name': 'Allas',
#   'Middle Name': 'A',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '27 Ridge',
#   'H Status-flag': 'Assume',
#   'H Address': '27 Ridge',
#   'H House Number': '27',
#   'H Street Name': '27 Ridge',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '983': {'Full Name': 'Allason W',
#   'First Name': 'W',
#   'Last Name': 'Allason',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'salesman',
#   'Full Address': "117 Pearl, h. Wyck'ff , Brklyn",
#   'H Status-flag': 'True',
#   'H Address': "Wyck'ff , Brklyn",
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': "Wyck'ff , Brklyn",
#   'Address 2': '117 Pearl',
#   'Address 2 House Number': '117',
#   'Address 2 Street Name': '117 Pearl',
#   'Address 2 City': ''},
#  '984': {'Full Name': 'Allason Frances',
#   'First Name': 'Frances',
#   'Last Name': 'Allason',
#   'Middle Name': '',
#   'Widow-flag': 'True',
#   'Widow Of': 'Allason',
#   'Title': '',
#   'Occupation': 'boarding',
#   'Full Address': '70 G . wich',
#   'H Status-flag': 'Assume',
#   'H Address': '70 G . wich',
#   'H House Number': '70',
#   'H Street Name': '70 G . wich',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '985': {'Full Name': 'Allcock Hugh',
#   'First Name': 'Hugh',
#   'Last Name': 'Allcock',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'way',
#   'Full Address': '341 B, h. 18 White',
#   'H Status-flag': 'True',
#   'H Address': '18 White',
#   'H House Number': '18',
#   'H Street Name': '18 White',
#   'H City': '',
#   'Address 2': '341 B',
#   'Address 2 House Number': '341',
#   'Address 2 Street Name': '341 B',
#   'Address 2 City': ''},
#  '986': {'Full Name': 'Allcock Thomas',
#   'First Name': 'Thomas',
#   'Last Name': 'Allcock',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'chemist',
#   'Full Address': '24 Perry',
#   'H Status-flag': 'Assume',
#   'H Address': '24 Perry',
#   'H House Number': '24',
#   'H Street Name': '24 Perry',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '987': {'Full Name': 'ALLCOCK & ALLEN',
#   'First Name': '&',
#   'Last Name': 'ALLCOCK',
#   'Middle Name': 'ALLEN',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'silverware & furnishing articles',
#   'Full Address': '341 Broadway',
#   'H Status-flag': 'Assume',
#   'H Address': '341 Broadway',
#   'H House Number': '341',
#   'H Street Name': '341 Broadway',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '988': {'Full Name': 'Allegri Joseph',
#   'First Name': 'Joseph',
#   'Last Name': 'Allegri',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'artist',
#   'Full Address': 'h. 131 E . 21st',
#   'H Status-flag': 'True',
#   'H Address': '131 E . 21st',
#   'H House Number': '131',
#   'H Street Name': '131 E . 21st',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '989': {'Full Name': 'Alleh Christopher',
#   'First Name': 'Christopher',
#   'Last Name': 'Alleh',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'soap',
#   'Full Address': 'h. E . 41st n . Av . 1',
#   'H Status-flag': 'True',
#   'H Address': 'E . 41st n . Av . 1',
#   'H House Number': '1',
#   'H Street Name': 'E . 41st n . Av . 1',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '990': {'Full Name': 'Allen A . B',
#   'First Name': 'A',
#   'Last Name': 'Allen',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': 'Co . 189 and 191 Water',
#   'H Status-flag': '',
#   'H Address': 'Co . 189 and 191 Water',
#   'H House Number': '189',
#   'H Street Name': 'Co . 189 and 191 Water',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '991': {'Full Name': 'Allen Abraham',
#   'First Name': 'Abraham',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'porterh',
#   'Full Address': '248 West, h. 44 Hubert',
#   'H Status-flag': 'True',
#   'H Address': '44 Hubert',
#   'H House Number': '44',
#   'H Street Name': '44 Hubert',
#   'H City': '',
#   'Address 2': '248 West',
#   'Address 2 House Number': '248',
#   'Address 2 Street Name': '248 West',
#   'Address 2 City': ''},
#  '992': {'Full Name': 'Allen Abraham',
#   'First Name': 'Abraham',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '46 Hubert',
#   'H Status-flag': 'Assume',
#   'H Address': '46 Hubert',
#   'H House Number': '46',
#   'H Street Name': '46 Hubert',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '993': {'Full Name': 'Allen Abraham & Co',
#   'First Name': 'Abraham',
#   'Last Name': 'Allen',
#   'Middle Name': '&',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'grocers',
#   'Full Address': 'Av . 8 c . W . 29th & 30 Av . 8, h. Av . 8c . W . 29th',
#   'H Status-flag': 'True',
#   'H Address': 'Av . 8c . W . 29th',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Av . 8c . W . 29th',
#   'Address 2': 'Av . 8 c . W . 29th & 30 Av . 8',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': 'Av . 8 c . W . 29th & 30 Av . 8'},
#  '994': {'Full Name': 'Allen Albert G',
#   'First Name': 'Albert',
#   'Last Name': 'Allen',
#   'Middle Name': 'G',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'furnaces',
#   'Full Address': '351 Broadway; h . 44 Sidney pl . Brooklyn',
#   'H Status-flag': 'Assume',
#   'H Address': '351 Broadway; h . 44 Sidney pl . Brooklyn',
#   'H House Number': '351',
#   'H Street Name': '351 Broadway; h . 44 Sidney pl . Brooklyn',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '995': {'Full Name': 'Allen Alexander',
#   'First Name': 'Alexander',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': 'W . 18th n . Av . 6',
#   'H Status-flag': '',
#   'H Address': 'W . 18th n . Av . 6',
#   'H House Number': '6',
#   'H Street Name': 'W . 18th n . Av . 6',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '996': {'Full Name': 'Allen Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'machinist',
#   'Full Address': 'W . 37th n . Av . 9',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 37th n . Av . 9',
#   'H House Number': '9',
#   'H Street Name': 'W . 37th n . Av . 9',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '997': {'Full Name': 'Allen Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'cagemaker',
#   'Full Address': '37 First, h. 267 Av . 3',
#   'H Status-flag': 'True',
#   'H Address': '267 Av . 3',
#   'H House Number': '267',
#   'H Street Name': '267 Av . 3',
#   'H City': '',
#   'Address 2': '37 First',
#   'Address 2 House Number': '37',
#   'Address 2 Street Name': '37 First',
#   'Address 2 City': ''},
#  '998': {'Full Name': 'Alen Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Alen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'police',
#   'Full Address': '564 Grand',
#   'H Status-flag': 'Assume',
#   'H Address': '564 Grand',
#   'H House Number': '564',
#   'H Street Name': '564 Grand',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '999': {'Full Name': 'Allen Andrew J',
#   'First Name': 'Andrew',
#   'Last Name': 'Allen',
#   'Middle Name': 'J',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'costumer',
#   'Full Address': '37 Bowery',
#   'H Status-flag': 'Assume',
#   'H Address': '37 Bowery',
#   'H House Number': '37',
#   'H Street Name': '37 Bowery',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '1000': {'Full Name': 'Allen Andrew J',
#   'First Name': 'Andrew',
#   'Last Name': 'Allen',
#   'Middle Name': 'J',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'cagemaker',
#   'Full Address': '37 First, h. 267 Av . 3',
#   'H Status-flag': 'True',
#   'H Address': '267 Av . 3',
#   'H House Number': '267',
#   'H Street Name': '267 Av . 3',
#   'H City': '',
#   'Address 2': '37 First',
#   'Address 2 House Number': '37',
#   'Address 2 Street Name': '37 First',
#   'Address 2 City': ''},
#  ...}

# %%
len(final_output)
# Out:
# 113606

# %%
len(entry_dict)
# Out:
# 113606

# %%
import pickle
# ...
with open('final_output_mn_1850.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(final_output, f, pickle.HIGHEST_PROTOCOL)

# %%
import pandas as pd

read_dict = pd.read_pickle('final_output_mn_1850.pickle')
read_dict
# Out:
# {'1': {'Full Name': 'Ackley Addison',
#   'First Name': 'Addison',
#   'Last Name': 'Ackley',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'clerk',
#   'Full Address': '47 Broadway, h. 39 Pearl',
#   'H Status-flag': 'True',
#   'H Address': '39 Pearl',
#   'H House Number': '39',
#   'H Street Name': '39 Pearl',
#   'H City': '',
#   'Address 2': '47 Broadway',
#   'Address 2 House Number': '47',
#   'Address 2 Street Name': '47 Broadway',
#   'Address 2 City': ''},
#  '2': {'Full Name': 'Adams William',
#   'First Name': 'William',
#   'Last Name': 'Adams',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'weigher',
#   'Full Address': '20 Washington & 13 West, h. 170 Clinton , Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': '170 Clinton , Brooklyn',
#   'H House Number': '170',
#   'H Street Name': '170 Clinton ,',
#   'H City': 'Brooklyn',
#   'Address 2': '20 Washington & 13 West',
#   'Address 2 House Number': '20',
#   'Address 2 Street Name': '20 Washington & 13 West',
#   'Address 2 City': ''},
#  '3': {'Full Name': 'Aitkin Thomas',
#   'First Name': 'Thomas',
#   'Last Name': 'Aitkin',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'stonecutter',
#   'Full Address': '601 Washington',
#   'H Status-flag': 'Assume',
#   'H Address': '601 Washington',
#   'H House Number': '601',
#   'H Street Name': '601 Washington',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '4': {'Full Name': 'Albro Benjamin',
#   'First Name': 'Benjamin',
#   'Last Name': 'Albro',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'sen',
#   'Full Address': '328 Bowery',
#   'H Status-flag': 'Assume',
#   'H Address': '328 Bowery',
#   'H House Number': '328',
#   'H Street Name': '328 Bowery',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '5': {'Full Name': 'Allen E . W',
#   'First Name': 'E',
#   'Last Name': 'Allen',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'publisher',
#   'Full Address': '42 Orange',
#   'H Status-flag': 'Assume',
#   'H Address': '42 Orange',
#   'H House Number': '42',
#   'H Street Name': '42 Orange',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '6': {'Full Name': 'Anderson Frederick R',
#   'First Name': 'Frederick',
#   'Last Name': 'Anderson',
#   'Middle Name': 'R',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '13 Front, h. 77 Barrow',
#   'H Status-flag': 'True',
#   'H Address': '77 Barrow',
#   'H House Number': '77',
#   'H Street Name': '77 Barrow',
#   'H City': '',
#   'Address 2': '13 Front',
#   'Address 2 House Number': '13',
#   'Address 2 Street Name': '13 Front',
#   'Address 2 City': ''},
#  '7': {'Full Name': 'Anderson John R',
#   'First Name': 'John',
#   'Last Name': 'Anderson',
#   'Middle Name': 'R',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'seaman',
#   'Full Address': '586 E , 4th',
#   'H Status-flag': 'Assume',
#   'H Address': '586 E , 4th',
#   'H House Number': '586',
#   'H Street Name': '586 E , 4th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '8': {'Full Name': 'Anthes Peter',
#   'First Name': 'Peter',
#   'Last Name': 'Anthes',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '34 Av . C',
#   'H Status-flag': '',
#   'H Address': '34 Av . C',
#   'H House Number': '34',
#   'H Street Name': '34 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '9': {'Full Name': 'Anthes & Eckardt',
#   'First Name': '&',
#   'Last Name': 'Anthes',
#   'Middle Name': 'Eckardt',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'barbers',
#   'Full Address': '34 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '34 Av . C',
#   'H House Number': '34',
#   'H Street Name': '34 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '10': {'Full Name': 'Appell John',
#   'First Name': 'John',
#   'Last Name': 'Appell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '40 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '40 Av . C',
#   'H House Number': '40',
#   'H Street Name': '40 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '11': {'Full Name': 'Arcularius Jacob S',
#   'First Name': 'Jacob',
#   'Last Name': 'Arcularius',
#   'Middle Name': 'S',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': 'h. 175 Canal',
#   'H Status-flag': 'True',
#   'H Address': '175 Canal',
#   'H House Number': '175',
#   'H Street Name': '175 Canal',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '12': {'Full Name': 'Arenfred George',
#   'First Name': 'George',
#   'Last Name': 'Arenfred',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '137 Norfolk',
#   'H Status-flag': 'Assume',
#   'H Address': '137 Norfolk',
#   'H House Number': '137',
#   'H Street Name': '137 Norfolk',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '13': {'Full Name': 'Armstrong George',
#   'First Name': 'George',
#   'Last Name': 'Armstrong',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shoemaker',
#   'Full Address': '53 Av . D',
#   'H Status-flag': 'Assume',
#   'H Address': '53 Av . D',
#   'H House Number': '53',
#   'H Street Name': '53 Av . D',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '14': {'Full Name': 'Armstrong John D',
#   'First Name': 'John',
#   'Last Name': 'Armstrong',
#   'Middle Name': 'D',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'coachmaker',
#   'Full Address': '5 Ludlow',
#   'H Status-flag': 'Assume',
#   'H Address': '5 Ludlow',
#   'H House Number': '5',
#   'H Street Name': '5 Ludlow',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '15': {'Full Name': 'Arnold Henry',
#   'First Name': 'Henry',
#   'Last Name': 'Arnold',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'drygoods',
#   'Full Address': '1 Av . D, h. 1 Av . D',
#   'H Status-flag': 'True',
#   'H Address': '1 Av . D',
#   'H House Number': '1',
#   'H Street Name': '1 Av . D',
#   'H City': '',
#   'Address 2': '1 Av . D',
#   'Address 2 House Number': '1',
#   'Address 2 Street Name': '1 Av . D',
#   'Address 2 City': ''},
#  '16': {'Full Name': 'Ash William A',
#   'First Name': 'William',
#   'Last Name': 'Ash',
#   'Middle Name': 'A',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'way',
#   'Full Address': '413 B, h. Morrisania',
#   'H Status-flag': 'True',
#   'H Address': 'Morrisania',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Morrisania',
#   'Address 2': '413 B',
#   'Address 2 House Number': '413',
#   'Address 2 Street Name': '413 B',
#   'Address 2 City': ''},
#  '17': {'Full Name': 'Auchincloss John T',
#   'First Name': 'John',
#   'Last Name': 'Auchincloss',
#   'Middle Name': 'T',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '192 Fulton, h. 7 Murray',
#   'H Status-flag': 'True',
#   'H Address': '7 Murray',
#   'H House Number': '7',
#   'H Street Name': '7 Murray',
#   'H City': '',
#   'Address 2': '192 Fulton',
#   'Address 2 House Number': '192',
#   'Address 2 Street Name': '192 Fulton',
#   'Address 2 City': ''},
#  '18': {'Full Name': 'Auchincloss & Croxon',
#   'First Name': '&',
#   'Last Name': 'Auchincloss',
#   'Middle Name': 'Croxon',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mers',
#   'Full Address': '192 Fulton',
#   'H Status-flag': 'Assume',
#   'H Address': '192 Fulton',
#   'H House Number': '192',
#   'H Street Name': '192 Fulton',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '19': {'Full Name': 'Bagley William',
#   'First Name': 'William',
#   'Last Name': 'Bagley',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'bank',
#   'Full Address': '50 Wall, h. 91 Henry , Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': '91 Henry , Brooklyn',
#   'H House Number': '91',
#   'H Street Name': '91 Henry ,',
#   'H City': 'Brooklyn',
#   'Address 2': '50 Wall',
#   'Address 2 House Number': '50',
#   'Address 2 Street Name': '50 Wall',
#   'Address 2 City': ''},
#  '20': {'Full Name': 'BAIN ALEXANDER',
#   'First Name': 'ALEXANDER',
#   'Last Name': 'BAIN',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '181 inventor ,',
#   'H Status-flag': '',
#   'H Address': '181 inventor ,',
#   'H House Number': '181',
#   'H Street Name': '181 inventor ,',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '21': {'Full Name': 'Baldwin Ezekiel',
#   'First Name': 'Ezekiel',
#   'Last Name': 'Baldwin',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shoemaker',
#   'Full Address': '79 Av . B',
#   'H Status-flag': 'Assume',
#   'H Address': '79 Av . B',
#   'H House Number': '79',
#   'H Street Name': '79 Av . B',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '22': {'Full Name': 'Ball Isaac',
#   'First Name': 'Isaac',
#   'Last Name': 'Ball',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'pedler',
#   'Full Address': '66 Mangin',
#   'H Status-flag': 'Assume',
#   'H Address': '66 Mangin',
#   'H House Number': '66',
#   'H Street Name': '66 Mangin',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '23': {'Full Name': 'Bannon Michael',
#   'First Name': 'Michael',
#   'Last Name': 'Bannon',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'cooper',
#   'Full Address': '304 Ninth',
#   'H Status-flag': 'Assume',
#   'H Address': '304 Ninth',
#   'H House Number': '304',
#   'H Street Name': '304 Ninth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '24': {'Full Name': 'Barmore Christopher',
#   'First Name': 'Christopher',
#   'Last Name': 'Barmore',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shoes',
#   'Full Address': 'E . 18th n . Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': 'E . 18th n . Av . A',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['E', '.', '18th', 'n', '.', 'Av', '.', 'A'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '25': {'Full Name': 'Barratt Thomas',
#   'First Name': 'Thomas',
#   'Last Name': 'Barratt',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '605 Fourth',
#   'H Status-flag': 'Assume',
#   'H Address': '605 Fourth',
#   'H House Number': '605',
#   'H Street Name': '605 Fourth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '26': {'Full Name': 'Barrowclough James , E',
#   'First Name': 'James',
#   'Last Name': 'Barrowclough',
#   'Middle Name': ',',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '24th c . Av . 3',
#   'H Status-flag': 'Assume',
#   'H Address': '24th c . Av . 3',
#   'H House Number': '3',
#   'H Street Name': '24th c . Av . 3',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '27': {'Full Name': 'Barry James',
#   'First Name': 'James',
#   'Last Name': 'Barry',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'marblepolisher',
#   'Full Address': '294 Eleventh',
#   'H Status-flag': 'Assume',
#   'H Address': '294 Eleventh',
#   'H House Number': '294',
#   'H Street Name': '294 Eleventh',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '28': {'Full Name': 'Barry John',
#   'First Name': 'John',
#   'Last Name': 'Barry',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': '60 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '60 Av . C',
#   'H House Number': '60',
#   'H Street Name': '60 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '29': {'Full Name': 'Bates John C',
#   'First Name': 'John',
#   'Last Name': 'Bates',
#   'Middle Name': 'C',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'sarsaparilla',
#   'Full Address': '82 Nassau, h. Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': 'Brooklyn',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Brooklyn',
#   'Address 2': '82 Nassau',
#   'Address 2 House Number': '82',
#   'Address 2 Street Name': '82 Nassau',
#   'Address 2 City': ''},
#  '30': {'Full Name': 'Beach John T',
#   'First Name': 'John',
#   'Last Name': 'Beach',
#   'Middle Name': 'T',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'paper',
#   'Full Address': '43 Fulton, h. 22 Vesey',
#   'H Status-flag': 'True',
#   'H Address': '22 Vesey',
#   'H House Number': '22',
#   'H Street Name': '22 Vesey',
#   'H City': '',
#   'Address 2': '43 Fulton',
#   'Address 2 House Number': '43',
#   'Address 2 Street Name': '43 Fulton',
#   'Address 2 City': ''},
#  '31': {'Full Name': 'Bear Isaac',
#   'First Name': 'Isaac',
#   'Last Name': 'Bear',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'drygoods',
#   'Full Address': '105 Av . D, h. 105 Av . D',
#   'H Status-flag': 'True',
#   'H Address': '105 Av . D',
#   'H House Number': '105',
#   'H Street Name': '105 Av . D',
#   'H City': '',
#   'Address 2': '105 Av . D',
#   'Address 2 House Number': '105',
#   'Address 2 Street Name': '105 Av . D',
#   'Address 2 City': ''},
#  '32': {'Full Name': 'Beard William',
#   'First Name': 'William',
#   'Last Name': 'Beard',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': '89 E . 11th',
#   'H Status-flag': 'Assume',
#   'H Address': '89 E . 11th',
#   'H House Number': '89',
#   'H Street Name': '89 E . 11th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '33': {'Full Name': 'Becom John J',
#   'First Name': 'John',
#   'Last Name': 'Becom',
#   'Middle Name': 'J',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'sawyer',
#   'Full Address': 'Av . C n . Eleventh',
#   'H Status-flag': 'Assume',
#   'H Address': 'Av . C n . Eleventh',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['Av', '.', 'C', 'n', '.', 'Eleventh'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '34': {'Full Name': 'Beebe Joseph D',
#   'First Name': 'Joseph',
#   'Last Name': 'Beebe',
#   'Middle Name': 'D',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'rigger',
#   'Full Address': '350 Tenth',
#   'H Status-flag': 'Assume',
#   'H Address': '350 Tenth',
#   'H House Number': '350',
#   'H Street Name': '350 Tenth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '35': {'Full Name': 'Beebe & Co',
#   'First Name': '&',
#   'Last Name': 'Beebe',
#   'Middle Name': 'Co',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'builders',
#   'Full Address': 'W . 24th n . Ay . 10',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 24th n . Ay . 10',
#   'H House Number': '10',
#   'H Street Name': 'W . 24th n . Ay . 10',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '36': {'Full Name': 'Beers William P',
#   'First Name': 'William',
#   'Last Name': 'Beers',
#   'Middle Name': 'P',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'butcher',
#   'Full Address': '69 Orange, h. 77 Third',
#   'H Status-flag': 'True',
#   'H Address': '77 Third',
#   'H House Number': '77',
#   'H Street Name': '77 Third',
#   'H City': '',
#   'Address 2': '69 Orange',
#   'Address 2 House Number': '69',
#   'Address 2 Street Name': '69 Orange',
#   'Address 2 City': ''},
#  '37': {'Full Name': 'Bender George W',
#   'First Name': 'George',
#   'Last Name': 'Bender',
#   'Middle Name': 'W',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '27 Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': '27 Av . A',
#   'H House Number': '27',
#   'H Street Name': '27 Av . A',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '38': {'Full Name': 'Benneit Cornelius',
#   'First Name': 'Cornelius',
#   'Last Name': 'Benneit',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '400 Tenth',
#   'H Status-flag': 'Assume',
#   'H Address': '400 Tenth',
#   'H House Number': '400',
#   'H Street Name': '400 Tenth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '39': {'Full Name': 'Bennett George',
#   'First Name': 'George',
#   'Last Name': 'Bennett',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shoemaker',
#   'Full Address': '131 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '131 Av . C',
#   'H House Number': '131',
#   'H Street Name': '131 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '40': {'Full Name': 'Bennett William',
#   'First Name': 'William',
#   'Last Name': 'Bennett',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '245 E . 13th',
#   'H Status-flag': 'Assume',
#   'H Address': '245 E . 13th',
#   'H House Number': '245',
#   'H Street Name': '245 E . 13th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '41': {'Full Name': 'Bernhard Gustavus',
#   'First Name': 'Gustavus',
#   'Last Name': 'Bernhard',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'teacher',
#   'Full Address': '18 Av , C',
#   'H Status-flag': 'Assume',
#   'H Address': '18 Av , C',
#   'H House Number': '18',
#   'H Street Name': '18 Av , C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '42': {'Full Name': 'Bernz John',
#   'First Name': 'John',
#   'Last Name': 'Bernz',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '306 Av . 1',
#   'H Status-flag': 'Assume',
#   'H Address': '306 Av . 1',
#   'H House Number': '306',
#   'H Street Name': '306 Av . 1',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '43': {'Full Name': 'Berrian Burr',
#   'First Name': 'Burr',
#   'Last Name': 'Berrian',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'fish',
#   'Full Address': '89 Pitt',
#   'H Status-flag': 'Assume',
#   'H Address': '89 Pitt',
#   'H House Number': '89',
#   'H Street Name': '89 Pitt',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '44': {'Full Name': 'Bird George L',
#   'First Name': 'George',
#   'Last Name': 'Bird',
#   'Middle Name': 'L',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'clerk',
#   'Full Address': '45 Norfolk',
#   'H Status-flag': 'Assume',
#   'H Address': '45 Norfolk',
#   'H House Number': '45',
#   'H Street Name': '45 Norfolk',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '45': {'Full Name': 'Bill Hannah',
#   'First Name': 'Hannah',
#   'Last Name': 'Bill',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailoress',
#   'Full Address': '46 Amos',
#   'H Status-flag': 'Assume',
#   'H Address': '46 Amos',
#   'H House Number': '46',
#   'H Street Name': '46 Amos',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '46': {'Full Name': 'Birmingham David',
#   'First Name': 'David',
#   'Last Name': 'Birmingham',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'police',
#   'Full Address': 'W . 26th n . Av . 7',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 26th n . Av . 7',
#   'H House Number': '7',
#   'H Street Name': 'W . 26th n . Av . 7',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '47': {'Full Name': 'Boole Thomas B',
#   'First Name': 'Thomas',
#   'Last Name': 'Boole',
#   'Middle Name': 'B',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '107 Av . B',
#   'H Status-flag': 'Assume',
#   'H Address': '107 Av . B',
#   'H House Number': '107',
#   'H Street Name': '107 Av . B',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '48': {'Full Name': 'Borman Eckhard',
#   'First Name': 'Eckhard',
#   'Last Name': 'Borman',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '5 Av . B',
#   'H Status-flag': 'Assume',
#   'H Address': '5 Av . B',
#   'H House Number': '5',
#   'H Street Name': '5 Av . B',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '49': {'Full Name': 'Bott John',
#   'First Name': 'John',
#   'Last Name': 'Bott',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '299 Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': '299 Av . A',
#   'H House Number': '299',
#   'H Street Name': '299 Av . A',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '50': {'Full Name': 'Botz Louis',
#   'First Name': 'Louis',
#   'Last Name': 'Botz',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'pedler',
#   'Full Address': '48 Av . 1',
#   'H Status-flag': 'Assume',
#   'H Address': '48 Av . 1',
#   'H House Number': '48',
#   'H Street Name': '48 Av . 1',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '51': {'Full Name': 'Bouton Gilbert',
#   'First Name': 'Gilbert',
#   'Last Name': 'Bouton',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '51 Norfolk',
#   'H Status-flag': 'Assume',
#   'H Address': '51 Norfolk',
#   'H House Number': '51',
#   'H Street Name': '51 Norfolk',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '52': {'Full Name': 'Bowen John',
#   'First Name': 'John',
#   'Last Name': 'Bowen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'plumber',
#   'Full Address': '268 EF . 13th',
#   'H Status-flag': 'Assume',
#   'H Address': '268 EF . 13th',
#   'H House Number': '268',
#   'H Street Name': '268 EF . 13th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '53': {'Full Name': 'Boyd John jr',
#   'First Name': 'John',
#   'Last Name': 'Boyd',
#   'Middle Name': 'jr',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '149 & 151 Front, h. 92 Madison',
#   'H Status-flag': 'True',
#   'H Address': '92 Madison',
#   'H House Number': '92',
#   'H Street Name': '92 Madison',
#   'H City': '',
#   'Address 2': '149 & 151 Front',
#   'Address 2 House Number': '149',
#   'Address 2 Street Name': '149 & 151 Front',
#   'Address 2 City': ''},
#  '54': {'Full Name': 'Boyle John',
#   'First Name': 'John',
#   'Last Name': 'Boyle',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'liquors',
#   'Full Address': 'W . 25th n . Av . 10',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 25th n . Av . 10',
#   'H House Number': '10',
#   'H Street Name': 'W . 25th n . Av . 10',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '55': {'Full Name': 'Boynton Ray',
#   'First Name': 'Ray',
#   'Last Name': 'Boynton',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '51 Exch, h. 31 W . 15th',
#   'H Status-flag': 'True',
#   'H Address': '31 W . 15th',
#   'H House Number': '31',
#   'H Street Name': '31 W . 15th',
#   'H City': '',
#   'Address 2': '51 Exch',
#   'Address 2 House Number': '51',
#   'Address 2 Street Name': '51 Exch',
#   'Address 2 City': ''},
#  '56': {'Full Name': 'Brady John',
#   'First Name': 'John',
#   'Last Name': 'Brady',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'school',
#   'Full Address': '219 E . 13th, h. 217 E , 13th',
#   'H Status-flag': 'True',
#   'H Address': '217 E , 13th',
#   'H House Number': '217',
#   'H Street Name': '217 E , 13th',
#   'H City': '',
#   'Address 2': '219 E . 13th',
#   'Address 2 House Number': '219',
#   'Address 2 Street Name': '219 E . 13th',
#   'Address 2 City': ''},
#  '57': {'Full Name': 'Bramley Patrick',
#   'First Name': 'Patrick',
#   'Last Name': 'Bramley',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'boilermaker',
#   'Full Address': '319 Ninth',
#   'H Status-flag': 'Assume',
#   'H Address': '319 Ninth',
#   'H House Number': '319',
#   'H Street Name': '319 Ninth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '58': {'Full Name': 'Bramwell Joseph',
#   'First Name': 'Joseph',
#   'Last Name': 'Bramwell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': 'h. 101 Henry , Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': '101 Henry , Brooklyn',
#   'H House Number': '101',
#   'H Street Name': '101 Henry , Brooklyn',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '59': {'Full Name': 'Brant Theophilus',
#   'First Name': 'Theophilus',
#   'Last Name': 'Brant',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shipjoiner',
#   'Full Address': 'Ay . D c . Fourth',
#   'H Status-flag': 'Assume',
#   'H Address': 'Ay . D c . Fourth',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['Ay', '.', 'D', 'c', '.', 'Fourth'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '60': {'Full Name': 'Breasted John',
#   'First Name': 'John',
#   'Last Name': 'Breasted',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'allaire works',
#   'Full Address': '464 Cherry',
#   'H Status-flag': 'Assume',
#   'H Address': '464 Cherry',
#   'H House Number': '464',
#   'H Street Name': '464 Cherry',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '61': {'Full Name': 'Brennan Joseph',
#   'First Name': 'Joseph',
#   'Last Name': 'Brennan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mason',
#   'Full Address': '312 Av . 1',
#   'H Status-flag': 'Assume',
#   'H Address': '312 Av . 1',
#   'H House Number': '312',
#   'H Street Name': '312 Av . 1',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '62': {'Full Name': 'Brennen James H',
#   'First Name': 'James',
#   'Last Name': 'Brennen',
#   'Middle Name': 'H',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'hatter',
#   'Full Address': '7 Av . D, h. 7 Av . D',
#   'H Status-flag': 'True',
#   'H Address': '7 Av . D',
#   'H House Number': '7',
#   'H Street Name': '7 Av . D',
#   'H City': '',
#   'Address 2': '7 Av . D',
#   'Address 2 House Number': '7',
#   'Address 2 Street Name': '7 Av . D',
#   'Address 2 City': ''},
#  '63': {'Full Name': 'Breuninger Henry',
#   'First Name': 'Henry',
#   'Last Name': 'Breuninger',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailot',
#   'Full Address': '25 Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': '25 Av . A',
#   'H House Number': '25',
#   'H Street Name': '25 Av . A',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '64': {'Full Name': 'Brice Henry',
#   'First Name': 'Henry',
#   'Last Name': 'Brice',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'silkweaver',
#   'Full Address': '143 W . 28th',
#   'H Status-flag': 'Assume',
#   'H Address': '143 W . 28th',
#   'H House Number': '143',
#   'H Street Name': '143 W . 28th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '65': {'Full Name': 'Brincker William',
#   'First Name': 'William',
#   'Last Name': 'Brincker',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': 'Third n . Av . A',
#   'H Status-flag': 'Assume',
#   'H Address': 'Third n . Av . A',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['Third', 'n', '.', 'Av', '.', 'A'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '66': {'Full Name': 'Brodhead John R',
#   'First Name': 'John',
#   'Last Name': 'Brodhead',
#   'Middle Name': 'R',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '32 Bond',
#   'H Status-flag': 'Assume',
#   'H Address': '32 Bond',
#   'H House Number': '32',
#   'H Street Name': '32 Bond',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '67': {'Full Name': 'Brooks Brothers',
#   'First Name': 'Brothers',
#   'Last Name': 'Brooks',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'clothing',
#   'Full Address': '116 & 118 Cherry',
#   'H Status-flag': 'Assume',
#   'H Address': '116 & 118 Cherry',
#   'H House Number': '116',
#   'H Street Name': '116 & 118 Cherry',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '68': {'Full Name': 'Brouard Peter',
#   'First Name': 'Peter',
#   'Last Name': 'Brouard',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '83 Leonard, h. 143 Reade',
#   'H Status-flag': 'True',
#   'H Address': '143 Reade',
#   'H House Number': '143',
#   'H Street Name': '143 Reade',
#   'H City': '',
#   'Address 2': '83 Leonard',
#   'Address 2 House Number': '83',
#   'Address 2 Street Name': '83 Leonard',
#   'Address 2 City': ''},
#  '69': {'Full Name': 'Brough William',
#   'First Name': 'William',
#   'Last Name': 'Brough',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '117 Fulton, h. 4 Beach ,',
#   'H Status-flag': 'True',
#   'H Address': '4 Beach ,',
#   'H House Number': '4',
#   'H Street Name': '4 Beach ,',
#   'H City': '',
#   'Address 2': '117 Fulton',
#   'Address 2 House Number': '117',
#   'Address 2 Street Name': '117 Fulton',
#   'Address 2 City': ''},
#  '70': {'Full Name': 'Brouner Joseph P',
#   'First Name': 'Joseph',
#   'Last Name': 'Brouner',
#   'Middle Name': 'P',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'drygoods',
#   'Full Address': '707 Greenwich, h. 529 Hudson',
#   'H Status-flag': 'True',
#   'H Address': '529 Hudson',
#   'H House Number': '529',
#   'H Street Name': '529 Hudson',
#   'H City': '',
#   'Address 2': '707 Greenwich',
#   'Address 2 House Number': '707',
#   'Address 2 Street Name': '707 Greenwich',
#   'Address 2 City': ''},
#  '71': {'Full Name': 'Brouwer Saml',
#   'First Name': 'Saml',
#   'Last Name': 'Brouwer',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'crockery',
#   'Full Address': '72 Vesey, h. 173 Wooster',
#   'H Status-flag': 'True',
#   'H Address': '173 Wooster',
#   'H House Number': '173',
#   'H Street Name': '173 Wooster',
#   'H City': '',
#   'Address 2': '72 Vesey',
#   'Address 2 House Number': '72',
#   'Address 2 Street Name': '72 Vesey',
#   'Address 2 City': ''},
#  '72': {'Full Name': 'Brown Charles P',
#   'First Name': 'Charles',
#   'Last Name': 'Brown',
#   'Middle Name': 'P',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '290 West, h. 95 W . 13th',
#   'H Status-flag': 'True',
#   'H Address': '95 W . 13th',
#   'H House Number': '95',
#   'H Street Name': '95 W . 13th',
#   'H City': '',
#   'Address 2': '290 West',
#   'Address 2 House Number': '290',
#   'Address 2 Street Name': '290 West',
#   'Address 2 City': ''},
#  '73': {'Full Name': 'Brown Robert',
#   'First Name': 'Robert',
#   'Last Name': 'Brown',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'physician',
#   'Full Address': '174 Chambers',
#   'H Status-flag': 'Assume',
#   'H Address': '174 Chambers',
#   'H House Number': '174',
#   'H Street Name': '174 Chambers',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '74': {'Full Name': 'Brown Thomas H',
#   'First Name': 'Thomas',
#   'Last Name': 'Brown',
#   'Middle Name': 'H',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'hosiery',
#   'Full Address': '34 Liberty',
#   'H Status-flag': 'Assume',
#   'H Address': '34 Liberty',
#   'H House Number': '34',
#   'H Street Name': '34 Liberty',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '75': {'Full Name': 'Brown & Englis',
#   'First Name': '&',
#   'Last Name': 'Brown',
#   'Middle Name': 'Englis',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shipwrights',
#   'Full Address': 'Twelfth c . Dry Dock',
#   'H Status-flag': 'Assume',
#   'H Address': 'Twelfth c . Dry Dock',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': ['Twelfth', 'c', '.', 'Dry', 'Dock'],
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '76': {'Full Name': 'Brownrse Jolin Â§8',
#   'First Name': 'Jolin',
#   'Last Name': 'Brownrse',
#   'Middle Name': 'Â§8',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carver',
#   'Full Address': 'h. 53 Monroe',
#   'H Status-flag': 'True',
#   'H Address': '53 Monroe',
#   'H House Number': '53',
#   'H Street Name': '53 Monroe',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '77': {'Full Name': 'Bruggemann Diedrich',
#   'First Name': 'Diedrich',
#   'Last Name': 'Bruggemann',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'grocer',
#   'Full Address': 'h. 72 Lewis',
#   'H Status-flag': 'True',
#   'H Address': '72 Lewis',
#   'H House Number': '72',
#   'H Street Name': '72 Lewis',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '78': {'Full Name': 'Brummell Adonijah',
#   'First Name': 'Adonijah',
#   'Last Name': 'Brummell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'confectioner',
#   'Full Address': 'h. 141 Norfolk',
#   'H Status-flag': 'True',
#   'H Address': '141 Norfolk',
#   'H House Number': '141',
#   'H Street Name': '141 Norfolk',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '79': {'Full Name': 'Budd Thomas S',
#   'First Name': 'Thomas',
#   'Last Name': 'Budd',
#   'Middle Name': 'S',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'shipmaster',
#   'Full Address': '166 E . 20th',
#   'H Status-flag': 'Assume',
#   'H Address': '166 E . 20th',
#   'H House Number': '166',
#   'H Street Name': '166 E . 20th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '80': {'Full Name': 'Bunce William C',
#   'First Name': 'William',
#   'Last Name': 'Bunce',
#   'Middle Name': 'C',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '201 Av . 3',
#   'H Status-flag': 'Assume',
#   'H Address': '201 Av . 3',
#   'H House Number': '201',
#   'H Street Name': '201 Av . 3',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '81': {'Full Name': 'Bunzel Gottlieb',
#   'First Name': 'Gottlieb',
#   'Last Name': 'Bunzel',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'whitewasher',
#   'Full Address': '93 Ridge',
#   'H Status-flag': 'Assume',
#   'H Address': '93 Ridge',
#   'H House Number': '93',
#   'H Street Name': '93 Ridge',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '82': {'Full Name': 'Burket James E',
#   'First Name': 'James',
#   'Last Name': 'Burket',
#   'Middle Name': 'E',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'porterhouse',
#   'Full Address': '433 Tenth',
#   'H Status-flag': 'Assume',
#   'H Address': '433 Tenth',
#   'H House Number': '433',
#   'H Street Name': '433 Tenth',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '83': {'Full Name': 'Camp Benjamin F',
#   'First Name': 'Benjamin',
#   'Last Name': 'Camp',
#   'Middle Name': 'F',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'builder',
#   'Full Address': '86 Av . 2',
#   'H Status-flag': 'Assume',
#   'H Address': '86 Av . 2',
#   'H House Number': '86',
#   'H Street Name': '86 Av . 2',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '84': {'Full Name': 'Campbell John',
#   'First Name': 'John',
#   'Last Name': 'Campbell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'blacksmith',
#   'Full Address': '180 Av . C',
#   'H Status-flag': 'Assume',
#   'H Address': '180 Av . C',
#   'H House Number': '180',
#   'H Street Name': '180 Av . C',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '85': {'Full Name': 'Campbell Peter',
#   'First Name': 'Peter',
#   'Last Name': 'Campbell',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'boatman',
#   'Full Address': '128 Charlton',
#   'H Status-flag': 'Assume',
#   'H Address': '128 Charlton',
#   'H House Number': '128',
#   'H Street Name': '128 Charlton',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '86': {'Full Name': 'Campbell William S',
#   'First Name': 'William',
#   'Last Name': 'Campbell',
#   'Middle Name': 'S',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'printer',
#   'Full Address': '180 Grand',
#   'H Status-flag': 'Assume',
#   'H Address': '180 Grand',
#   'H House Number': '180',
#   'H Street Name': '180 Grand',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '87': {'Full Name': 'Campbell & Moody',
#   'First Name': '&',
#   'Last Name': 'Campbell',
#   'Middle Name': 'Moody',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'steam saw mill , foot 36th',
#   'Full Address': '7 Broad, .',
#   'H Status-flag': 'True',
#   'H Address': '.',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': '.',
#   'Address 2': '7 Broad',
#   'Address 2 House Number': '7',
#   'Address 2 Street Name': '7 Broad',
#   'Address 2 City': ''},
#  '88': {'Full Name': 'Cunham Wm',
#   'First Name': 'Wm',
#   'Last Name': 'Cunham',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carputer',
#   'Full Address': '16 Clarkson, h. 14 Clarkson',
#   'H Status-flag': 'True',
#   'H Address': '14 Clarkson',
#   'H House Number': '14',
#   'H Street Name': '14 Clarkson',
#   'H City': '',
#   'Address 2': '16 Clarkson',
#   'Address 2 House Number': '16',
#   'Address 2 Street Name': '16 Clarkson',
#   'Address 2 City': ''},
#  '89': {'Full Name': 'Cannon Cornelius',
#   'First Name': 'Cornelius',
#   'Last Name': 'Cannon',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tinner',
#   'Full Address': '176 Wooster, h. 2 Congress',
#   'H Status-flag': 'True',
#   'H Address': '2 Congress',
#   'H House Number': '2',
#   'H Street Name': '2 Congress',
#   'H City': '',
#   'Address 2': '176 Wooster',
#   'Address 2 House Number': '176',
#   'Address 2 Street Name': '176 Wooster',
#   'Address 2 City': ''},
#  '90': {'Full Name': 'Carey Thomas',
#   'First Name': 'Thomas',
#   'Last Name': 'Carey',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': '104 FE . 11th',
#   'H Status-flag': 'Assume',
#   'H Address': '104 FE . 11th',
#   'H House Number': '104',
#   'H Street Name': '104 FE . 11th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '91': {'Full Name': 'Carlisle George',
#   'First Name': 'George',
#   'Last Name': 'Carlisle',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '165 Pearl, h. Cincinnati , O',
#   'H Status-flag': 'True',
#   'H Address': 'Cincinnati , O',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Cincinnati , O',
#   'Address 2': '165 Pearl',
#   'Address 2 House Number': '165',
#   'Address 2 Street Name': '165 Pearl',
#   'Address 2 City': ''},
#  '92': {'Full Name': 'Carlisle & Stedman',
#   'First Name': '&',
#   'Last Name': 'Carlisle',
#   'Middle Name': 'Stedman',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mers',
#   'Full Address': '165 Pearl :',
#   'H Status-flag': 'Assume',
#   'H Address': '165 Pearl :',
#   'H House Number': '165',
#   'H Street Name': '165 Pearl :',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '93': {'Full Name': 'Carrington Z . E',
#   'First Name': 'Z',
#   'Last Name': 'Carrington',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'salesman',
#   'Full Address': '13 William, h. Court n . Degraw , Brooklyn',
#   'H Status-flag': 'True',
#   'H Address': 'Court n . Degraw , Brooklyn',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Court n . Degraw , Brooklyn',
#   'Address 2': '13 William',
#   'Address 2 House Number': '13',
#   'Address 2 Street Name': '13 William',
#   'Address 2 City': ''},
#  '94': {'Full Name': 'Carroll D . J',
#   'First Name': 'D',
#   'Last Name': 'Carroll',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'physician',
#   'Full Address': '400 Broadway :',
#   'H Status-flag': 'Assume',
#   'H Address': '400 Broadway :',
#   'H House Number': '400',
#   'H Street Name': '400 Broadway :',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '95': {'Full Name': 'Case George',
#   'First Name': 'George',
#   'Last Name': 'Case',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'sashmaker',
#   'Full Address': 'W . 25th n . Av . 8 , h . W 2th n . Av . 8',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 25th n . Av . 8 , h . W 2th n . Av . 8',
#   'H House Number': '8',
#   'H Street Name': 'W . 25th n . Av . 8 , h . W 2th n . Av . 8',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '96': {'Full Name': 'Castle Charles H',
#   'First Name': 'Charles',
#   'Last Name': 'Castle',
#   'Middle Name': 'H',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'mer',
#   'Full Address': '121 Pearl',
#   'H Status-flag': 'Assume',
#   'H Address': '121 Pearl',
#   'H House Number': '121',
#   'H Street Name': '121 Pearl',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '97': {'Full Name': 'Carlough George',
#   'First Name': 'George',
#   'Last Name': 'Carlough',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '746 Washington',
#   'H Status-flag': 'Assume',
#   'H Address': '746 Washington',
#   'H House Number': '746',
#   'H Street Name': '746 Washington',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '98': {'Full Name': 'Channing William',
#   'First Name': 'William',
#   'Last Name': 'Channing',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'physician',
#   'Full Address': '88 White',
#   'H Status-flag': 'Assume',
#   'H Address': '88 White',
#   'H House Number': '88',
#   'H Street Name': '88 White',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '99': {'Full Name': 'Chapin R . Spencer',
#   'First Name': 'R',
#   'Last Name': 'Chapin',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'physician',
#   'Full Address': '305 Third',
#   'H Status-flag': 'Assume',
#   'H Address': '305 Third',
#   'H House Number': '305',
#   'H Street Name': '305 Third',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '100': {'Full Name': 'Charcin John',
#   'First Name': 'John',
#   'Last Name': 'Charcin',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carpenter',
#   'Full Address': 'W . 28th n . Av . 7',
# ...
#   'H Street Name': '22 Morton',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '969': {'Full Name': 'Allaire Robert',
#   'First Name': 'Robert',
#   'Last Name': 'Allaire',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'bookkeeper',
#   'Full Address': '262 Seventh',
#   'H Status-flag': 'Assume',
#   'H Address': '262 Seventh',
#   'H House Number': '262',
#   'H Street Name': '262 Seventh',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '970': {'Full Name': 'Allaire Seaman',
#   'First Name': 'Seaman',
#   'Last Name': 'Allaire',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'butcher',
#   'Full Address': '301 Bleecker, h. 61 Leroy',
#   'H Status-flag': 'True',
#   'H Address': '61 Leroy',
#   'H House Number': '61',
#   'H Street Name': '61 Leroy',
#   'H City': '',
#   'Address 2': '301 Bleecker',
#   'Address 2 House Number': '301',
#   'Address 2 Street Name': '301 Bleecker',
#   'Address 2 City': ''},
#  '971': {'Full Name': 'Allaire Thomas H',
#   'First Name': 'Thomas',
#   'Last Name': 'Allaire',
#   'Middle Name': 'H',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'and custom house',
#   'Full Address': '419 Broadway, 93 Morton',
#   'H Status-flag': 'True',
#   'H Address': '93 Morton',
#   'H House Number': '93',
#   'H Street Name': '93 Morton',
#   'H City': '',
#   'Address 2': '419 Broadway',
#   'Address 2 House Number': '419',
#   'Address 2 Street Name': '419 Broadway',
#   'Address 2 City': ''},
#  '972': {'Full Name': 'Allaire Wilmot D',
#   'First Name': 'Wilmot',
#   'Last Name': 'Allaire',
#   'Middle Name': 'D',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'coppersmith',
#   'Full Address': '44 Broome',
#   'H Status-flag': 'Assume',
#   'H Address': '44 Broome',
#   'H House Number': '44',
#   'H Street Name': '44 Broome',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '973': {'Full Name': 'Allan Alexander',
#   'First Name': 'Alexander',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'jeweller',
#   'Full Address': '111 Division and r . 276 Bowery, h. 149 Wooster . :',
#   'H Status-flag': 'True',
#   'H Address': '149 Wooster . :',
#   'H House Number': '149',
#   'H Street Name': '149 Wooster . :',
#   'H City': '',
#   'Address 2': '111 Division and r . 276 Bowery',
#   'Address 2 House Number': '111',
#   'Address 2 Street Name': '111 Division and r . 276 Bowery',
#   'Address 2 City': ''},
#  '974': {'Full Name': 'Allan Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'engineer',
#   'Full Address': 'h. Av . 9 Â¢ . W . 37th',
#   'H Status-flag': 'True',
#   'H Address': 'Av . 9 Â¢ . W . 37th',
#   'H House Number': '9',
#   'H Street Name': 'Av . 9 Â¢ . W . 37th',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '975': {'Full Name': 'Allan George',
#   'First Name': 'George',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '113 Cherry .',
#   'H Status-flag': 'Assume',
#   'H Address': '113 Cherry .',
#   'H House Number': '113',
#   'H Street Name': '113 Cherry .',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '976': {'Full Name': 'Allan John',
#   'First Name': 'John',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': '17 Vandewater',
#   'H Status-flag': 'Assume',
#   'H Address': '17 Vandewater',
#   'H House Number': '17',
#   'H Street Name': '17 Vandewater',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '977': {'Full Name': 'Allan Robt',
#   'First Name': 'Robt',
#   'Last Name': 'Allan',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'provisions',
#   'Full Address': '226 Washington, h. 53 Watts',
#   'H Status-flag': 'True',
#   'H Address': '53 Watts',
#   'H House Number': '53',
#   'H Street Name': '53 Watts',
#   'H City': '',
#   'Address 2': '226 Washington',
#   'Address 2 House Number': '226',
#   'Address 2 Street Name': '226 Washington',
#   'Address 2 City': ''},
#  '978': {'Full Name': 'Allan & Rose',
#   'First Name': '&',
#   'Last Name': 'Allan',
#   'Middle Name': 'Rose',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': "butter'and provisions",
#   'Full Address': '226 Washgtn',
#   'H Status-flag': 'Assume',
#   'H Address': '226 Washgtn',
#   'H House Number': '226',
#   'H Street Name': '226 Washgtn',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '979': {'Full Name': 'Allard Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Allard',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'clerk',
#   'Full Address': 'E , 42d, Av . 3 ,',
#   'H Status-flag': 'True',
#   'H Address': 'Av . 3 ,',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Av . 3 ,',
#   'Address 2': 'E , 42d',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': 'E , 42d'},
#  '980': {'Full Name': 'Allard Nahun W',
#   'First Name': 'Nahun',
#   'Last Name': 'Allard',
#   'Middle Name': 'W',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'butcher',
#   'Full Address': '154 Varick, h. 152 Varick',
#   'H Status-flag': 'True',
#   'H Address': '152 Varick',
#   'H House Number': '152',
#   'H Street Name': '152 Varick',
#   'H City': '',
#   'Address 2': '154 Varick',
#   'Address 2 House Number': '154',
#   'Address 2 Street Name': '154 Varick',
#   'Address 2 City': ''},
#  '981': {'Full Name': 'Allari Joseph',
#   'First Name': 'Joseph',
#   'Last Name': 'Allari',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'boarding',
#   'Full Address': '37 Rose',
#   'H Status-flag': 'Assume',
#   'H Address': '37 Rose',
#   'H House Number': '37',
#   'H Street Name': '37 Rose',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '982': {'Full Name': 'Allas Joseph A',
#   'First Name': 'Joseph',
#   'Last Name': 'Allas',
#   'Middle Name': 'A',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'tailor',
#   'Full Address': '27 Ridge',
#   'H Status-flag': 'Assume',
#   'H Address': '27 Ridge',
#   'H House Number': '27',
#   'H Street Name': '27 Ridge',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '983': {'Full Name': 'Allason W',
#   'First Name': 'W',
#   'Last Name': 'Allason',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'salesman',
#   'Full Address': "117 Pearl, h. Wyck'ff , Brklyn",
#   'H Status-flag': 'True',
#   'H Address': "Wyck'ff , Brklyn",
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': "Wyck'ff , Brklyn",
#   'Address 2': '117 Pearl',
#   'Address 2 House Number': '117',
#   'Address 2 Street Name': '117 Pearl',
#   'Address 2 City': ''},
#  '984': {'Full Name': 'Allason Frances',
#   'First Name': 'Frances',
#   'Last Name': 'Allason',
#   'Middle Name': '',
#   'Widow-flag': 'True',
#   'Widow Of': 'Allason',
#   'Title': '',
#   'Occupation': 'boarding',
#   'Full Address': '70 G . wich',
#   'H Status-flag': 'Assume',
#   'H Address': '70 G . wich',
#   'H House Number': '70',
#   'H Street Name': '70 G . wich',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '985': {'Full Name': 'Allcock Hugh',
#   'First Name': 'Hugh',
#   'Last Name': 'Allcock',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'way',
#   'Full Address': '341 B, h. 18 White',
#   'H Status-flag': 'True',
#   'H Address': '18 White',
#   'H House Number': '18',
#   'H Street Name': '18 White',
#   'H City': '',
#   'Address 2': '341 B',
#   'Address 2 House Number': '341',
#   'Address 2 Street Name': '341 B',
#   'Address 2 City': ''},
#  '986': {'Full Name': 'Allcock Thomas',
#   'First Name': 'Thomas',
#   'Last Name': 'Allcock',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'chemist',
#   'Full Address': '24 Perry',
#   'H Status-flag': 'Assume',
#   'H Address': '24 Perry',
#   'H House Number': '24',
#   'H Street Name': '24 Perry',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '987': {'Full Name': 'ALLCOCK & ALLEN',
#   'First Name': '&',
#   'Last Name': 'ALLCOCK',
#   'Middle Name': 'ALLEN',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'silverware & furnishing articles',
#   'Full Address': '341 Broadway',
#   'H Status-flag': 'Assume',
#   'H Address': '341 Broadway',
#   'H House Number': '341',
#   'H Street Name': '341 Broadway',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '988': {'Full Name': 'Allegri Joseph',
#   'First Name': 'Joseph',
#   'Last Name': 'Allegri',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'artist',
#   'Full Address': 'h. 131 E . 21st',
#   'H Status-flag': 'True',
#   'H Address': '131 E . 21st',
#   'H House Number': '131',
#   'H Street Name': '131 E . 21st',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '989': {'Full Name': 'Alleh Christopher',
#   'First Name': 'Christopher',
#   'Last Name': 'Alleh',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'soap',
#   'Full Address': 'h. E . 41st n . Av . 1',
#   'H Status-flag': 'True',
#   'H Address': 'E . 41st n . Av . 1',
#   'H House Number': '1',
#   'H Street Name': 'E . 41st n . Av . 1',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '990': {'Full Name': 'Allen A . B',
#   'First Name': 'A',
#   'Last Name': 'Allen',
#   'Middle Name': '.',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': '',
#   'Full Address': 'Co . 189 and 191 Water',
#   'H Status-flag': '',
#   'H Address': 'Co . 189 and 191 Water',
#   'H House Number': '189',
#   'H Street Name': 'Co . 189 and 191 Water',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '991': {'Full Name': 'Allen Abraham',
#   'First Name': 'Abraham',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'porterh',
#   'Full Address': '248 West, h. 44 Hubert',
#   'H Status-flag': 'True',
#   'H Address': '44 Hubert',
#   'H House Number': '44',
#   'H Street Name': '44 Hubert',
#   'H City': '',
#   'Address 2': '248 West',
#   'Address 2 House Number': '248',
#   'Address 2 Street Name': '248 West',
#   'Address 2 City': ''},
#  '992': {'Full Name': 'Allen Abraham',
#   'First Name': 'Abraham',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': '46 Hubert',
#   'H Status-flag': 'Assume',
#   'H Address': '46 Hubert',
#   'H House Number': '46',
#   'H Street Name': '46 Hubert',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '993': {'Full Name': 'Allen Abraham & Co',
#   'First Name': 'Abraham',
#   'Last Name': 'Allen',
#   'Middle Name': '&',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'grocers',
#   'Full Address': 'Av . 8 c . W . 29th & 30 Av . 8, h. Av . 8c . W . 29th',
#   'H Status-flag': 'True',
#   'H Address': 'Av . 8c . W . 29th',
#   'H House Number': '',
#   'H Street Name': '',
#   'H City': 'Av . 8c . W . 29th',
#   'Address 2': 'Av . 8 c . W . 29th & 30 Av . 8',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': 'Av . 8 c . W . 29th & 30 Av . 8'},
#  '994': {'Full Name': 'Allen Albert G',
#   'First Name': 'Albert',
#   'Last Name': 'Allen',
#   'Middle Name': 'G',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'furnaces',
#   'Full Address': '351 Broadway; h . 44 Sidney pl . Brooklyn',
#   'H Status-flag': 'Assume',
#   'H Address': '351 Broadway; h . 44 Sidney pl . Brooklyn',
#   'H House Number': '351',
#   'H Street Name': '351 Broadway; h . 44 Sidney pl . Brooklyn',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '995': {'Full Name': 'Allen Alexander',
#   'First Name': 'Alexander',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'carman',
#   'Full Address': 'W . 18th n . Av . 6',
#   'H Status-flag': '',
#   'H Address': 'W . 18th n . Av . 6',
#   'H House Number': '6',
#   'H Street Name': 'W . 18th n . Av . 6',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '996': {'Full Name': 'Allen Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'machinist',
#   'Full Address': 'W . 37th n . Av . 9',
#   'H Status-flag': 'Assume',
#   'H Address': 'W . 37th n . Av . 9',
#   'H House Number': '9',
#   'H Street Name': 'W . 37th n . Av . 9',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '997': {'Full Name': 'Allen Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Allen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'cagemaker',
#   'Full Address': '37 First, h. 267 Av . 3',
#   'H Status-flag': 'True',
#   'H Address': '267 Av . 3',
#   'H House Number': '267',
#   'H Street Name': '267 Av . 3',
#   'H City': '',
#   'Address 2': '37 First',
#   'Address 2 House Number': '37',
#   'Address 2 Street Name': '37 First',
#   'Address 2 City': ''},
#  '998': {'Full Name': 'Alen Andrew',
#   'First Name': 'Andrew',
#   'Last Name': 'Alen',
#   'Middle Name': '',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'police',
#   'Full Address': '564 Grand',
#   'H Status-flag': 'Assume',
#   'H Address': '564 Grand',
#   'H House Number': '564',
#   'H Street Name': '564 Grand',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '999': {'Full Name': 'Allen Andrew J',
#   'First Name': 'Andrew',
#   'Last Name': 'Allen',
#   'Middle Name': 'J',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'costumer',
#   'Full Address': '37 Bowery',
#   'H Status-flag': 'Assume',
#   'H Address': '37 Bowery',
#   'H House Number': '37',
#   'H Street Name': '37 Bowery',
#   'H City': '',
#   'Address 2': '',
#   'Address 2 House Number': '',
#   'Address 2 Street Name': '',
#   'Address 2 City': ''},
#  '1000': {'Full Name': 'Allen Andrew J',
#   'First Name': 'Andrew',
#   'Last Name': 'Allen',
#   'Middle Name': 'J',
#   'Widow-flag': 'False',
#   'Widow Of': '',
#   'Title': '',
#   'Occupation': 'cagemaker',
#   'Full Address': '37 First, h. 267 Av . 3',
#   'H Status-flag': 'True',
#   'H Address': '267 Av . 3',
#   'H House Number': '267',
#   'H Street Name': '267 Av . 3',
#   'H City': '',
#   'Address 2': '37 First',
#   'Address 2 House Number': '37',
#   'Address 2 Street Name': '37 First',
#   'Address 2 City': ''},
#  ...}

# %%
import pandas as pd
output_1850_tess = pd.DataFrame.from_dict(final_output).transpose()

# %%
output_1850_tess.replace('', np.nan, inplace=True)
# output_1850_tess.sort_values(by=['Full Name'], inplace=True)

# %%
output_1850_tess = output_1850_tess.replace({'â€œ':''}, regex=True)
output_1850_tess= output_1850_tess.replace({'â€�':''}, regex=True)
output_1850_tess = output_1850_tess.replace({'â€”':''}, regex=True)
output_1850_tess.head(10)
# Out:
#                Full Name First Name Last Name Middle Name Widow-flag Widow Of  \
# 1         Ackley Addison    Addison    Ackley         NaN      False      NaN
# 2          Adams William    William     Adams         NaN      False      NaN
# 3          Aitkin Thomas     Thomas    Aitkin         NaN      False      NaN
# 4         Albro Benjamin   Benjamin     Albro         NaN      False      NaN
# 5            Allen E . W          E     Allen           .      False      NaN
# 6   Anderson Frederick R  Frederick  Anderson           R      False      NaN
# 7        Anderson John R       John  Anderson           R      False      NaN
# 8           Anthes Peter      Peter    Anthes         NaN      False      NaN
# 9       Anthes & Eckardt          &    Anthes     Eckardt      False      NaN
# 10           Appell John       John    Appell         NaN      False      NaN
#
#     Title   Occupation                                       Full Address  \
# 1     NaN        clerk                           47 Broadway, h. 39 Pearl
# 2     NaN      weigher  20 Washington & 13 West, h. 170 Clinton , Broo...
# 3     NaN  stonecutter                                     601 Washington
# 4     NaN          sen                                         328 Bowery
# 5     NaN    publisher                                          42 Orange
# 6     NaN          mer                             13 Front, h. 77 Barrow
# 7     NaN       seaman                                        586 E , 4th
# 8     NaN          NaN                                          34 Av . C
# 9     NaN      barbers                                          34 Av . C
# 10    NaN       tailor                                          40 Av . C
#
#    H Status-flag               H Address H House Number   H Street Name  \
# 1           True                39 Pearl             39        39 Pearl
# 2           True  170 Clinton , Brooklyn            170   170 Clinton ,
# 3         Assume          601 Washington            601  601 Washington
# 4         Assume              328 Bowery            328      328 Bowery
# 5         Assume               42 Orange             42       42 Orange
# 6           True               77 Barrow             77       77 Barrow
# 7         Assume             586 E , 4th            586     586 E , 4th
# 8            NaN               34 Av . C             34       34 Av . C
# 9         Assume               34 Av . C             34       34 Av . C
# 10        Assume               40 Av . C             40       40 Av . C
#
#       H City                Address 2 Address 2 House Number  \
# 1        NaN              47 Broadway                     47
# 2   Brooklyn  20 Washington & 13 West                     20
# 3        NaN                      NaN                    NaN
# 4        NaN                      NaN                    NaN
# 5        NaN                      NaN                    NaN
# 6        NaN                 13 Front                     13
# 7        NaN                      NaN                    NaN
# 8        NaN                      NaN                    NaN
# 9        NaN                      NaN                    NaN
# 10       NaN                      NaN                    NaN
#
#       Address 2 Street Name Address 2 City
# 1               47 Broadway            NaN
# 2   20 Washington & 13 West            NaN
# 3                       NaN            NaN
# 4                       NaN            NaN
# 5                       NaN            NaN
# 6                  13 Front            NaN
# 7                       NaN            NaN
# 8                       NaN            NaN
# 9                       NaN            NaN
# 10                      NaN            NaN

# %%
output_1850_tess.tail(10)
# Out:
#                  Full Name First Name Last Name Middle Name Widow-flag  \
# 113597         Derman John       John    Derman         NaN      False
# 113598           Dern John       John      Dern         NaN      False
# 113599        Dero William    William      Dero         NaN      False
# 113600       Deromas Peter      Peter   Deromas         NaN      False
# 113601      De Ronge Louis      Ronge        De       Louis      False
# 113602    DE RONGE & MORAN      RONGE        DE           &      False
# 113603        De Roos Joel       Roos        De        Joel      False
# 113604  De Rosset Armand J     Rosset        De      Armand      False
# 113605         Derr John C       John      Derr           C      False
# 113606        Derregh John       John   Derregh         NaN      False
#
#        Widow Of  Title   Occupation                      Full Address  \
# 113597      NaN    NaN     porter h                           39 Pitt
# 113598      NaN    NaN  upholsterer                         59 Av . A
# 113599      NaN    NaN     boxmaker                        16 Chesnut
# 113600      NaN    NaN        drugs         59 Chatham, h. 59 Chatha:
# 113601      NaN    NaN          mer                          50 Broad
# 113602      NaN    NaN    importers                          50 Broad
# 113603      NaN    NaN        clerk                  129 W . Broadway
# 113604      NaN    NaN          mer  180 Front, h. Â¥ mington, N . Cc
# 113605      NaN    NaN    carpenter                     h. 380 Av . 6
# 113606      NaN    NaN      laborer                      283 Mulberry
#
#        H Status-flag         H Address H House Number     H Street Name  \
# 113597        Assume           39 Pitt             39           39 Pitt
# 113598        Assume         59 Av . A             59         59 Av . A
# 113599        Assume        16 Chesnut             16        16 Chesnut
# 113600          True        59 Chatha:             59        59 Chatha:
# 113601        Assume          50 Broad             50          50 Broad
# 113602        Assume          50 Broad             50          50 Broad
# 113603        Assume  129 W . Broadway            129  129 W . Broadway
# 113604          True        Â¥ mington            NaN               NaN
# 113605          True        380 Av . 6            380        380 Av . 6
# 113606        Assume      283 Mulberry            283      283 Mulberry
#
#             H City   Address 2 Address 2 House Number Address 2 Street Name  \
# 113597         NaN         NaN                    NaN                   NaN
# 113598         NaN         NaN                    NaN                   NaN
# 113599         NaN         NaN                    NaN                   NaN
# 113600         NaN  59 Chatham                     59            59 Chatham
# 113601         NaN         NaN                    NaN                   NaN
# 113602         NaN         NaN                    NaN                   NaN
# 113603         NaN         NaN                    NaN                   NaN
# 113604  Â¥ mington   180 Front                    180             180 Front
# 113605         NaN         NaN                    NaN                   NaN
# 113606         NaN         NaN                    NaN                   NaN
#
#        Address 2 City
# 113597            NaN
# 113598            NaN
# 113599            NaN
# 113600            NaN
# 113601            NaN
# 113602            NaN
# 113603            NaN
# 113604            NaN
# 113605            NaN
# 113606            NaN

# %%
# output_1850_tess.sort_values(by=['Full Name'], inplace=True)
output_1850_tess.head(10)
# Out:
#                   Full Name  First Name Last Name Middle Name Widow-flag  \
# 41487       . Duryce John L           .                Duryce      False
# 95641   . Terrett Horatio N           .               Terrett      False
# 77255        Brown Morris A       Brown                Morris      False
# 81089              Sullivan    Sullivan                   NaN      False
# 81088                Varick      Varick                   NaN      False
# 60081            Washington  Washington                   NaN      False
# 27442            Washington  Washington                   NaN      False
# 36809                     '         NaN       NaN         NaN      False
# 69448                     '         NaN       NaN         NaN      False
# 73577          ' - . Fulton           -         '           .      False
#
#       Widow Of  Title   Occupation  \
# 41487      NaN    NaN        baths
# 95641      NaN    NaN  stereotyper
# 77255      NaN    NaN       carter
# 81089      NaN    NaN          NaN
# 81088      NaN    NaN          NaN
# 60081      NaN    NaN          NaN
# 27442      NaN    NaN          NaN
# 36809      NaN    NaN          NaN
# 69448      NaN    NaN          NaN
# 73577      NaN    NaN          NaN
#
#                                             Full Address H Status-flag  \
# 41487                    7 , 9 & 11 Catharine, h. 92 E .          True
# 95641  251 Front, h. 48 Lispenard | Thatcher Stephen ...          True
# 77255                               W . 26th n . Av . 10           NaN
# 81089                                                NaN           NaN
# 81088                                                NaN           NaN
# 60081                                                NaN           NaN
# 27442                                                NaN           NaN
# 36809                                        10 Caroline        Assume
# 69448                                        10 Caroline        Assume
# 73577                                 h. Williamsburg on          True
#
#                                H Address H House Number  \
# 41487                             92 E .             92
# 95641  48 Lispenard | Thatcher Stephen D             48
# 77255               W . 26th n . Av . 10             10
# 81089                                NaN            NaN
# 81088                                NaN            NaN
# 60081                                NaN            NaN
# 27442                                NaN            NaN
# 36809                        10 Caroline             10
# 69448                        10 Caroline             10
# 73577                    Williamsburg on            NaN
#
#                            H Street Name              H City  \
# 41487                             92 E .                 NaN
# 95641  48 Lispenard | Thatcher Stephen D                 NaN
# 77255               W . 26th n . Av . 10                 NaN
# 81089                                NaN                 NaN
# 81088                                NaN                 NaN
# 60081                                NaN                 NaN
# 27442                                NaN                 NaN
# 36809                        10 Caroline                 NaN
# 69448                        10 Caroline                 NaN
# 73577                                NaN  [Williamsburg, on]
#
#                   Address 2 Address 2 House Number Address 2 Street Name  \
# 41487  7 , 9 & 11 Catharine                      7  7 , 9 & 11 Catharine
# 95641             251 Front                    251             251 Front
# 77255                   NaN                    NaN                   NaN
# 81089                   NaN                    NaN                   NaN
# 81088                   NaN                    NaN                   NaN
# 60081                   NaN                    NaN                   NaN
# 27442                   NaN                    NaN                   NaN
# 36809                   NaN                    NaN                   NaN
# 69448                   NaN                    NaN                   NaN
# 73577                   NaN                    NaN                   NaN
#
#       Address 2 City
# 41487            NaN
# 95641            NaN
# 77255            NaN
# 81089            NaN
# 81088            NaN
# 60081            NaN
# 27442            NaN
# 36809            NaN
# 69448            NaN
# 73577            NaN

# %%
output_1850_tess = output_1850_tess.loc[output_1850_tess.astype(str).drop_duplicates().index]
len(output_1850_tess)
# Out:
# 78518

# %%
output_1850_tess.head(10)
# Out:
#                Full Name First Name Last Name Middle Name Widow-flag Widow Of  \
# 1         Ackley Addison    Addison    Ackley         NaN      False      NaN
# 2          Adams William    William     Adams         NaN      False      NaN
# 3          Aitkin Thomas     Thomas    Aitkin         NaN      False      NaN
# 4         Albro Benjamin   Benjamin     Albro         NaN      False      NaN
# 5            Allen E . W          E     Allen           .      False      NaN
# 6   Anderson Frederick R  Frederick  Anderson           R      False      NaN
# 7        Anderson John R       John  Anderson           R      False      NaN
# 8           Anthes Peter      Peter    Anthes         NaN      False      NaN
# 9       Anthes & Eckardt          &    Anthes     Eckardt      False      NaN
# 10           Appell John       John    Appell         NaN      False      NaN
#
#     Title   Occupation                                       Full Address  \
# 1     NaN        clerk                           47 Broadway, h. 39 Pearl
# 2     NaN      weigher  20 Washington & 13 West, h. 170 Clinton , Broo...
# 3     NaN  stonecutter                                     601 Washington
# 4     NaN          sen                                         328 Bowery
# 5     NaN    publisher                                          42 Orange
# 6     NaN          mer                             13 Front, h. 77 Barrow
# 7     NaN       seaman                                        586 E , 4th
# 8     NaN          NaN                                          34 Av . C
# 9     NaN      barbers                                          34 Av . C
# 10    NaN       tailor                                          40 Av . C
#
#    H Status-flag               H Address H House Number   H Street Name  \
# 1           True                39 Pearl             39        39 Pearl
# 2           True  170 Clinton , Brooklyn            170   170 Clinton ,
# 3         Assume          601 Washington            601  601 Washington
# 4         Assume              328 Bowery            328      328 Bowery
# 5         Assume               42 Orange             42       42 Orange
# 6           True               77 Barrow             77       77 Barrow
# 7         Assume             586 E , 4th            586     586 E , 4th
# 8            NaN               34 Av . C             34       34 Av . C
# 9         Assume               34 Av . C             34       34 Av . C
# 10        Assume               40 Av . C             40       40 Av . C
#
#       H City                Address 2 Address 2 House Number  \
# 1        NaN              47 Broadway                     47
# 2   Brooklyn  20 Washington & 13 West                     20
# 3        NaN                      NaN                    NaN
# 4        NaN                      NaN                    NaN
# 5        NaN                      NaN                    NaN
# 6        NaN                 13 Front                     13
# 7        NaN                      NaN                    NaN
# 8        NaN                      NaN                    NaN
# 9        NaN                      NaN                    NaN
# 10       NaN                      NaN                    NaN
#
#       Address 2 Street Name Address 2 City
# 1               47 Broadway            NaN
# 2   20 Washington & 13 West            NaN
# 3                       NaN            NaN
# 4                       NaN            NaN
# 5                       NaN            NaN
# 6                  13 Front            NaN
# 7                       NaN            NaN
# 8                       NaN            NaN
# 9                       NaN            NaN
# 10                      NaN            NaN

# %%
#filter those with name and no address
output_1850_tess = output_1850_tess[~output_1850_tess['Full Name'].isna()]

# %%
len(output_1850_tess)
# Out:
# 113606

# %%
output_1850_tess.tail(15)
# Out:
#         Full Name First Name Last Name Middle Name Widow-flag Widow Of  Title  \
# 110288  bedsteads        NaN       NaN         NaN      False      NaN    NaN
# 111652  Greenwich        NaN       NaN         NaN      False      NaN    NaN
# 111654       wich        NaN       NaN         NaN      False      NaN    NaN
# 111728  Greenwich        NaN       NaN         NaN      False      NaN    NaN
# 111730       wich        NaN       NaN         NaN      False      NaN    NaN
# 111979        ket        NaN       NaN         NaN      False      NaN    NaN
# 112078      widow        NaN       NaN         NaN       True    widow    NaN
# 112080          h        NaN       NaN         NaN      False      NaN    NaN
# 112955          i        NaN       NaN         NaN      False      NaN    NaN
# 113188       slip        NaN       NaN         NaN      False      NaN    NaN
# 113210        way        NaN       NaN         NaN      False      NaN    NaN
# 113263        row        NaN       NaN         NaN      False      NaN    NaN
# 113265        Why        NaN       NaN         NaN      False      NaN    NaN
# 113288        way        NaN       NaN         NaN      False      NaN    NaN
# 113319        way        NaN       NaN         NaN      False      NaN    NaN
#
#        Occupation           Full Address H Status-flag           H Address  \
# 110288        NaN                    c .           NaN                 c .
# 111652        NaN           h. 68 Laight          True           68 Laight
# 111654        NaN       h. 410 Greenwich          True       410 Greenwich
# 111728        NaN           h. 63 Laight          True           63 Laight
# 111730        NaN       h. 410 Greenwich          True       410 Greenwich
# 111979        NaN         h. Long Island          True         Long Island
# 112078        NaN       h. 236 Elizabeth          True       236 Elizabeth
# 112080        NaN              321 Fifth           NaN           321 Fifth
# 112955        NaN                    25t           NaN                 25t
# 113188        NaN  h. 39 Lafayette place          True  39 Lafayette place
# 113210        NaN       h. 476} Broadway          True       476} Broadway
# 113263     Crosby    250 Av . 4, Houston          True             Houston
# 113265        NaN             250 Av . 4           NaN          250 Av . 4
# 113288        NaN               W . 28th           NaN            W . 28th
# 113319        NaN          h. 305 Hudson          True          305 Hudson
#
#        H House Number       H Street Name            H City   Address 2  \
# 110288            NaN                 NaN            [c, .]         NaN
# 111652             68           68 Laight               NaN         NaN
# 111654            410       410 Greenwich               NaN         NaN
# 111728             63           63 Laight               NaN         NaN
# 111730            410       410 Greenwich               NaN         NaN
# 111979            NaN                 NaN    [Long, Island]         NaN
# 112078            236       236 Elizabeth               NaN         NaN
# 112080            321           321 Fifth               NaN         NaN
# 112955            NaN                 NaN             [25t]         NaN
# 113188             39  39 Lafayette place               NaN         NaN
# 113210            NaN                 NaN  [476}, Broadway]         NaN
# 113263            NaN                 NaN           Houston  250 Av . 4
# 113265            250          250 Av . 4               NaN         NaN
# 113288            NaN                 NaN      [W, ., 28th]         NaN
# 113319            305          305 Hudson               NaN         NaN
#
#        Address 2 House Number Address 2 Street Name Address 2 City
# 110288                    NaN                   NaN            NaN
# 111652                    NaN                   NaN            NaN
# 111654                    NaN                   NaN            NaN
# 111728                    NaN                   NaN            NaN
# 111730                    NaN                   NaN            NaN
# 111979                    NaN                   NaN            NaN
# 112078                    NaN                   NaN            NaN
# 112080                    NaN                   NaN            NaN
# 112955                    NaN                   NaN            NaN
# 113188                    NaN                   NaN            NaN
# 113210                    NaN                   NaN            NaN
# 113263                    250            250 Av . 4            NaN
# 113265                    NaN                   NaN            NaN
# 113288                    NaN                   NaN            NaN
# 113319                    NaN                   NaN            NaN

# %%
len(output_1850_tess)
# Out:
# 78518

# %%
output_1850_tess = output_1850_tess[~output_1850_tess['Full Address'].isna()]

# %%
len(output_1850_tess)
# Out:
# 77895

# %%
output_1850_tess.head()
# Out:
#                 Full Name First Name Last Name Middle Name Widow-flag  \
# 36809                   '        NaN       NaN         NaN      False
# 73577        ' - . Fulton          -         '           .      False
# 98603               ' . E          .         '           E      False
# 70758  ' Bridge Paulina W     Bridge         '     Paulina       True
# 40993         ' Dudy John       Dudy         '        John      False
#
#       Widow Of  Title        Occupation                      Full Address  \
# 36809      NaN    NaN               NaN                       10 Caroline
# 73577      NaN    NaN               NaN                h. Williamsburg on
# 98603      NaN    NaN               NaN                        . Broadway
# 70758        '    NaN  widow of Lewis K                       40 E . 14th
# 40993      NaN    NaN           laborer  3 Sixth Duffy John, 114 Mulberry
#
#       H Status-flag        H Address H House Number H Street Name  \
# 36809        Assume      10 Caroline             10   10 Caroline
# 73577          True  Williamsburg on            NaN           NaN
# 98603        Assume       . Broadway            NaN           NaN
# 70758        Assume      40 E . 14th             40   40 E . 14th
# 40993          True     114 Mulberry            114  114 Mulberry
#
#                    H City           Address 2 Address 2 House Number  \
# 36809                 NaN                 NaN                    NaN
# 73577  [Williamsburg, on]                 NaN                    NaN
# 98603       [., Broadway]                 NaN                    NaN
# 70758                 NaN                 NaN                    NaN
# 40993                 NaN  3 Sixth Duffy John                      3
#
#       Address 2 Street Name Address 2 City
# 36809                   NaN            NaN
# 73577                   NaN            NaN
# 98603                   NaN            NaN
# 70758                   NaN            NaN
# 40993    3 Sixth Duffy John            NaN

# %%
output_1850_tess = output_1850_tess[output_1850_tess['Full Name'].str.len() > 1]

# %%
len(output_1850_tess)
# Out:
# 76197

# %%
output_1850_tess = output_1850_tess[~output_1850_tess['Full Address'].isna()]
len(output_1850_tess)
# Out:
# 76197

# %%
output_1850_tess.to_csv('output_1850_tess.csv')

# %%
len(output_1850_tess)
# Out:
# 109336

# %%
output_1850_tess.head(15)
# Out:
#                                                Full Name First Name Last Name  \
# 73577                                       ' - . Fulton          -         '
# 98603                                              ' . E          .         '
# 70758                                 ' Bridge Paulina W     Bridge         '
# 8294                                         ' Dudy John       Dudy         '
# 40993                                        ' Dudy John       Dudy         '
# 10667                         ' FARMERS' LOAN & TRUST CO   FARMERS'         '
# 43357  ' FARMERS' LOAN & TRUST CO . 28 Exchange pl . ...   FARMERS'         '
# 43371                             ' Farnham P . J . & Co    Farnham         '
# 10692                             ' Farnham P . J . & Co    Farnham         '
# 55464                                  ' Hollings Martin   Hollings         '
# 22825                                  ' Hollings Martin   Hollings         '
# 55487                                   ' Holloran James   Holloran         '
# 22848                                   ' Holloran James   Holloran         '
# 55505                                   ' Hollwegs Jacob   Hollwegs         '
# 22866                                   ' Hollwegs Jacob   Hollwegs         '
#
#       Middle Name Widow-flag Widow Of  Title        Occupation  \
# 73577           .      False      NaN    NaN               NaN
# 98603           E      False      NaN    NaN               NaN
# 70758     Paulina       True        '    NaN  widow of Lewis K
# 8294         John      False      NaN    NaN         shoemaker
# 40993        John      False      NaN    NaN           laborer
# 10667        LOAN      False      NaN    NaN               NaN
# 43357        LOAN      False      NaN    NaN           laborer
# 43371           P      False      NaN    NaN           laborer
# 10692           P      False      NaN    NaN         importers
# 55464      Martin      False      NaN    NaN            grocer
# 22825      Martin      False      NaN    NaN            grocer
# 55487       James      False      NaN    NaN         shoemaker
# 22848       James      False      NaN    NaN         shoemaker
# 55505       Jacob      False      NaN    NaN            grocer
# 22866       Jacob      False      NaN    NaN            grocer
#
#                                Full Address H Status-flag  \
# 73577                    h. Williamsburg on          True
# 98603                            . Broadway        Assume
# 70758                           40 E . 14th        Assume
# 8294                                3 Sixth        Assume
# 40993      3 Sixth Duffy John, 114 Mulberry          True
# 10667                    28 Exchange pl . |        Assume
# 43357                            200 Second        Assume
# 43371  85 Pearl Farrell William, 491 Av . 6          True
# 10692                              85 Pearl        Assume
# 55464                          125 Franklia        Assume
# 22825                          125 Franklia        Assume
# 55487            137 Anthony sau , Brooklyn        Assume
# 22848            137 Anthony sau , Brooklyn        Assume
# 55505             59 Mulverry, h. 59 Mulbry          True
# 22866             59 Mulverry, h. 59 Mulbry          True
#
#                         H Address H House Number               H Street Name  \
# 73577             Williamsburg on            NaN                         NaN
# 98603                  . Broadway            NaN                         NaN
# 70758                 40 E . 14th             40                 40 E . 14th
# 8294                      3 Sixth              3                     3 Sixth
# 40993                114 Mulberry            114                114 Mulberry
# 10667          28 Exchange pl . |             28          28 Exchange pl . |
# 43357                  200 Second            200                  200 Second
# 43371                  491 Av . 6            491                  491 Av . 6
# 10692                    85 Pearl             85                    85 Pearl
# 55464                125 Franklia            125                125 Franklia
# 22825                125 Franklia            125                125 Franklia
# 55487  137 Anthony sau , Brooklyn            137  137 Anthony sau , Brooklyn
# 22848  137 Anthony sau , Brooklyn            137  137 Anthony sau , Brooklyn
# 55505                   59 Mulbry             59                   59 Mulbry
# 22866                   59 Mulbry             59                   59 Mulbry
#
#                    H City                 Address 2 Address 2 House Number  \
# 73577  [Williamsburg, on]                       NaN                    NaN
# 98603       [., Broadway]                       NaN                    NaN
# 70758                 NaN                       NaN                    NaN
# 8294                  NaN                       NaN                    NaN
# 40993                 NaN        3 Sixth Duffy John                      3
# 10667                 NaN                       NaN                    NaN
# 43357                 NaN                       NaN                    NaN
# 43371                 NaN  85 Pearl Farrell William                     85
# 10692                 NaN                       NaN                    NaN
# 55464                 NaN                       NaN                    NaN
# 22825                 NaN                       NaN                    NaN
# 55487                 NaN                       NaN                    NaN
# 22848                 NaN                       NaN                    NaN
# 55505                 NaN               59 Mulverry                     59
# 22866                 NaN               59 Mulverry                     59
#
#           Address 2 Street Name Address 2 City
# 73577                       NaN            NaN
# 98603                       NaN            NaN
# 70758                       NaN            NaN
# 8294                        NaN            NaN
# 40993        3 Sixth Duffy John            NaN
# 10667                       NaN            NaN
# 43357                       NaN            NaN
# 43371  85 Pearl Farrell William            NaN
# 10692                       NaN            NaN
# 55464                       NaN            NaN
# 22825                       NaN            NaN
# 55487                       NaN            NaN
# 22848                       NaN            NaN
# 55505               59 Mulverry            NaN
# 22866               59 Mulverry            NaN

# %%
output_1850_tess = output_1850_tess[output_1850_tess['Full Name'].str.len() > 3]

# %%
len(output_1850_tess)
# Out:
# 75644

# %%
output_1850_tess.head(15)
# Out:
#                                                Full Name First Name Last Name  \
# 73577                                       ' - . Fulton          -         '
# 98603                                              ' . E          .         '
# 70758                                 ' Bridge Paulina W     Bridge         '
# 8294                                         ' Dudy John       Dudy         '
# 40993                                        ' Dudy John       Dudy         '
# 10667                         ' FARMERS' LOAN & TRUST CO   FARMERS'         '
# 43357  ' FARMERS' LOAN & TRUST CO . 28 Exchange pl . ...   FARMERS'         '
# 43371                             ' Farnham P . J . & Co    Farnham         '
# 10692                             ' Farnham P . J . & Co    Farnham         '
# 55464                                  ' Hollings Martin   Hollings         '
# 22825                                  ' Hollings Martin   Hollings         '
# 55487                                   ' Holloran James   Holloran         '
# 22848                                   ' Holloran James   Holloran         '
# 55505                                   ' Hollwegs Jacob   Hollwegs         '
# 22866                                   ' Hollwegs Jacob   Hollwegs         '
#
#       Middle Name Widow-flag Widow Of  Title        Occupation  \
# 73577           .      False      NaN    NaN               NaN
# 98603           E      False      NaN    NaN               NaN
# 70758     Paulina       True        '    NaN  widow of Lewis K
# 8294         John      False      NaN    NaN         shoemaker
# 40993        John      False      NaN    NaN           laborer
# 10667        LOAN      False      NaN    NaN               NaN
# 43357        LOAN      False      NaN    NaN           laborer
# 43371           P      False      NaN    NaN           laborer
# 10692           P      False      NaN    NaN         importers
# 55464      Martin      False      NaN    NaN            grocer
# 22825      Martin      False      NaN    NaN            grocer
# 55487       James      False      NaN    NaN         shoemaker
# 22848       James      False      NaN    NaN         shoemaker
# 55505       Jacob      False      NaN    NaN            grocer
# 22866       Jacob      False      NaN    NaN            grocer
#
#                                Full Address H Status-flag  \
# 73577                    h. Williamsburg on          True
# 98603                            . Broadway        Assume
# 70758                           40 E . 14th        Assume
# 8294                                3 Sixth        Assume
# 40993      3 Sixth Duffy John, 114 Mulberry          True
# 10667                    28 Exchange pl . |        Assume
# 43357                            200 Second        Assume
# 43371  85 Pearl Farrell William, 491 Av . 6          True
# 10692                              85 Pearl        Assume
# 55464                          125 Franklia        Assume
# 22825                          125 Franklia        Assume
# 55487            137 Anthony sau , Brooklyn        Assume
# 22848            137 Anthony sau , Brooklyn        Assume
# 55505             59 Mulverry, h. 59 Mulbry          True
# 22866             59 Mulverry, h. 59 Mulbry          True
#
#                         H Address H House Number               H Street Name  \
# 73577             Williamsburg on            NaN                         NaN
# 98603                  . Broadway            NaN                         NaN
# 70758                 40 E . 14th             40                 40 E . 14th
# 8294                      3 Sixth              3                     3 Sixth
# 40993                114 Mulberry            114                114 Mulberry
# 10667          28 Exchange pl . |             28          28 Exchange pl . |
# 43357                  200 Second            200                  200 Second
# 43371                  491 Av . 6            491                  491 Av . 6
# 10692                    85 Pearl             85                    85 Pearl
# 55464                125 Franklia            125                125 Franklia
# 22825                125 Franklia            125                125 Franklia
# 55487  137 Anthony sau , Brooklyn            137  137 Anthony sau , Brooklyn
# 22848  137 Anthony sau , Brooklyn            137  137 Anthony sau , Brooklyn
# 55505                   59 Mulbry             59                   59 Mulbry
# 22866                   59 Mulbry             59                   59 Mulbry
#
#                    H City                 Address 2 Address 2 House Number  \
# 73577  [Williamsburg, on]                       NaN                    NaN
# 98603       [., Broadway]                       NaN                    NaN
# 70758                 NaN                       NaN                    NaN
# 8294                  NaN                       NaN                    NaN
# 40993                 NaN        3 Sixth Duffy John                      3
# 10667                 NaN                       NaN                    NaN
# 43357                 NaN                       NaN                    NaN
# 43371                 NaN  85 Pearl Farrell William                     85
# 10692                 NaN                       NaN                    NaN
# 55464                 NaN                       NaN                    NaN
# 22825                 NaN                       NaN                    NaN
# 55487                 NaN                       NaN                    NaN
# 22848                 NaN                       NaN                    NaN
# 55505                 NaN               59 Mulverry                     59
# 22866                 NaN               59 Mulverry                     59
#
#           Address 2 Street Name Address 2 City
# 73577                       NaN            NaN
# 98603                       NaN            NaN
# 70758                       NaN            NaN
# 8294                        NaN            NaN
# 40993        3 Sixth Duffy John            NaN
# 10667                       NaN            NaN
# 43357                       NaN            NaN
# 43371  85 Pearl Farrell William            NaN
# 10692                       NaN            NaN
# 55464                       NaN            NaN
# 22825                       NaN            NaN
# 55487                       NaN            NaN
# 22848                       NaN            NaN
# 55505               59 Mulverry            NaN
# 22866               59 Mulverry            NaN

# %%
#names that are not 2 or three words long
n = len(entry_dict)
count = 0
namelengths =[]
for i in range(1,n+1):
    try:
        name = ast.literal_eval(entry_dict[str(i)])['subjects'][0]
        name = name.split()
        if(len(name) != 2 and len(name) != 3):
            print(name, len(name))
            count += 1
            namelengths.append(len(name))
    except:
        pass
print(count)
print(namelengths)
# Out:
# ['Allen', 'E', '.', 'W'] 4
# ['Barrowclough', 'James', ',', 'E'] 4
# ['Amerman', 'Geo', '.', 'V'] 4
# ['Amerman', 'O', '.', 'V', '.', '(Rev'] 6
# ['Amerman', 'Wm', '.', 'C'] 4
# ['Amswick', 'L', '.', 'E'] 4
# ['Anderson', 'Chas', '.', 'F'] 4
# ['Anderson', 'Eliza', 'J', '.', '(col’d)', 'wid', '.', 'Thos'] 8
# ['Anderson', 'Jas', '.', 'J'] 4
# ['Anderson', 'James', 'W', '.', 'Broadway'] 5
# ['Anderson', 'John', '&', 'Co'] 4
# ['Anderson', 'John', 'H', '.', '&', 'Co'] 6
# ['Anderson', 'Robert', 'S', '.', 'N'] 5
# ['Anderson', 'Wm', '.', 'Theodore'] 4
# ['Andersén', 'C', '.', 'V', '.', '&', 'J'] 7
# ['Anderson', ',', 'Ritter', '&', 'Co'] 5
# ['ANDERSON', ',', 'STARR', '&', 'CO', '.'] 6
# ['Anderton', 'Ralph', '.', 'L'] 4
# ['Andrews', 'F', '.', 'A'] 4
# ['Andrews', 'Loring', '&', 'Co'] 4
# ['Andrews', 'Robt', '.', 'J'] 4
# ['Andrews', '§', '.', 'B'] 4
# ['Andrews', 'Thomas', 'M', '.', '15', 'Cortlandt'] 6
# ['Andrews', 'Wm', '.', 'D'] 4
# ['Andrews', 'Wm', '.', 'M'] 4
# ['Andrews', 'B', '.', '&', 'Co'] 5
# ['ANGEVINE', 'DANIEL', '&', 'LEVI'] 4
# ['Anner', 'Jas', '.', 'H'] 4
# ['Anthon', 'Wm', '.', 'H'] 4
# ['Anthony', 'William', 'R', '.', '4', 'Mer', '.', 'Ex'] 8
# ['Anthony', 'C', '.', 'L', '.', '&', 'Co'] 7
# ['APGAR', 'LEVI', '&', 'CO'] 4
# ['Appleby', 'Leonard', 'L', '.', 'F'] 5
# ['Appleton', 'John', 'W', '.', 'V'] 5
# ['Archer', 'Wm', '.', 'A'] 4
# ['Armstrong', 'Math’w', '&', 'Sons'] 4
# ['Arcularius', 'P', '.', 'G', '.', '&', 'Co'] 7
# ['Arcularius', ',', 'Bonnett', '&', 'Co'] 5
# ['Armstrong', 'Wm', '.', 'H'] 4
# ['Armstrong', 'Wm', '.', '8'] 4
# ['Armstrong', 'Wm', '.', 'V', '.', 'R'] 6
# ['Arnesen', 'Fred', '.', 'E'] 4
# ['t', 'Arnheimer', '&', 'Kats'] 4
# ['Arnold', 'Saml', '.', 'B'] 4
# ['Arnold', 'W', '.', 'E'] 4
# ['Arnold', 'Welcome', 'V', '.', 'R'] 5
# ['ARNOLD', 'A', '.', '&', 'CO'] 5
# ['Arnold', 'D', '.', 'H', '.', '&', 'Co'] 7
# ['ARN', 'OLD', '&', 'SOUTHWORTH'] 4
# ['Arnold', ',', 'Beeman', '&', 'Co'] 5
# ['ARNOUX', 'A', '.', '&', 'G', '.', 'A'] 7
# ['Arrosmith', 'Samuel', 'Y', '.', 'D'] 5
# ['Arrowsmith', '&', 'Co', '.'] 4
# ['Arthur', 'E', '.', 'H'] 4
# ['Arthur', 'Jacob', 'F', '.'] 4
# ['Arthur', 'Jahne', '&', 'Co'] 4
# ['Arthur', 'Wm', '.', 'C'] 4
# ['Arthur', 'Wm', '.', 'H'] 4
# ['Ashe', 'Wm', '.', 'A'] 4
# ['Ashley', 'L', '.', 'Seymour'] 4
# ['Ashwin', 'Wm', '.', 'M'] 4
# ['Asten', 'Wm', '.', 'B'] 4
# ['ASTOR', 'MUTUAL', 'INS', '.', 'CO', '.', 'William', 'c'] 8
# ['Atkins', 'Chas', '.', 'A'] 4
# ['Atkins', 'Chas', '.', 'H'] 4
# ['ATKINS', 'JOSHUA', '&', 'CO'] 4
# ['Atkins', 'W', '.', 'D'] 4
# ['Atkinson', 'C', '.', 'F'] 4
# ['ATLANTIC', 'MUTUAL', 'INSURANCE', 'CO'] 4
# ['Atlee', 'W', '.', 'Putnam'] 4
# ['Atterbury', 'B', '.', 'Bakewell'] 4
# ['Atwater', 'J', '.', 'G', '.', 'E'] 6
# ['Atwater', ',', 'Gould', '&', 'Co'] 5
# ['ATWATER', ',', 'MULFORD', '&', 'CO'] 5
# ['Atwater', ',', 'Knapp', '&', 'Woodruff'] 5
# ['Atwood', ',', 'Larkin', '&', 'Co'] 5
# ['Atwood', 'Wm', '.', 'T'] 4
# ['AUCHINCLOSS', 'HUGH', '&', 'SONS'] 4
# ['AUDUBON', 'V', '.', 'G'] 4
# ['Audubon', 'Victor', 'G', '.', '&', 'Co'] 6
# ['AUGUSTA', '(Georgia)', 'INSURANCE', '&', 'BANKING', 'Co', '.'] 7
# ['Austen', 'Geo', '.', 'W'] 4
# ['Austin', 'Fred', '.', 'J'] 4
# ['Doane', 'A', '.', 'Sidney'] 4
# ['Ferris', 'S', '.', 'A'] 4
# ['Foster', '8', '.', 'R'] 4
# ['Francis', 'J', '.', 'M'] 4
# ['Lawrance', 'F', '.', 'C', '.', '&', 'Co'] 7
# ['LEFMAN', 'HENRY', '&', 'CO'] 4
# ['PERKINS', ',', 'WARREN', '&', 'CO'] 5
# ['Boerem', 'A', '.', 'M'] 4
# ['Bogardus', 'C', '.', '8'] 4
# ['Bogardus', 'G', ',', 'M'] 4
# ['Bogardus', 'William', '.', 'H'] 4
# ['DOQSL', 'UPVIIAG', 'Ihe', 'MELGMEL'] 4
# ['Bogert', 'Benj', '.', 'C'] 4
# ['Bogert', 'J', '.', 'Augustus'] 4
# ['Bogert', 'John', 'M', '.', 'B'] 5
# ['Bogert', 'Wm', '.', '8'] 4
# ['Bogert', ',', 'Brown', '&', 'Co'] 5
# ['Bohde', 'F', '.', '&', 'Co'] 5
# ['Bohnsted', 'F', '.', 'W'] 4
# ['Boisseau', 'Jas', '.', 'E'] 4
# ['Bolles', 'Wm', '.', 'B'] 4
# ['Bolster', 'I', 'Henry', 'B'] 4
# ['Bond', 'J', ',', 'Edwin'] 4
# ['Bond', 'Joseph', 'N', ',', 'B'] 5
# ['Bonnel', 'Mahlon', '&', 'Sons'] 4
# ['Bonner', 'Gustav', '&', 'Co'] 4
# ['Ay', 'ULEAD', 'Se', 'VGA', ',', 'APRA', 'LAY', 'MUGLUS'] 8
# ['Bood', 'C', '.', 'Robert'] 4
# ['Boon', 'Von', 'Ostade', 'John', 'J'] 5
# ['BOORMAN', ',', 'JOHNSTON', '&', 'CO'] 5
# ['Bord', 'Geo', '.', 'F'] 4
# ['Borden', 'Wm', '.', 'D'] 4
# ['Born', 'C', '.', 'George'] 4
# ['Bostwick', 'C', '.', 'B'] 4
# ['BOSTWICK', ',', 'KENT', '&', 'ATWOOD'] 5
# ['BOUCHAUD', ',', 'THEBAUD', '&', 'CO'] 5
# ['Boucher', 'Pierre', 'L', '.', 'W'] 5
# ['BOUCK', 'BROTHER', '&', 'CO'] 4
# ['BOUGHTON', ',', 'WARD', '&', 'SPARKS'] 5
# ['BOURRY', 'DIVERNGOIS', '&', 'CO'] 4
# ['Bouton', 'Seymour', 'St', '.', 'John'] 5
# ['Bovers', 'Eibe', '&', 'Fred'] 4
# ['Bowen', 'Hen', '.', 'Â©'] 4
# ['Bowen', 'W', '.', 'B'] 4
# ['Bowen', 'Wm', '.', 'H'] 4
# ['BOWIE', 'JOHN', 'H', '.', '&', 'CO'] 6
# ['Bowie', 'J', '.', 'S', '.', '&', 'L'] 7
# ['Boyd', 'Robt', '.', 'B'] 4
# ['Boyd', 'Robt', '.', 'H'] 4
# ['Boyd', 'Wm', '.', 'A'] 4
# ['Boyd', 'Wm', '.', 'L'] 4
# ['Boyer', 'Edwd', '.', 'F'] 4
# ['Boyle', 'F', '.', 'T', '.', 'R'] 6
# ['Brace', 'Thos', '.', 'K', '.', 'jr'] 6
# ['Braddick', 'Wm', '.', 'H'] 4
# ['Bradford', 'Frances', '(colâ€™d)', 'wid', '.', 'of', 'John', 'W'] 8
# ['Bradford', 'Geo', '.', 'P'] 4
# ['Bradford', 'J', '.', 'S'] 4
# ['Bradford', 'Nath', '.', 'G'] 4
# ['Bradford', 'Wm', '.', '(Rev'] 4
# ['Bradley', 'E', '.', 'W', '.', 'jr'] 6
# ['Bradley', 'Fred', '.', 'A'] 4
# ['Bradley', 'Wm', '.', 'C'] 4
# ['BRADLEY', ',', 'MILLS', '&', 'BECKWITH'] 5
# ['Bradshaw', 'Jos', '.', 'W'] 4
# ['Bradshaw', 'Wm', '.', 'A'] 4
# ['Brady', 'A', '.', '&', 'G', '.', 'W'] 7
# ['Brady', ',', 'Anderson', '&', 'Co'] 5
# ['Bragg', 'A', '.', '&', 'Co', '.'] 6
# ['Brahe', 'A', '.', 'H', '.', '&', 'Co'] 7
# ['BRAIN', 'E', '.', 'T', '.', '&', 'Co'] 7
# ['Brainerd', ',', 'Geftroy', '&', 'Babcock'] 5
# ['Braisted', 'Peter', 'D', '.', 'jr'] 5
# ['Braisted', 'Wm', '.', 'C'] 4
# ['Braisted', 'Wm', '.', 'H'] 4
# ['Braman', 'Wm', '.', 'H'] 4
# ['Bramhall', ',', 'Abernethy', '&', 'Collins'] 5
# ['BRAMWELL', 'JOSEPH', ',', '&', 'CO'] 5
# ['Branch', 'Heny', '.', 'E'] 4
# ['DIGMUE', 'RES', 'oe', 'Us', '.', 'BW', 'LUEITUY', 'pa', '.', 'Brawley', 'Robert'] 11
# ['Brandeis', 'L', '.', '&', 'Co'] 5
# ['Brandon', 'A', '.', '&', '.', 'G'] 6
# ['Brandt', 'Geo', '.', 'F'] 4
# ['Brant', 'Wm', '.', 'H'] 4
# ['Breck', 'Ben}', '.', 'D'] 4
# ['Breck', 'Chas', '.', 'E'] 4
# ['Breese', 'J', '.', 'S'] 4
# ['Brehaut', 'Ann', 'M', '.', 'widow', 'Nicholas'] 6
# ['Breidenbah', 'I', '.', 'H', '.', 'jr'] 6
# ['Breinig', 'Peter', 'B', '.', 'jr'] 5
# ['Breisach', 'L', '.', 'R'] 4
# ['BREITHAUPT', 'P', '.', 'A', '.', '&', 'CHUN'] 7
# ['Breitschwerdt', 'John', 'G', '.', 'F'] 5
# ['Bremen', 'Steam', 'Navigation', 'Line'] 4
# ['Bremner', 'And', '.', 'A'] 4
# ['Bremner', 'Hen', '.', 'H'] 4
# ['Brennan', 'George', '8', '.'] 4
# ['BRENNAN', 'J', '.', '&', 'CO'] 5
# ['Bresland', 'Pat', '.', 'B'] 4
# ['Brett', 'Philip', 'M', '.', '(Rev'] 5
# ['Brett', 'Theo', '.', 'F'] 4
# ['Brewster', 'Jas', '.', 'B'] 4
# ['Abbatt', 'Wm', '.', 'D', '.', '&', 'Co'] 7
# ['ABBOT', 'ABIEL', '&', 'SON'] 4
# ['way'] 1
# ['ABBOT', ',', 'DODGE', '&', 'CO'] 5
# ['Abbott', 'Benjamin', 'V', '.', 'C'] 5
# ['ABBOTT', 'GORHAM', 'D', '.', '(Rev'] 5
# ['ABBOTT', 'JOHN', 'S', '.', 'C', '.', '(Rev'] 7
# ['Abbott', 'Sarah', 'M', '.', 'wid', '.', 'Samuel'] 7
# ['Abeel', 'John', 'H', '.', '&', 'CO'] 6
# ['Abel', 'P', '.', 'Henry'] 4
# ['Abendroth', 'Wm', '.', 'P'] 4
# ['Aborn', 'Robt', '.', 'W'] 4
# ['NNN', 'OREO', 'INNA', 'EAD', 'Ew'] 5
# ['Briddon', 'Chas', '.', 'K'] 4
# ['Bridge', 'Edward', '&', 'Co'] 4
# ['â€˜', 'Bridge', 'Paulina', 'W'] 4
# ['Bridgens', 'W', '.', 'H'] 4
# ['Bridges', 'W', '.', 'E'] 4
# ['Bridges', ',', 'Woodman', '&', 'Black'] 5
# ['Bridgwood', 'Thos', '.', 'H'] 4
# ['Brieder', 'Chas', '.', 'A'] 4
# ['Briest', 'Susan', 'E', '.', 'widow'] 5
# ['Briggs', 'E', '.', 'P'] 4
# ['Briggs', 'George', 'W', '.', 'M'] 5
# ['Briggs', 'Wm', '.', 'D'] 4
# ['Briggs', 'Wm', '.', 'E'] 4
# ['BRIGGS', 'J', '.', '&', 'N'] 5
# ['Brigham', 'John', 'C', ',', '(Rev'] 5
# ['Brigham', 'Wm', '.', 'H'] 4
# ['Briggs', 'D', 'avid', 'R'] 4
# ['Abrahams', 'Abhm', '.', 'S'] 4
# ['Ackerman', 'Jas', '.', 'D'] 4
# ['Ackerman', 'John', 'V', '.', 'W'] 5
# ['Ackerman', 'Melancthon', 'B', '.', 'D'] 5
# ['Ackerman', 'P', '.', 'Curtis'] 4
# ['Ackerman', 'Thos', '.', 'C'] 4
# ['Acton', 'Thos', '.', 'C'] 4
# ['Adams', 'J', '.', 'W'] 4
# ['Adams', 'Thomas', '&', 'Co'] 4
# ['Adams', 'Wm', '.', 'B'] 4
# ['ADAMS', 'C', '.', '&', 'CO'] 5
# ['Adams', 'H', '.', '&', 'C'] 5
# ['Adams', 'J', '.', 'F', '.', '&', 'Co'] 7
# ['Adams', 'P', '.', 'W', '.', '&', 'Co'] 7
# ['Addicks', 'T', '.', 'William'] 4
# ['Adema', 'M', ',', 'Catherine'] 4
# ['AIBRTIGI', 'Wile', 'lhesy', 'CULAR', 'LUO'] 5
# ['Akerly', 'Rich', '.', 'C'] 4
# ['Akerly', 'R', '.', 'C', '.', '&', 'Co'] 7
# ['ALBANY', '&', 'CANAL', 'LINE'] 4
# ['Albertson’Maria', ',', 'wid', '.', 'John'] 5
# ['Albion', 'Life', 'Insurance', 'Company'] 4
# ['_', 'Albro', 'George', 'A'] 4
# ['Alcock', 'Samuel', '&', 'Co'] 4
# ['ALLAIRE', 'ANTHONY', 'J', '.', '&', 'CO'] 6
# ['Allaire', 'Ewd', '.', 'C'] 4
# ['Allen', 'A', '.', 'B'] 4
# ['Allen', 'Abraham', '&', 'Co'] 4
# ['Allen', 'Jas', '.', 'H'] 4
# ['Allen', 'Jona', '.', 'W'] 4
# ['Allen', 'Jos', '.', 'S'] 4
# ['Allen', 'Thomas', 'E', '.', '\\', '&', 'Son'] 7
# ['ALTHAUSE', '8', '.', 'B', '.', '&', 'CO'] 7
# ['Althof', 'L', '.', '&', 'Co'] 5
# ['Althof', 'L', '.', '&', 'Co'] 5
# ['Altmayer', 'Aaron', '&', 'Brother'] 4
# ['Alton', 'J', '.', '&', 'Co'] 5
# ['ALTON', 'W', '.', 'S'] 4
# ['Alvord', 'Chas', '.', 'F'] 4
# ['Amburger', 'Chas', '.', 'W'] 4
# ['American', 'and', 'Foreign', 'Bible', 'Society'] 5
# ['AMERICAN', '&', 'HOWE', 'PIN', 'COMPANY'] 5
# ['American', 'Baptist', 'Home', 'Mission', 'Soc'] 5
# ['AMERICAN', 'FEMALE', 'GUARDIAN', 'SOCIETY'] 4
# ['AMERICAN', 'HOME', 'MISSIONARY', 'SOCIETY'] 4
# 260
# [4, 4, 4, 6, 4, 4, 4, 8, 4, 5, 4, 6, 5, 4, 7, 5, 6, 4, 4, 4, 4, 4, 6, 4, 4, 5, 4, 4, 4, 8, 7, 4, 5, 5, 4, 4, 7, 5, 4, 4, 6, 4, 4, 4, 4, 5, 5, 7, 4, 5, 7, 5, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 6, 5, 5, 5, 5, 4, 4, 4, 6, 7, 4, 4, 4, 4, 4, 4, 7, 4, 5, 4, 4, 4, 4, 4, 4, 4, 5, 4, 5, 5, 4, 4, 4, 4, 4, 5, 4, 4, 8, 4, 5, 5, 4, 4, 4, 4, 5, 5, 5, 4, 5, 4, 5, 4, 4, 4, 4, 6, 7, 4, 4, 4, 4, 4, 6, 6, 4, 8, 4, 4, 4, 4, 6, 4, 4, 5, 4, 4, 7, 5, 6, 7, 7, 5, 5, 4, 4, 4, 5, 5, 4, 11, 5, 6, 4, 4, 4, 4, 4, 6, 6, 5, 4, 7, 5, 4, 4, 4, 4, 5, 4, 5, 4, 4, 7, 4, 1, 5, 5, 5, 7, 7, 6, 4, 4, 4, 5, 4, 4, 4, 4, 4, 5, 4, 4, 5, 4, 5, 4, 4, 5, 5, 4, 4, 4, 4, 5, 5, 4, 4, 4, 4, 4, 4, 5, 5, 7, 7, 4, 4, 5, 4, 7, 4, 5, 4, 4, 4, 6, 4, 4, 4, 4, 4, 4, 7, 7, 5, 5, 4, 5, 4, 4, 4, 5, 5, 5, 4, 4]

# %%
'Wid' in ast.literal_eval(entry_dict['103'])['occupations'][0]
# Out:
# False

# %%
entry_dict['113536']
# Out:
# '{"subjects": [], "occupations": [], "locations": [{"value": "34th n , Av . 9"}]}'

# %%
full_entry[113535]
# Out:
# '113536 34th n, Av. 9'
