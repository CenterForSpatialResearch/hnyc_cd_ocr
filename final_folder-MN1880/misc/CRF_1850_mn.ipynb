# %%
# !pip install sklearn-crfsuite
# Out:
# Requirement already satisfied: sklearn-crfsuite in c:\users\himab\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: tabulate in c:\users\himab\anaconda3\lib\site-packages (from sklearn-crfsuite) (0.8.7)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\himab\anaconda3\lib\site-packages (from sklearn-crfsuite) (0.9.7)
# Requirement already satisfied: six in c:\users\himab\anaconda3\lib\site-packages (from sklearn-crfsuite) (1.14.0)
# Requirement already satisfied: tqdm>=2.0 in c:\users\himab\anaconda3\lib\site-packages (from sklearn-crfsuite) (4.43.0)

# %%
import nltk
import sklearn_crfsuite
from sklearn_crfsuite import metrics
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd
import re
import scipy
import pickle
import json

# %%
# Prepare training and test data
def prepare_data(path):
    df = pd.read_csv(path, engine = "python")
    sents = []
    record = []
    cur = df['number'][0]
    for index,row in df.iterrows():
        if row['number'] != cur:
            sents.append(record)
            record = [(row['pos'], row['tag'])]
        else:
            record.append((row['pos'], row['tag']))
        cur = row['number']
    sents.append(record)

    return sents

# %%
train_sents = prepare_data("1850_train_mn.csv")
validation_sents = prepare_data("1850_validation_mn.csv")

# %% [markdown]
# Show an example of data

# %%
train_sents[0]
# Out:
# [('START', 'START'),
#  ('Otersen', 'NC'),
#  ('Casten', 'NC'),
#  (',', 'D'),
#  ('produce', 'OC'),
#  (',', 'D'),
#  ('h', 'PA'),
#  ('149', 'AC'),
#  ('Franklin', 'AC'),
#  ('END', 'END')]

# %% [markdown]
# Define CRF features
# Feature Explanation
#
# is_junior_token: does it equal "jr"?
#
# is_widow_token: does it equal "widow"?
#
# contains_digit: does it contain any number?
#
# is_delimiter: is it a delimiter?
#
# is_start: start of record?
#
# is_end: end of record?
#
# is_lower: all lowercase letters?
#
# is_upper: all uppercase letters?

# %%
def is_junior_token(input):
        dc = input.lower()
        if dc == "jr":
            return True
        return False

def is_widow_token(input):
        dc = input.lower()
        if dc == "wid." or dc == "widow":
            return True
        return False

def contains_digit(input):
        for c in input:
            if c.isdigit():
                return True
        return False

def is_delimiter(input):
        for c in input:
            if c == '.' or c == ',':
                return True
        return False

def is_start(input):
        if input == "START":
            return True
        return False

def is_end(input):
        if input == "END":
            return True
        return False

# %% [markdown]
# Notice that features are not only generated on the current word, but also previous and next word.

# %%
def word2features(sent, i):
    word = sent[i][0]

    features = {
        'bias': 1.0,
        'is_junior_token': is_junior_token(word),
        'is_widow_token': is_widow_token(word),
        'contains_digit': contains_digit(word),
        'is_delimiter': is_delimiter(word),
        'is_start': is_start(word),
        'is_end': is_end(word),
        'is_lower': word.islower(),
        'is_title': word.istitle(),
        'is_upper': word.isupper(),
        'substr[-2:]': word[-2:],
        'substr[-1:]': word[-1:]
    }

    if i == 0:
      features.update({'BOS':True})
    elif i == len(sent) - 1:
      features.update({'EOS':True})
    else:
      word_prev = sent[i-1][0]
      word_next = sent[i+1][0]
      features.update({'prev_is_lower': word_prev.islower(), 
                       'prev_is_title': word_prev.istitle(),
                       'prev_is_upper': word_prev.isupper(),
                       'prev_is_delimiter': is_delimiter(word_prev),
                       'next_is_lower': word_next.islower(),
                       'next_is_title': word_next.istitle(),
                       'next_is_upper': word_next.isupper(),
                       'next_contains_digit': contains_digit(word_next),
                       'next_is_end': is_end(word_next)})
    
    return features

# %%
def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for word, label in sent]

# %%
# Extract features from data
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]
X_validation = [sent2features(s) for s in validation_sents]
y_validation = [sent2labels(s) for s in validation_sents]

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=500,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# C:\Users\himab\Anaconda3\lib\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=True,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=500,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %% [markdown]
# Evaluation
#
# Precision, recall and f1-score are used as evaluation metrics.
#
# A detailed explanation on metrics: https://medium.com/analytics-vidhya/pos-tagging-using-conditional-random-fields-92077e5eaa31

# %%
labels = list(crf.classes_)
y_pred = crf.predict(X_validation)
metrics.flat_f1_score(y_validation, y_pred,
                      average='weighted', labels=labels)
# Out:
# 0.9876333689517943

# %% [markdown]
# Notice that evaluation metrics are applied to each category (AC, NC, PA etc.)

# %%
# Metrics by label
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_validation, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#            D      1.000     0.963     0.981        54
#           PA      1.000     1.000     1.000        21
#           AC      0.989     1.000     0.995        94
#           NC      0.975     0.987     0.981        79
#           OC      0.955     0.955     0.955        22
#          END      1.000     1.000     1.000        27
#        START      1.000     1.000     1.000        27
#
#     accuracy                          0.988       324
#    macro avg      0.988     0.986     0.987       324
# weighted avg      0.988     0.988     0.988       324

# %% [markdown]
# Apply the model to the entire dataset

# %%
import glob
file_path = "nypl_1850_mn_clean_records.txt"

with open(file_path,encoding="utf-8") as f:
  data = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-2f12cf74c5d2> in <module>
#       2 file_path = "nypl_1850_mn_clean_records.txt"
#       3
# ----> 4 with open(file_path,encoding="utf-8") as f:
#       5   data = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nypl_1850_mn_clean_records.txt'

# %% [markdown]
# Format the records to apply on the entire dataset

# %%
formatted = []
for record in data:
  ls = record.split()
  if ls:
    if bool(re.match("([A-Z]+\.)", ls[0])) == True:
      continue
    else:
      record_split = []
      for word in ls[1:]:
        if word[-1] == "." or word[-1] == ",":
          record_split.append(word[:-1])
          record_split.append(word[-1])
        else:
          record_split.append(word)
    formatted.append([ls[0], record_split])

# %%
def predict_label(s):
  sents = [[(word,0) for word in s]]
  sents[0].insert(0, ('START',0))
  sents[0].append(('END', 0))
  X = [sent2features(s) for s in sents]
  y = crf.predict(X)
  return y

# %%
n = len(formatted)
for i in range(n):
  labels = predict_label(formatted[i][1])
  formatted[i].append(labels[0])

# %%
# Pickle the list to save preliminary result
with open("mn_prediction.pkl", "wb") as f:
  pickle.dump(formatted,f)

# %% [markdown]
# Save the prediction to json format

# %%
# Retrieve result
with open("mn_prediction.pkl", 'rb') as f:
  d = pickle.load(f)

# %%
d
# Out:
# [['1',
#   ['Ackley',
#    'Addison',
#    ',',
#    'clerk',
#    ',',
#    '47',
#    'Broadway',
#    ',',
#    'h',
#    '.',
#    '39',
#    'Pearl'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['2',
#   ['Adams',
#    'William',
#    ',',
#    'weigher',
#    ',',
#    '20',
#    'Washington',
#    '&',
#    '13',
#    'West',
#    ',',
#    'h',
#    '.',
#    '170',
#    'Clinton',
#    ',',
#    'Brooklyn'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['3',
#   ['Aitkin', 'Thomas', ',', 'stonecutter', ',', '601', 'Washington'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['4',
#   ['Albro', 'Benjamin', 'sen', '.', '328', 'Bowery'],
#   ['START', 'NC', 'AC', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['5',
#   ['Allen', 'E', '.', 'W', '.', 'publisher', ',', '42', 'Orange'],
#   ['START', 'NC', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['6',
#   ['Anderson',
#    'Frederick',
#    '11',
#    '.',
#    'com',
#    '.',
#    'mer',
#    '.',
#    '13',
#    'Front',
#    ',',
#    'h',
#    '.',
#    '77',
#    'Barrow'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['7',
#   ['Anderson', 'John', 'R', '.', 'seaman', ',', '586', 'E', '.', '4th'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['8',
#   ['Anthes', 'Peter', ',', 'barber', '34', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'AC', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['9',
#   ['Anthes', '&', 'Eckardt', ',', 'barbers', ',', '34', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['10',
#   ['Appell', 'John', ',', 'tailor', ',', '40', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['11',
#   ['Arcularius', 'Jacob', 'S', '.', 'h', '.', '175', 'Canal'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['12',
#   ['Arenfred', 'George', ',', '137', 'Norfolk'],
#   ['START', 'NC', 'NC', 'D', 'AC', 'AC', 'END']],
#  ['13',
#   ['Armstrong', 'George', ',', 'shoemaker', ',', '53', 'Av', '.', 'D'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['14',
#   ['Armstrong', 'John', 'D', '.', 'coachmaker', ',', '5', 'Ludlow'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['15',
#   ['Arnold',
#    'Henry',
#    ',',
#    'drygoods',
#    ',',
#    '1',
#    'Av',
#    '.',
#    'D',
#    ',',
#    'h',
#    '.',
#    'r',
#    '.',
#    '1',
#    'Av',
#    '.',
#    'D'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['16',
#   ['Ash',
#    'William',
#    'A',
#    '.',
#    'saloon',
#    ',',
#    '413',
#    'B.way',
#    ',',
#    'h',
#    '.',
#    'Morrisania'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'END']],
#  ['17',
#   ['Auchincloss',
#    'John',
#    'T',
#    '.',
#    'com',
#    '.',
#    'mer',
#    '.',
#    '192',
#    'Fulton',
#    ',',
#    'h',
#    '.',
#    '7',
#    'Murray'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['18',
#   ['Auchincloss',
#    '&',
#    'Croxon',
#    ',',
#    'com',
#    '.',
#    'mers',
#    '.',
#    '192',
#    'Fulton'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['19',
#   ['Bagley',
#    'William',
#    ',',
#    'clerk',
#    ',',
#    'bank',
#    ',',
#    '50',
#    'Wall',
#    ',',
#    'h',
#    '.',
#    '91',
#    'Henry',
#    ',',
#    'Brooklyn'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['20',
#   ['BAIN',
#    'ALEXANDER',
#    ',',
#    'telegraph',
#    'inventor',
#    ',',
#    '181',
#    'Broadway',
#    ',',
#    'h',
#    '.',
#    'Irving',
#    'house'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['21',
#   ['Baldwin', 'Ezekiel', ',', 'shoemaker', ',', '79', 'Av', '.', 'B'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['22',
#   ['Ball', 'Isaac', ',', 'pedler', ',', '66', 'Mangin'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['23',
#   ['Bannon', 'Michael', ',', 'cooper', ',', '304', 'Ninth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['24',
#   ['Bannore',
#    'Christopher',
#    ',',
#    'shoes',
#    ',',
#    'E',
#    '.',
#    '13th',
#    'n',
#    '.',
#    'Av',
#    '.',
#    'A'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['25',
#   ['Barratt', 'Thomas', ',', 'carman', ',', '605', 'Fourth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['26',
#   ['Barrowclough', 'James', ',', 'E', '.', '24th', 'c', '.', 'Av', '.', '3'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['27',
#   ['Barry', 'James', ',', 'marblepolisher', ',', '294', 'Eleventh'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['28',
#   ['Barry', 'John', ',', 'carpenter', ',', '60', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['29',
#   ['Bates',
#    'John',
#    'C',
#    '.',
#    'sarsaparilla',
#    ',',
#    '82',
#    'Nassau',
#    ',',
#    'h',
#    '.',
#    'Brooklyn'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'END']],
#  ['30',
#   ['Beach',
#    'John',
#    'T',
#    '.',
#    'paper',
#    ',',
#    '43',
#    'Fulton',
#    ',',
#    'h',
#    '.',
#    '22',
#    'Vesey'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['31',
#   ['Bear',
#    'Isaac',
#    ',',
#    'drygoods',
#    ',',
#    '105',
#    'Av',
#    '.',
#    'D',
#    ',',
#    'h',
#    '.',
#    '105',
#    'Av',
#    '.',
#    'D'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['32',
#   ['Beard', 'William', ',', 'carpenter', ',', '89', 'E', '.', '11th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['33',
#   ['Becom',
#    'John',
#    'J',
#    '.',
#    'sawyer',
#    ',',
#    'Av',
#    '.',
#    'C',
#    'n',
#    '.',
#    'Eleventh'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['34',
#   ['Beebe', 'Joseph', 'D', '.', 'rigger', ',', '350', 'Tenth'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['35',
#   ['Beebe',
#    '&',
#    'Co',
#    '.',
#    'builders',
#    '.',
#    'W',
#    '.',
#    '24th',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '10'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['36',
#   ['Beers',
#    'William',
#    'P',
#    '.',
#    'butcher',
#    ',',
#    '69',
#    'Orange',
#    ',',
#    'h',
#    '.',
#    '77',
#    'Third'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['37',
#   ['Bender', 'George', 'W', '.', 'tailor', ',', '27', 'Av', '.', 'A'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['38',
#   ['Bennett', 'Cornelius', ',', 'carman', ',', '400', 'Tenth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['39',
#   ['Bennett', 'George', ',', 'shoemaker', ',', '131', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['40',
#   ['Bennett', 'William', ',', 'carman', ',', '245', 'E', '.', '13th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['41',
#   ['Bernhard', 'Gustavus', ',', 'teacher', ',', '18', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['42',
#   ['Bernz', 'John', ',', 'tailor', ',', '306', 'Av', '.', '1'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['43',
#   ['Berrian', 'Burr', ',', 'fish', ',', '89', 'Pitt'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['44',
#   ['Bird', 'George', 'L', '.', 'clerk', ',', '45', 'Norfolk'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['45',
#   ['Bill', 'Hannah', ',', 'tailoress', ',', '46', 'Amos'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['46',
#   ['Birmingham',
#    'David',
#    ',',
#    'police',
#    ',',
#    'W',
#    '.',
#    '26th',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '7'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['47',
#   ['Boole', 'Thomas', 'B', '.', '107', 'Av', '.', 'B'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['48',
#   ['Borman', 'Eckhard', ',', 'tailor', ',', '5', 'Av', '.', 'B'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['49',
#   ['Bott', 'John', ',', 'tailor', ',', '299', 'Av', '.', 'A'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['50',
#   ['Botz', 'Louis', ',', 'pedler', ',', '49', 'Av', '.', '1'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['51',
#   ['Bouton', 'Gilbert', ',', 'carman', ',', '51', 'Norfolk'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['52',
#   ['Bowen', 'John', ',', 'plumber', ',', '268', 'E', '.', '13th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['53',
#   ['Boyd',
#    'John',
#    'jr',
#    '.',
#    'mer',
#    '.',
#    '149',
#    '&',
#    '151',
#    'Front',
#    ',',
#    'h',
#    '.',
#    '92',
#    'Madison'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['54',
#   ['Boyle',
#    'John',
#    ',',
#    'liquors',
#    ',',
#    'W',
#    '.',
#    '25th',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '10'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['55',
#   ['Boynton',
#    'Ray',
#    ',',
#    'com',
#    '.',
#    'mer',
#    '.',
#    '51',
#    'Exch',
#    '.',
#    'pl',
#    '.',
#    'h',
#    '.',
#    '31',
#    'W',
#    '.',
#    '15th'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'OC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['56',
#   ['Brady',
#    'John',
#    ',',
#    'school',
#    ',',
#    '219',
#    'E',
#    '.',
#    '13th',
#    ',',
#    'h',
#    '.',
#    '217',
#    'E',
#    '.',
#    '13th'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['57',
#   ['Bramley', 'Patrick', ',', 'boilermaker', ',', '319', 'Ninth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['58',
#   ['Bramwell',
#    'Joseph',
#    ',',
#    'mer',
#    '.',
#    'h',
#    '.',
#    '101',
#    'Henry',
#    ',',
#    'Brooklyn'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['59',
#   ['Brant',
#    'Theophilus',
#    ',',
#    'shipjoiner',
#    ',',
#    'Av',
#    '.',
#    'D',
#    'c',
#    '.',
#    'Fourth'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['60',
#   ['Breasted', 'John', ',', 'allaire', 'works', ',', '464', 'Cherry'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['61',
#   ['Brennan', 'Joseph', ',', 'mason', ',', '312', 'Av', '.', '1'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['62',
#   ['Brennen',
#    'James',
#    'H',
#    '.',
#    'hatter',
#    ',',
#    '7',
#    'Av',
#    '.',
#    'D',
#    ',',
#    'h',
#    '.',
#    '7',
#    'Av',
#    '.',
#    'D'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['63',
#   ['Breuninger', 'Henry', ',', 'tailor', ',', '25', 'Av', '.', 'A'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['64',
#   ['Brice', 'Henry', ',', 'silkweaver', ',', '143', 'W', '.', '28th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['65',
#   ['Brincker',
#    'William',
#    ',',
#    'carpenter',
#    ',',
#    'Third',
#    'n',
#    '.',
#    'Av',
#    '.',
#    'A'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['66',
#   ['Brodhead', 'John', 'R', '.', '32', 'Bond'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'AC', 'AC', 'END']],
#  ['67',
#   ['Brooks', 'Brothers', ',', 'clothing', ',', '116', '&', '118', 'Cherry'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['68',
#   ['Brouard',
#    'Peter',
#    ',',
#    '83',
#    'Leonard',
#    ',',
#    'h',
#    '.',
#    '143',
#    'Reade',
#    'FOR',
#    'INSERTION',
#    ',',
#    'S',
#    ',',
#    '&C',
#    '.'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['69',
#   ['Brough',
#    'William',
#    ',',
#    '117',
#    'Fulton',
#    ',',
#    'h',
#    '.',
#    '4',
#    'Beach',
#    '.'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['70',
#   ['Brouner',
#    'Joseph',
#    'P',
#    '.',
#    'drygoods',
#    ',',
#    '707',
#    'Greenwich',
#    ',',
#    'h',
#    '.',
#    '529',
#    'Hudson'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['71',
#   ['Brouwer',
#    'Saml',
#    '.',
#    'crockery',
#    ',',
#    '72',
#    'Vesey',
#    ',',
#    'h',
#    '.',
#    '173',
#    'Wooster'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['72',
#   ['Brown',
#    'Charles',
#    'P',
#    '.',
#    '290',
#    'West',
#    ',',
#    'h',
#    '.',
#    '95',
#    'W',
#    '.',
#    '13th'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['73',
#   ['Brown', 'Robert', ',', 'physician', ',', '174', 'Chambers'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['74',
#   ['Brown', 'Thomas', 'H', '.', 'hosiery', ',', '34', 'Liberty'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['75',
#   ['Brown',
#    '&',
#    'Englis',
#    ',',
#    'shipwrights',
#    ',',
#    'Twelfth',
#    'c',
#    '.',
#    'Dry',
#    'Dock'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['76',
#   ['Brownme', 'John', 'S', '.', 'carver', ',', 'h', '.', '53', 'Monroe'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['77',
#   ['Bruggemann', 'Diedrich', ',', 'grocer', ',', 'h', '.', '72', 'Lewis'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['78',
#   ['Brummell',
#    'Adonijah',
#    ',',
#    'confectioner',
#    ',',
#    'h',
#    '.',
#    '141',
#    'Norfolk'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['79',
#   ['Budd', 'Thomas', 'S', '.', 'shipmaster', ',', '166', 'E', '.', '20th'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['80',
#   ['Bunce', 'William', 'C', '.', 'carman', ',', '201', 'Av', '.', '3'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['81',
#   ['Bunzel', 'Gottlieb', ',', 'rvhitewasher', ',', '93', 'Ridge'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['82',
#   ['Burket', 'James', 'E', '.', 'porterhouse', ',', '433', 'Tenth'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['83',
#   ['Camp', 'Benjamin', 'F', '.', 'builder', ',', '86', 'Av', '.', '2'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['84',
#   ['Campbell', 'John', ',', 'blacksmith', ',', '180', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['85',
#   ['Campbell', 'Peter', ',', 'boatman', ',', '128', 'Charlton'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['86',
#   ['Campbell', 'William', 'S', '.', 'printer', ',', '180', 'Grand'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['87',
#   ['Campbell',
#    '&',
#    'Moody',
#    ',',
#    'lumber',
#    ',',
#    '7',
#    'Broad',
#    ',',
#    'steam',
#    'saw',
#    'mill',
#    ',',
#    'foot',
#    '36th',
#    ',',
#    'n',
#    '.',
#    'r',
#    '.'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'OC',
#    'OC',
#    'OC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'END']],
#  ['88',
#   ['Cunham',
#    'Wm',
#    '.',
#    'carputer',
#    '.',
#    '16',
#    'Clarkson',
#    ',',
#    'h',
#    '.',
#    '14',
#    'Clarkson'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['89',
#   ['Cannon',
#    'Cornelius',
#    ',',
#    'tinner',
#    ',',
#    '176',
#    'Wooster',
#    ',',
#    'h',
#    '.',
#    '2',
#    'Congress'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['90',
#   ['Carey', 'Thomas', ',', 'carpenter', ',', '104', 'E', '.', '11th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['91',
#   ['Carlisle',
#    'George',
#    ',',
#    'mer',
#    '.',
#    '165',
#    'Pearl',
#    ',',
#    'h',
#    '.',
#    'Cincinnati',
#    ',',
#    'O'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['92',
#   ['Carlisle', '&', 'Stedman', ',', 'mers', '.', '165', 'Pearl'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['93',
#   ['Carrington',
#    'Z',
#    '.',
#    'E',
#    '.',
#    'salesman',
#    ',',
#    '13',
#    'William',
#    ',',
#    'h',
#    '.',
#    'Court',
#    'n',
#    '.',
#    'Degraw',
#    ',',
#    'Brooklyn'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['94',
#   ['Carroll', 'D', '.', 'J', '.', 'physician', '.', '400', 'Broadway'],
#   ['START', 'NC', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['95',
#   ['Case',
#    'George',
#    ',',
#    'sashmaker',
#    ',',
#    'W',
#    '.',
#    '25th',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '8',
#    ',',
#    'h',
#    '.',
#    'W',
#    '25th',
#    'n',
#    '.',
#    'A.v',
#    '.',
#    '8'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['96',
#   ['Castle', 'Charles', 'H', '.', 'com', '.', 'mer', '.', '121', 'Pearl'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['97',
#   ['Carlough', 'George', ',', 'carman', ',', '746', 'Washington'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['98',
#   ['Channing', 'William', ',', 'physician', ',', '88', 'White'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['99',
#   ['Chapin', 'R', '.', 'Spencer', ',', 'physician', ',', '305', 'Third'],
#   ['START', 'NC', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['100',
#   ['Charcin',
#    'John',
#    ',',
#    'carpenter',
#    ',',
#    'W',
#    '.',
#    '28th',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '7'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['101',
#   ['Clarke', 'William', ',', 'brassfounder', ',', '41', 'Sheriff'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['102',
#   ['Clarke', '&', 'Dougherty', ',', 'morocco', ',', '29', 'Ferry'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['103',
#   ['Clary', 'Philip', ',', 'livery', 'stables', ',', '193', 'Ninth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['104',
#   ['Clausen',
#    '&',
#    'Suhr',
#    ',',
#    'boarding',
#    ',',
#    'Peck',
#    'slip',
#    ',',
#    'c',
#    '.',
#    'Pearl'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'END']],
#  ['105',
#   ['Claussen', 'John', ',', 'grocer', ',', '160', 'Church'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['106',
#   ['Clayton', 'John', ',', 'carpenter', ',', '63', 'Factory'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['107',
#   ['Clear',
#    'Edward',
#    ',',
#    'boxes',
#    ',',
#    '73',
#    'Maiden',
#    'la',
#    '.',
#    'h',
#    '.',
#    '43',
#    'Elm'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['108',
#   ['Collins',
#    'Joseph',
#    'B',
#    '.',
#    'pres',
#    '.',
#    'm',
#    '.',
#    '1',
#    '.',
#    'ins',
#    '.',
#    'co',
#    '.',
#    '35',
#    'Wall',
#    ',',
#    'h',
#    '.',
#    '415',
#    'Broome'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['109',
#   ['Cooper',
#    'Thos',
#    '.',
#    'S',
#    '.',
#    'grocer',
#    ',',
#    '104',
#    'Broad',
#    ',',
#    'h',
#    '.',
#    '23',
#    'Whitehall'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['110',
#   ['Cooper', ',', 'Storm', '&', 'Smith', ',', 'grocers', ',', '104', 'Broad'],
#   ['START', 'NC', 'NC', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['111',
#   ['Corell', 'Peter', ',', '20', 'Hamersley', 'place'],
#   ['START', 'NC', 'NC', 'D', 'AC', 'AC', 'AC', 'END']],
#  ['112',
#   ['Cosgrove', 'Henry', ',', 'h', '.', '7', 'Chrystie'],
#   ['START', 'NC', 'NC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['113',
#   ['Crawford', 'George', 'W', '.', 'carman', ',', '650', 'Fourth'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['114',
#   ['Crawford', 'Susannah', ',', 'widow', 'of', 'David', '.', '650', 'Fourth'],
#   ['START', 'NC', 'NC', 'D', 'NC', 'NC', 'NC', 'NC', 'AC', 'AC', 'END']],
#  ['115',
#   ['Croxon',
#    'H',
#    '.',
#    'Thomas',
#    ',',
#    'com',
#    '.',
#    'mer',
#    '.',
#    '192',
#    'Fulton',
#    ','],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['116',
#   ['Cunningham', 'Thomas', ',', 'rigger', ',', 'r', '.', '14', 'Pelham'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['117',
#   ['Curtis', 'Joseph', 'T', '.', 'physician', ',', '609', 'Broadway'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['118',
#   ['Cushman', 'J', '.', 'Newland', ',', 'lawyer', ',', '118', 'Wi)liam'],
#   ['START', 'NC', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['119',
#   ['Daniel',
#    'Joseph',
#    'P',
#    '.',
#    'sodawater',
#    ',',
#    '118',
#    'Fulton',
#    ',',
#    'h',
#    '.',
#    '76',
#    'Mott'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['120',
#   ['Darling',
#    'Wm',
#    '.',
#    'physician',
#    '.',
#    '645',
#    'B.way',
#    ',',
#    'h',
#    '.',
#    '226',
#    'Wooster'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['121',
#   ['Davis',
#    'Edwin',
#    ',',
#    'com',
#    '.',
#    'mer',
#    '.',
#    '16',
#    'Burling',
#    'slip',
#    '.',
#    'h',
#    '.',
#    'Brooklu'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['122',
#   ['Deafenbuck', 'Henry', ',', 'butcher', ',', '465', 'Fourth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['123',
#   ['Decry', 'Dennis', ',', 'late', 'porterhouse', ',', '623', 'Washington'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['124',
#   ['Delavan', 'James', ',', 'secretary', ',', '25', 'Nassau'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['125',
#   ['Denison',
#    'Charles',
#    'S',
#    '.',
#    'liquors',
#    ',',
#    '267',
#    'Washington',
#    'h',
#    '.',
#    '5',
#    'Charlton'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['126',
#   ['Derickson',
#    'Kinlock',
#    'S',
#    '.',
#    'com',
#    '.',
#    'mer',
#    '.',
#    '87',
#    'Beaver',
#    ',',
#    'h',
#    '.',
#    '2',
#    'College',
#    'pl'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['127',
#   ['Devermaun',
#    'Hammond',
#    ',',
#    'grocer',
#    ',',
#    '45',
#    'Ridge',
#    ',',
#    'h.CHnton',
#    'c',
#    '.',
#    'Delancy'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['128',
#   ['Devoe', 'John', 'C', '.', 'saddler', ',', 'h', '.', '184', 'Ludlow'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['129',
#   ['Diederich', 'Charles', ',', 'coppersmith', ',', '101', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['130',
#   ['Donnely',
#    'Edward',
#    'C',
#    '.',
#    'mer',
#    '.',
#    '7',
#    'S',
#    '.',
#    'William',
#    ',',
#    'h',
#    '.',
#    '102',
#    'Av',
#    '.',
#    '2'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['131',
#   ['Duffey', 'James', ',', 'carpenter', ',', '200', 'Av', '.', '1'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['132',
#   ["Duft'y",
#    'John',
#    ',',
#    'surgeon',
#    ',',
#    '12',
#    'Sixth',
#    ',',
#    'h',
#    '.',
#    '30',
#    'Bleecker'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['133',
#   ['Duffy',
#    'Bernard',
#    'G',
#    '.',
#    'grocer',
#    ',',
#    '560',
#    'Fourth',
#    ',',
#    'h',
#    '.',
#    '560',
#    'Fourth'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['134',
#   ['Duignan', 'Peter', ',', 'carman', ',', '110', 'Av', '.', '7'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['135',
#   ['Dumont', 'John', ',', 'shipcarpenter', ',', '686', 'Fourth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['136',
#   ['Duncan', 'Francis', ',', 'stonecutter', ',', 'h', '.', '291', 'Seventh'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['137',
#   ['Duncan', 'George', ',', 'painter', ',', '105', 'E', '.', '11th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['138',
#   ['Dunn', 'Benjamm', ',', 'late', 'carman', ',', '156', 'Av', '.', '6'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['139',
#   ['Dunn', 'William', ',', 'tailor', ',', '27', 'Sheriff'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['140',
#   ['Dunning', 'Moses', ',', 'tailor', ',', 'r', '.', '67', 'James'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['141',
#   ['Dupuy', 'Henry', ',', '19', 'Cliff', ',', 'h', '.', 'Williamsburg'],
#   ['START', 'NC', 'NC', 'D', 'AC', 'AC', 'D', 'PA', 'AC', 'AC', 'END']],
#  ['142',
#   ['Durant', 'John', ',', 'silversmith', ',', 'h', '.', '349', 'Broome'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['143',
#   ['Durst',
#    'Gottleb',
#    ',',
#    'butcher',
#    ',',
#    'E',
#    '.',
#    '16th',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '1'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['144',
#   ['Dwinett', 'Andrew', 'A', '.', 'printer', ',', '460', 'Washington'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['145',
#   ['Dyckman', 'States', ',', 'carman', ',', '648', 'Fourth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['146',
#   ['Dyer', 'James', ',', 'cabinetmaker', ',', '6', 'Goerck'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['147',
#   ['Doane',
#    'A',
#    '.',
#    'Sidney',
#    ',',
#    'health',
#    'officer',
#    ',',
#    '5',
#    'City',
#    'Hall'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['148',
#   ['Doney',
#    'Thomas',
#    ',',
#    'engraver',
#    ',',
#    '16',
#    'Burling',
#    'sl',
#    '.',
#    'h',
#    '.',
#    'New',
#    'J'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['149',
#   ['Donnell',
#    'James',
#    ',',
#    'lime',
#    ',',
#    '500',
#    'West',
#    ',',
#    'h',
#    '.',
#    '727',
#    'Washington'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['150',
#   ['Donnell',
#    'John',
#    ',',
#    'restaurant',
#    ',',
#    '249',
#    'Wooster',
#    ',',
#    'h',
#    '.',
#    '154',
#    'Sullivan'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['151',
#   ['Dougherty', 'Richard', ',', 'mason', ',', 'r', '.', '185', 'Laurens'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['152',
#   ['Dougherty',
#    'William',
#    ',',
#    'carman',
#    ',',
#    'W',
#    '.',
#    '29th',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '11'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['153',
#   ['Doughty', 'Leonard', 'D', '.', 'varnisher', ',', '669', 'Fourth'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['154',
#   ['Douglas', 'Thomas', ',', 'tailor', ',', '658', 'Fourth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['155',
#   ['Dow', '&', 'Burdi', ',', 'paperhangers', ',', '151', 'Broadway'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['156',
#   ['Downie',
#    'James',
#    ',',
#    'laces',
#    ',',
#    'W',
#    '.',
#    '27th',
#    'b',
#    '.',
#    'Avs',
#    '.',
#    '9',
#    '&',
#    '10'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['157',
#   ['Doyle', 'Thomas', ',', 'blacksmith', ',', '5', 'Weehawken'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['158',
#   ['Dredger', 'Jacob', 'W', '.', 'carman', '.', '16', 'Christopher'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['159',
#   ['Ebbets',
#    'Edward',
#    'A',
#    '.',
#    'baker',
#    ',',
#    '319',
#    'Hudson',
#    ',',
#    'h',
#    '.',
#    '319',
#    'Hudson'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['160',
#   ['Eckardt',
#    'Philip',
#    ',',
#    'barber',
#    ',',
#    '34',
#    'Av',
#    '.',
#    'C',
#    ',',
#    'h',
#    '.',
#    '34',
#    'Av',
#    'C'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['161',
#   ['Engel', 'Edward', ',', 'frescopainter', ',', '22', 'Market'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['162',
#   ['Fagan', 'Edmund', 'W', '.', 'engraver', ',', '333', 'Broadway'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['163',
#   ['Farley', 'Thomas', ',', 'shoemaker', ',', 'r', '.', '616', 'Broadway'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['164',
#   ['Farrington', 'Joseph', 'T', '.', 'clerk', ',', '100', 'Sullivan'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['165',
#   ['Felkar', 'George', ',', 'malster', ',', '281', 'E', '.', '13th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['166',
#   ['Fenning', 'Michael', ',', 'shoemaker', ',', '398', 'West'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['167',
#   ['Fenton', 'David', ',', 'cooper', ',', '34', 'Elizabeth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['168',
#   ['Ferguson', 'John', 'C', '.', 'shoemaker', ',', '119', 'Lewis'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['169',
#   ['Ferris', 'George', 'S', '.', 'clerk', ',', '30', 'Fifth'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['170',
#   ['Ferris',
#    'John',
#    'M',
#    '.',
#    'lumber',
#    ',',
#    '457',
#    'West',
#    ',',
#    'boards',
#    '95',
#    'Bank'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'OC',
#    'AC',
#    'AC',
#    'END']],
#  ['171',
#   ['Ferris', 'S', '.', 'A', '.', 'mer', '.', '33', 'Front'],
#   ['START', 'NC', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['172',
#   ['Ferris', 'Thomas', 'T', '.', '129', 'Charles'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'AC', 'AC', 'END']],
#  ['173',
#   ['Ferris', 'Thomas', ',', 'carpets', ',', '159', 'Chatham'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['174',
#   ['Ferry', 'Edward', ',', 'weigher', ',', 'r', '.', '76', 'Mulberry'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['175',
#   ['Ferry', 'Eli', ',', 'police', ',', '391', 'Broome'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['176',
#   ['Fessenden',
#    'William',
#    'W',
#    '.',
#    'clerk',
#    ',',
#    '45',
#    'Broadway',
#    ',',
#    'boards',
#    '16',
#    'State'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'OC',
#    'AC',
#    'AC',
#    'END']],
#  ['177',
#   ['Fetters', 'John', ',', 'tobacconist', ',', '54', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['178',
#   ['Fick',
#    'Eliza',
#    ',',
#    'widow',
#    'of',
#    'David',
#    'S',
#    '.',
#    'confectionery',
#    ',',
#    '588',
#    'Fourth'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'END']],
#  ['179',
#   ['Fick', '&', 'Kucharski', ',', 'trunkmakers', ',', '2', 'Bowery'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['180',
#   ['Fickett',
#    'Hart',
#    ',',
#    'shipcarpenter',
#    '.',
#    'Ninth',
#    'c',
#    '.',
#    'Av',
#    '.',
#    'C'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['181',
#   ['Fiedo', 'William', ',', 'carman', ',', 'r', '.', '208', 'Elm'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['182',
#   ['Field', 'Edward', ',', 'druggist', ',', '279', 'Delancy'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['183',
#   ['Field',
#    'Edward',
#    ',',
#    'late',
#    'hardware',
#    '.',
#    '1',
#    'Platt',
#    ',',
#    'h',
#    '.',
#    '35',
#    'CHnton',
#    'place'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['184',
#   ['Field', 'Franklin', 'C', '.', '721', 'Broadway'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'AC', 'AC', 'END']],
#  ['185',
#   ['Fieselmann', 'Stephen', ',', 'brassfounder', ',', '25', 'Av', '.', 'B'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['186',
#   ['Fiettretch', 'William', ',', 'mason', ',', '49', 'Av', '.', 'B'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['187',
#   ['Fiken',
#    'Richard',
#    ',',
#    'late',
#    'grocer',
#    ',',
#    'h',
#    '.',
#    '529',
#    'Greenwich'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['188',
#   ['Finch', 'Joseph', ',', 'teacher', ',', '215', 'W', '.', '18th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['189',
#   ['Finch', 'John', ',', 'painter', ',', '62', 'Sixth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['190',
#   ['Fink', 'Conrad', ',', 'clerk', ',', '151', 'W', '.', 'Broadway'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['191',
#   ['Fink', 'Joseph', ',', 'shipjoiner', ',', '367', 'Sixth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['192',
#   ['Fink', 'Lewis', ',', 'grocer', ',', '536', 'Pearl'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['193',
#   ['Finley', 'Joseph', ',', 'upholsterer', ',', '134', 'Broome'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['194',
#   ['Fisher', 'Peter', 'G', '.', 'carver', ',', '241', 'Mott'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['195',
#   ['Fitch',
#    'Asa',
#    ',',
#    'mer',
#    '.',
#    '43',
#    'New',
#    ',',
#    'h',
#    '.',
#    '8',
#    'University',
#    'place'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['196',
#   ['Fitch', 'William', ',', 'merchant', ',', '43', 'New'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['197',
#   ['Fitz', 'John', ',', 'foundry', ',', '149', 'Bowery'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['198',
#   ['Fitzgerald',
#    'Edward',
#    ',',
#    'mason',
#    ',',
#    'E',
#    '.',
#    '22d',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '3'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['199',
#   ['Fletcher', 'John', 'W', '.', 'smith', ',', '92', 'Delancy'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['200',
#   ['Flood',
#    'James',
#    ',',
#    'grocer',
#    ',',
#    '346',
#    'Sixth',
#    ',',
#    'h',
#    '.',
#    '346',
#    'Sixth'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['201',
#   ['Flowers', 'George', ',', 'machinist', ',', '6', 'Columbia', 'place'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'END']],
#  ['202',
#   ['Folkes', 'Thomas', ',', 'caulker', ',', '153', 'Goerck'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['203',
#   ['Ford', 'Augustus', ',', 'furrier', ',', '184', 'Spring'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['204',
#   ['Forrest', 'James', ',', 'hatter', ',', '22', 'Mulberry'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['205',
#   ['Forrester', 'Charles', ',', 'lettercarrier', ',', '27', 'Columbia'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['206',
#   ['Foster', 'Charles', 'R', '.', 'carman', ',', '214', 'E', '.', '11th'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['207',
#   ['Foster', 'James', ',', 'joiner', ',', 'Twelfth', 'n', '.', 'Dry', 'dock'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['208',
#   ['Foster', 'Joseph', 'A', '.', 'bookkeeper', ',', '75', 'Varick'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['209',
#   ['Foster',
#    'Samuel',
#    ',',
#    'carriagemaker',
#    ',',
#    '203',
#    'Mercer',
#    ',',
#    'h',
#    '.',
#    '203',
#    'Mercer'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['210',
#   ['Foster',
#    'S',
#    '.',
#    'R',
#    '.',
#    'broker',
#    ',',
#    '166',
#    'Greenwich',
#    ',',
#    'h',
#    '.',
#    'Harlem'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'END']],
#  ['211',
#   ['Fotzlen', 'Adam', ',', 'segars', ',', '34', 'Av', '.', 'B'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['212',
#   ['Fountain', 'Garret', "W.'chairs", ',', '284', 'E', '.', '13th'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['213',
#   ['Fountain',
#    "Henry'",
#    'K',
#    '.',
#    'lighter',
#    ',',
#    '61',
#    'Whitehall',
#    ',',
#    'h',
#    '.',
#    'Staten',
#    'Island',
#    '—CONTINUED',
#    '.'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['214',
#   ['Francis',
#    'J',
#    '.',
#    'M',
#    '.',
#    'telegraph',
#    'agent',
#    ',',
#    '181',
#    'B.way',
#    ',',
#    'h',
#    '.',
#    '46',
#    'Hudson'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['215',
#   ['Gerdeng', 'Ludowick', ',', 'cabinetmaker', ',', '18', 'Doyer'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['216',
#   ['Gerdes', 'Martin', ',', 'grocer', ',', '19', 'Pell'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['217',
#   ['Gerety',
#    'Francis',
#    ',',
#    'clerk',
#    ',',
#    '31',
#    'Old',
#    'slip',
#    ',',
#    'h',
#    '.',
#    '5',
#    'State'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['218',
#   ['Gerety', 'Michael', ',', 'stonecutter', ',', '192', 'A.v', '.', '1'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['219',
#   ['Gerger', 'Valentine', ',', 'porterhouse', ',', '127', 'Ridge'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['220',
#   ['Gerhard', 'Baltzel', ',', 'grocer', ',', '115', 'Delancy'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['221',
#   ['Germer',
#    'Ludolph',
#    ',',
#    'cabinetmaker',
#    ',',
#    '65',
#    'Beekman',
#    ',',
#    'h',
#    '.',
#    'Ob',
#    'Beekman'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['222',
#   ['Gerry',
#    'James',
#    'M',
#    '.',
#    'shoes',
#    ',',
#    '564',
#    'Grand',
#    ',',
#    'h',
#    '.',
#    '564',
#    'Grand'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['223',
#   ['Gildmeister', 'Charles', ',', 'artist', ',', '200', 'Fulton'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['224',
#   ['Gregory',
#    'Stephen',
#    'B',
#    '.',
#    'crockery',
#    ',',
#    '115',
#    'Pearl',
#    ',',
#    'h',
#    '.',
#    '113',
#    'Clinton',
#    ',',
#    'Brooklyn'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['225',
#   ['Gregory', "'&", 'Co', '.', 'crockery', ',', '115', 'Pearl'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['226',
#   ['Gruby',
#    'William',
#    ',',
#    'Albany',
#    'ale',
#    ',',
#    '254',
#    'Washington',
#    ',',
#    'h',
#    '.',
#    'Jersey',
#    'City'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['227',
#   ['Hall', 'William', ',', 'grocer', ',', 'h', '.', 'r', '.', '195', 'Monroe'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'END']],
#  ['228',
#   ['Halsted', 'Richard', 'F', '.', 'h', '.', '217', 'W', '.', '18th'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'PA', 'AC', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['229',
#   ['Harmer', 'Charles', 'G', '.', 'imp', '.', 'h', '.', '161', 'Madison'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['230',
#   ['Harmon',
#    'Philip',
#    'C',
#    '.',
#    'brewer',
#    ',',
#    '6',
#    'Sheriff',
#    ',',
#    'h',
#    '.',
#    '65',
#    'S',
#    '.',
#    'Fifth',
#    ',',
#    'Williamsburg'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['231',
#   ['Harney',
#    'John',
#    ',',
#    'machinist',
#    ',',
#    'Jane',
#    'c',
#    '.',
#    'Greenwich',
#    ',',
#    'h',
#    '.',
#    '687',
#    'Hudson'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['232',
#   ['Hendrickson', '&', 'Pearsall', ',', 'stables', ',', '675', 'Fourth'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['233',
#   ['Herman', 'Jacob', ',', 'segars', ',', '21', 'Av', '.', 'C'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['234',
#   ['Hickok',
#    'William',
#    ',',
#    'agent',
#    ',',
#    'G.wich',
#    'c',
#    '.',
#    'Dey',
#    ',',
#    'h',
#    '.',
#    'B’klyn'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'END']],
#  ['235',
#   ['Hillsburgh', 'Charles', ',', 'h', '.', '65', 'Monroe'],
#   ['START', 'NC', 'NC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['236',
#   ['Hirschland', 'Isaac', ',', 'butcher', ',', '263', 'Third'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['237',
#   ['Hopkins', 'George', 'W', '.', 'butcher', ',', '128', 'Suffolk'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['238',
#   ['Hoppin',
#    'Hamilton',
#    ',',
#    'mer',
#    '.',
#    'Centre',
#    'c',
#    '.',
#    'Duane',
#    ',',
#    'h',
#    '.',
#    '12',
#    'Washington',
#    'square'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['239',
#   ['Horton', 'Franklin', ',', 'shipcarpenter', ',', '674', 'Fourth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['240',
#   ['Howe',
#    'Smith',
#    ',',
#    'cooper',
#    ',',
#    '660',
#    'Water',
#    ',',
#    'h',
#    '.',
#    '90',
#    'Essex'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['241',
#   ['Hoyt',
#    'William',
#    ',',
#    'leather',
#    ',',
#    '40',
#    'Spruce',
#    ',',
#    'h',
#    '.',
#    '82',
#    'E',
#    '.',
#    'B.way'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['242',
#   ['Hubbs', 'Scott', ',', 'stagedriver', ',', '600', 'Fourth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['243',
#   ['Hugrel', 'Adolphus', 'D', '.', 'mer', '.', '58', 'Cedar'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['244',
#   ['Jackson', 'Loring', ',', 'shipcarpenter', ',', '297', 'Third'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['245',
#   ['Jacobson', 'John', 'C', '.', 'com', '.', 'mer', '.', '121', 'Water'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['246',
#   ['Jenings',
#    'Chester',
#    ',',
#    'late',
#    'City',
#    'Hotel',
#    ',',
#    'h',
#    '.',
#    'Astor',
#    'House'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['247',
# ...
#  ['923',
#   ['Alexander',
#    'James',
#    ',',
#    'dry',
#    'goods',
#    ',',
#    '164',
#    'Canal',
#    ',',
#    'h',
#    '.',
#    '164',
#    'Canal'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['924',
#   ['Alexander', 'James', ',', 'plasterer', ',', '6', 'W', '.', '27th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['925',
#   ['Alexander', 'James', ',', 'boatman', ',', '83', 'Hester'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['926',
#   ['Alexander', 'James', 'G', '.', 'segar', 'maker', ',', '131', 'Goerck'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['927',
#   ['Alexander',
#    'James',
#    'K',
#    '.',
#    'clerk',
#    ',',
#    '65',
#    'Pine',
#    ',',
#    'h',
#    '.',
#    'Brooklyn'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'END']],
#  ['928',
#   ['Alexander', 'John', ',', ',plasterer', ',', '350', 'Av', '.', '6'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['929',
#   ['Alexander',
#    'John',
#    ',',
#    'clerk',
#    ',',
#    'h',
#    '.',
#    'r',
#    '.',
#    '24',
#    'Rivington'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'END']],
#  ['930',
#   ['Alexander', 'John', ',', 'moulder', ',', '378', 'Ninth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['931',
#   ['Alexander', 'John', ',', 'coffeeroastcr', ',', '69', 'Cannon'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['932',
#   ['Alexander', 'John', ',', 'agent', ',', 'h', '.', '5', 'Av', '.', '3'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['933',
#   ['Alexander', 'John', 'W', '.', 'machinist', ',', 'h', '.', '150', 'Lewis'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['934',
#   ['Alexander', 'Joseph', ',', 'machinist', ',', '380', 'Tenth'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['935',
#   ['Alexander', 'Mendel', ',', 'needles', ',', '119', 'Third'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['936',
#   ['Alexander', 'Oscar', 'W', '.', 'shipcarpenter', ',', '32', 'Lewis'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['937',
#   ['Alexander', 'Robert', 'H', '.', 'hardware', ',', '88', 'John'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['938',
#   ['Alexander', 'William', ',', 'carpenter', ',', 'h', '.', '271', 'Monroe'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['939',
#   ['Alexander', 'William', ',', 'seaman', ',', '91', 'Oliver'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['940',
#   ['Alexander', 'William', ',', 'whipmaker', ',', 'h', '.', '7', 'Anthony'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['941',
#   ['Alexander', 'William', ',', 'carman', ',', '122', 'W', '.', '19th'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['942',
#   ['Alexander',
#    'William',
#    ',',
#    'smith',
#    ',',
#    '98',
#    'Grand',
#    ',',
#    'h',
#    '.',
#    '551',
#    'Broome'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['943',
#   ['Alexander', 'Willgam', ',', 'tailor', ',', 'r', '.', '60', 'Henry'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['944',
#   ['Alexander', '&', 'Barton', ',', 'hardware', ',', '88', 'John'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['945',
#   ['Alexandre',
#    'Francis',
#    ',',
#    'mer',
#    '.',
#    '28',
#    'South',
#    ',',
#    'h',
#    '.',
#    '14',
#    'E',
#    '.',
#    '18th'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['946',
#   ['Alexandre',
#    'Lambert',
#    ',',
#    'engineer',
#    ',',
#    '23',
#    'Maiden',
#    'Lane',
#    ',',
#    'h',
#    '.',
#    '5',
#    'Chambers',
#    '.'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['947',
#   ['Alfaya', 'Francisco', ',', 'Spanish', 'hotel', ',', '65', 'Fulton'],
#   ['START', 'NC', 'NC', 'NC', 'NC', 'NC', 'D', 'AC', 'AC', 'END']],
#  ['948',
#   ['Alfka',
#    'John',
#    ',',
#    'grcr',
#    ',',
#    '104',
#    'Grand&',
#    '251',
#    'Av',
#    '.',
#    '6',
#    ',',
#    'h',
#    '.',
#    '104Grnd'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'END']],
#  ['949',
#   ['Alfonce',
#    'Joseph',
#    'E',
#    '.',
#    'manf',
#    '.',
#    '47',
#    'Ann',
#    ',',
#    'h',
#    '.',
#    '198',
#    'William'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['950',
#   ['ALFONCE', '&', 'CO', '.', 'manf', '.', '47', 'Ann'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['951',
#   ['Alford',
#    'Edwin',
#    'M',
#    '.',
#    'paints',
#    ',',
#    '550',
#    'Grand',
#    ',',
#    'h',
#    ',',
#    '14',
#    'Cannon'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'END']],
#  ['952',
#   ['Alford',
#    'Lydia',
#    ',',
#    '(col’d)',
#    'widow',
#    'of',
#    'Benj',
#    '.',
#    'r',
#    '.',
#    '174',
#    'Essex'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'END']],
#  ['953',
#   ['Alford',
#    'Samuel',
#    'M',
#    '.',
#    'clerk',
#    ',',
#    '5',
#    'Platt',
#    ',',
#    'h',
#    '.',
#    '21',
#    'Hammond'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['954',
#   ['Alford', '&', 'Dash', ',', 'hardware', ',', '5', 'Platt'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['955',
#   ['Alfred', 'John', ',', 'locksmith', ',', '41', 'Allen'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['956',
#   ['Alger', 'Addison', ',', 'mason', ',', '58', 'Stanton'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['957',
#   ['Alger', 'Andrew', 'J', '.', 'bookkeeper', ',', '94', 'W', '.', 'Broadway'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['958',
#   ['Alger', 'Charles', 'C', '.', 'clerk', ',', '127', 'Franklin'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['959',
#   ['Alger',
#    'Daniel',
#    'B',
#    '.',
#    'grocer',
#    ',',
#    '85',
#    'Dey',
#    ',',
#    'h',
#    '.',
#    'Harsimus'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'END']],
#  ['960',
#   ['Alger',
#    'Seneca',
#    ',',
#    'grocer',
#    ',',
#    '85',
#    'Dey',
#    ',',
#    'h',
#    '.',
#    'Jersey',
#    'city'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['961',
#   ['Alger', '&', 'Brothers', ',', 'grocers', ',', '85', 'Dey'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['962',
#   ['Albeit', 'Adam', ',', 'baker', ',', '72', 'Pike'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['963',
#   ['Alhiet',
#    'Adam',
#    ',',
#    'bootmaker',
#    ',',
#    '107',
#    'E',
#    '.',
#    '27th',
#    ',',
#    'h',
#    '.',
#    '107',
#    'E',
#    '.',
#    '27th'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['964',
#   ['Alicotis', 'John', 'M', '.', 'carman', ',', '10', 'Lewis'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['965',
#   ['Alingren', 'Andrew', 'G', '.', 'boarding', ',', '100', 'Oliver'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['966',
#   ['Aliot', 'Jacob', ',', 'tailor', ',', '29', 'Av', '.', 'A'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'AC', 'AC', 'END']],
#  ['967',
#   ['Alker', 'Adolphus', 'L', '.', 'dentist', ',', '341', 'Fourth'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['968',
#   ['Alker',
#    'George',
#    ',',
#    'Apollo',
#    'rooms',
#    ',',
#    '410',
#    'Broadway',
#    'and',
#    '33',
#    'Canal',
#    ',',
#    'n',
#    '.',
#    '33',
#    'Canal'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'END']],
#  ['969',
#   ['Alker',
#    'Henry',
#    ',',
#    'lawyer',
#    ',',
#    '27',
#    'Beekman',
#    ',',
#    'h',
#    '.',
#    '504',
#    'Hudson'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['970',
#   ['Alker', 'James', ',', 'carman', ',', '248', 'Rivington'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['971',
#   ['Allabern',
#    'Almeru',
#    'W',
#    '.',
#    'feed',
#    ',',
#    '523',
#    'Hdsn',
#    '.',
#    'bds',
#    '.',
#    '15',
#    'Morton'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['972',
#   ['Allaird', 'Palmon', ',', 'carpenter', ',', '214', 'Broome'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['973',
#   ['Allaire', 'Alexander', ',', 'carman', ',', '636', 'Greenwich'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['974',
#   ['Allaire',
#    'Alexander',
#    ',',
#    'jr',
#    '.',
#    'teller',
#    ',',
#    '40',
#    'Wall',
#    ',',
#    'h',
#    '.',
#    'Wmsburg'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'END']],
#  ['975',
#   ['Allaire', 'Andrew', ',', 'h', '.', '266', 'Monroe'],
#   ['START', 'NC', 'NC', 'D', 'PA', 'AC', 'AC', 'AC', 'END']],
#  ['976',
#   ['Allaire',
#    'Anthny',
#    'M',
#    '.',
#    'butcher',
#    ',',
#    '462',
#    'Hudsn',
#    ',',
#    'h',
#    '.',
#    '10',
#    'Morton'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['977',
#   ['ALLAIRE',
#    'ANTHONY',
#    'J',
#    '.',
#    '&',
#    'CO',
#    '.',
#    'coppersmith',
#    ',',
#    '618',
#    'Water',
#    ',',
#    'h',
#    '.',
#    '169',
#    'Henry'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['978',
#   ['Allaire',
#    'Charles',
#    ',',
#    'butcher',
#    ',',
#    '2',
#    'Clinton',
#    'mkt',
#    ',',
#    'h',
#    '.',
#    '164',
#    'Christopher'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['979',
#   ['Allaire', 'Daniel', 'D', '.', 'butcher', ',', '534', 'Hudson'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['980',
#   ['Allaire',
#    'Ewd',
#    '.',
#    'C',
#    '.',
#    'manhattan',
#    'bk',
#    ',',
#    '40',
#    'Wall',
#    ',',
#    'h',
#    '.',
#    'Wmsbg',
#    '.'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['981',
#   ['Allaire',
#    'Jas',
#    '.',
#    'P',
#    '.',
#    'Allaire',
#    'works',
#    ',',
#    '464',
#    'Cherry',
#    ',',
#    'h',
#    '.',
#    '462',
#    'Cherry'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['982',
#   ['Allaire',
#    'Jane',
#    ',',
#    'widow',
#    'of',
#    'Charles',
#    'D',
#    '.',
#    '203',
#    'W',
#    '.',
#    '24th'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'NC',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['983',
#   ['Allaire',
#    'Margaret',
#    ',',
#    'widow',
#    'of',
#    'Samuel',
#    'Y',
#    '.',
#    '161',
#    'Mott'],
#   ['START', 'NC', 'NC', 'D', 'NC', 'NC', 'NC', 'NC', 'D', 'AC', 'AC', 'END']],
#  ['984',
#   ['Allaire', 'Maria', ',', 'widow', 'of', 'Edwin', ',', '22', 'Morton'],
#   ['START', 'NC', 'NC', 'D', 'NC', 'NC', 'NC', 'D', 'AC', 'AC', 'END']],
#  ['985',
#   ['Allaire',
#    'Mary',
#    ',',
#    'widow',
#    'of',
#    'William',
#    ',',
#    'h',
#    '.',
#    '468',
#    'Houston'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['986',
#   ['Allaire', 'Philip', ',', 'carpenter', ',', '22', 'Morton'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['987',
#   ['Allaire', 'Robert', ',', 'bookkeeper', ',', '262', 'Seventh'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['988',
#   ['Allaire',
#    'Seaman',
#    ',',
#    'butcher',
#    ',',
#    '301',
#    'Bleecker',
#    ',',
#    'h',
#    '.',
#    '61',
#    'Leroy'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['989',
#   ['Allaire',
#    'Thomas',
#    'H',
#    '.',
#    'fancy',
#    'goods',
#    ',',
#    '419',
#    'Broadway',
#    ',',
#    'and',
#    'custom',
#    'house',
#    ',',
#    'h',
#    '.',
#    '93',
#    'Morton'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'OC',
#    'OC',
#    'OC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['990',
#   ['Allaire', 'Wilmot', 'D', '.', 'coppersmith', ',', '44', 'Broome'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['991',
#   ['Allan',
#    'Alexander',
#    ',',
#    'jeweller',
#    ',',
#    '111',
#    'Division',
#    'and',
#    'r',
#    '.',
#    '276',
#    'Bowery',
#    ',',
#    'h',
#    '.',
#    '149',
#    'Wooster',
#    '.'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['992',
#   ['Allan',
#    'Andrew',
#    ',',
#    'engineer',
#    ',',
#    'h',
#    '.',
#    'Av',
#    '.',
#    '9',
#    'c',
#    '.',
#    'W',
#    '.',
#    '37th'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['993',
#   ['Allan', 'George', ',', 'tailor', ',', '113', 'Cherry'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['994',
#   ['Allan', 'John', ',', '17', 'Vandewater'],
#   ['START', 'NC', 'NC', 'D', 'AC', 'AC', 'END']],
#  ['995',
#   ['Allan',
#    'Robt',
#    '.',
#    'provisions',
#    ',',
#    '226',
#    'Washington',
#    ',',
#    'h',
#    '.',
#    '53',
#    'Watts'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['996',
#   ['Allan',
#    '&',
#    'Rose',
#    ',',
#    'butter',
#    'and',
#    'provisions',
#    ',',
#    '226',
#    'Washgtn'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'OC', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['997',
#   ['Allard',
#    'Andrew',
#    ',',
#    'clerk',
#    ',',
#    'E',
#    '.',
#    '42d',
#    ',',
#    'n',
#    '.',
#    'Av',
#    '.',
#    '3'],
#   ['START',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['998',
#   ['Allard',
#    'Nahun',
#    'W',
#    '.',
#    'butcher',
#    ',',
#    '154',
#    'Varick',
#    ',',
#    'h',
#    '.',
#    '152',
#    'Varick'],
#   ['START',
#    'NC',
#    'NC',
#    'NC',
#    'D',
#    'OC',
#    'D',
#    'AC',
#    'AC',
#    'D',
#    'PA',
#    'AC',
#    'AC',
#    'AC',
#    'END']],
#  ['999',
#   ['Allari', 'Joseph', ',', 'boarding', ',', '37', 'Rose'],
#   ['START', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ['1000',
#   ['Allas', 'Joseph', 'A', '.', 'tailor', ',', '27', 'Ridge'],
#   ['START', 'NC', 'NC', 'NC', 'D', 'OC', 'D', 'AC', 'AC', 'END']],
#  ...]

# %%
output = []
for record in d:
  d_record = {}
  d_record["index"] = int(record[0])
  n = len(record[1])
  start = 1
  for i in range(1, n + 1):
    if i <  n:
      # Skip delimiters
      if record[2][i] == "D":
        start = i+1
        continue
      elif record[2][i+1] == "D":
        try:
          d_record[record[2][i]].append(record[1][(start-1):i])
        except:
          d_record[record[2][i]] = [record[1][(start-1):i]]
        start = i + 2
    else:
      try:
          d_record[record[2][i]].append(record[1][(start-1):])
      except:
          d_record[record[2][i]] = [record[1][(start-1):]]

  output.append(d_record)

# %% [markdown]
# Generate primary fields
#
# Here 4 primary fields are generated to faciliate the generation of final output: Occupation, Name, Marriage_Status and Address.

# %%
final = {}
for record in output:
  new = {}
  try:
    occupation = record['OC']
    new['Occupation'] = []
    for oc in occupation:
      new['Occupation'].append(' '.join(oc))
    new['Occupation'] = ' '.join(new['Occupation'])
  except:
    pass
  try:
    # Deal with widow marriage status
    name = record['NC']
    new['Name'] = ' '.join(name[0])
    if len(name) > 1:
      if name[1][0] == 'widow':
        new['Marriage_Status'] = 'widow'
      else:
        new['Marriage_Status'] = 'widow of ' + ' '.join(name[1][2:])
  except:
    pass

  try:
    # Multiple address
    address = record['AC']
    if len(address) == 1:
      if ((address[0][0] == "h") or (address[0][0] == "h.")):
        new['Address'] = [['h', ' '.join(address[0][1:])]]
      else:
        new['Address'] = [['assume_h', ' '.join(address[0])]]
    else:
      new['Address'] = []
      for ad in address:
        if ((ad[0] == "h") or (ad[0] == "h.")):
          new['Address'].append(['h', ' '.join(ad[1:])])
        else:
          new['Address'].append(['w', ' '.join(ad)])
  except:
    pass
  
  final[str(record['index'])] = new

# %%
# Save file
with open('mn_result.json', 'w') as f:
    json.dump(final,f)
f.close()

# %%
# Open file
with open('mn_result.json', 'r') as f:
    d = json.load(f)
f.close()

# %%
d['2001']
# Out:
# {'Occupation': 'tailor',
#  'Name': 'Asheld Thomas',
#  'Address': [['assume_h', '34 Av . B']]}

# %% [markdown]
# Some examples

# %%
# 10 alphabetical examples
for i in range(3100, 3110):
  print(' '.join(formatted[i-1][1]))
  print(final[str(i)])
  print('\n')
# Out:
# Bants John , assist , capt . 6th dist . h . 59 Franklin
# {'Occupation': 'assist capt', 'Name': 'Bants John', 'Address': [['assume_h', '6th dist . h . 59 Franklin']]}
#
#
# Bantz John , tailor , 266 Walker
# {'Occupation': 'tailor', 'Name': 'Bantz John', 'Address': [['assume_h', '266 Walker']]}
#
#
# Banyer G . Le Roy , 56 Barclay
# {'Name': 'Banyer G . Le Roy', 'Address': [['assume_h', '56 Barclay']]}
#
#
# Banyer Maria , 20 Bond
# {'Name': 'Banyer Maria', 'Address': [['assume_h', '20 Bond']]}
#
#
# Bapp John , police , 55 Attorney
# {'Occupation': 'police', 'Name': 'Bapp John', 'Address': [['assume_h', '55 Attorney']]}
#
#
# Baptis Benj . lapidary . 162 Fulton , h . Wllliamsburg
# {'Occupation': 'lapidary', 'Name': 'Baptis Benj', 'Address': [['w', '162 Fulton'], ['h', '. Wllliamsburg']]}
#
#
# Baptis Francis , boatbuilder , 329 Front
# {'Occupation': 'boatbuilder', 'Name': 'Baptis Francis', 'Address': [['assume_h', '329 Front']]}
#
#
# Baptis Harmon , boatbuilder , 368 Cherry
# {'Occupation': 'boatbuilder', 'Name': 'Baptis Harmon', 'Address': [['assume_h', '368 Cherry']]}
#
#
# Baptis Sarah , widow of John , 368 Cherry
# {'Name': 'Baptis Sarah', 'Marriage_Status': 'widow', 'Address': [['assume_h', '368 Cherry']]}
#
#
# Baptist John , fruits , 24 Grand
# {'Occupation': 'fruits', 'Name': 'Baptist John', 'Address': [['assume_h', '24 Grand']]}
