# %% [markdown]
# ## 1880 bk data

# %%
# !convert BPL_BK_1880_extract_cropped.pdf bk-1880-test.tiff
# !magick convert -density 300 BPL_BK_1880_extract_cropped.pdf image_%d.tiff

# %%
for i in range(108):
    print('!magick image_' + str(i) + '.tiff -depth 8 image_' + str(i) + '.tiff')
# Out:
# !magick image_0.tiff -depth 8 image_0.tiff
# !magick image_1.tiff -depth 8 image_1.tiff
# !magick image_2.tiff -depth 8 image_2.tiff
# !magick image_3.tiff -depth 8 image_3.tiff
# !magick image_4.tiff -depth 8 image_4.tiff
# !magick image_5.tiff -depth 8 image_5.tiff
# !magick image_6.tiff -depth 8 image_6.tiff
# !magick image_7.tiff -depth 8 image_7.tiff
# !magick image_8.tiff -depth 8 image_8.tiff
# !magick image_9.tiff -depth 8 image_9.tiff
# !magick image_10.tiff -depth 8 image_10.tiff
# !magick image_11.tiff -depth 8 image_11.tiff
# !magick image_12.tiff -depth 8 image_12.tiff
# !magick image_13.tiff -depth 8 image_13.tiff
# !magick image_14.tiff -depth 8 image_14.tiff
# !magick image_15.tiff -depth 8 image_15.tiff
# !magick image_16.tiff -depth 8 image_16.tiff
# !magick image_17.tiff -depth 8 image_17.tiff
# !magick image_18.tiff -depth 8 image_18.tiff
# !magick image_19.tiff -depth 8 image_19.tiff
# !magick image_20.tiff -depth 8 image_20.tiff
# ...

# %%
# !magick image_0.tiff -depth 8 image_0.tiff
# !magick image_1.tiff -depth 8 image_1.tiff
# !magick image_2.tiff -depth 8 image_2.tiff
# !magick image_3.tiff -depth 8 image_3.tiff
# !magick image_4.tiff -depth 8 image_4.tiff
# !magick image_5.tiff -depth 8 image_5.tiff
# !magick image_6.tiff -depth 8 image_6.tiff
# !magick image_7.tiff -depth 8 image_7.tiff
# !magick image_8.tiff -depth 8 image_8.tiff
# !magick image_9.tiff -depth 8 image_9.tiff
# !magick image_10.tiff -depth 8 image_10.tiff
# !magick image_11.tiff -depth 8 image_11.tiff
# !magick image_12.tiff -depth 8 image_12.tiff
# !magick image_13.tiff -depth 8 image_13.tiff
# !magick image_14.tiff -depth 8 image_14.tiff
# !magick image_15.tiff -depth 8 image_15.tiff
# !magick image_16.tiff -depth 8 image_16.tiff
# !magick image_17.tiff -depth 8 image_17.tiff
# !magick image_18.tiff -depth 8 image_18.tiff
# !magick image_19.tiff -depth 8 image_19.tiff
# !magick image_20.tiff -depth 8 image_20.tiff
# !magick image_21.tiff -depth 8 image_21.tiff
# !magick image_22.tiff -depth 8 image_22.tiff
# !magick image_23.tiff -depth 8 image_23.tiff
# !magick image_24.tiff -depth 8 image_24.tiff
# !magick image_25.tiff -depth 8 image_25.tiff
# !magick image_26.tiff -depth 8 image_26.tiff
# !magick image_27.tiff -depth 8 image_27.tiff
# !magick image_28.tiff -depth 8 image_28.tiff
# !magick image_29.tiff -depth 8 image_29.tiff
# !magick image_30.tiff -depth 8 image_30.tiff
# !magick image_31.tiff -depth 8 image_31.tiff
# !magick image_32.tiff -depth 8 image_32.tiff
# !magick image_33.tiff -depth 8 image_33.tiff
# !magick image_34.tiff -depth 8 image_34.tiff
# !magick image_35.tiff -depth 8 image_35.tiff
# !magick image_36.tiff -depth 8 image_36.tiff
# !magick image_37.tiff -depth 8 image_37.tiff
# !magick image_38.tiff -depth 8 image_38.tiff
# !magick image_39.tiff -depth 8 image_39.tiff
# !magick image_40.tiff -depth 8 image_40.tiff
# !magick image_41.tiff -depth 8 image_41.tiff
# !magick image_42.tiff -depth 8 image_42.tiff
# !magick image_43.tiff -depth 8 image_43.tiff
# !magick image_44.tiff -depth 8 image_44.tiff
# !magick image_45.tiff -depth 8 image_45.tiff
# !magick image_46.tiff -depth 8 image_46.tiff
# !magick image_47.tiff -depth 8 image_47.tiff
# !magick image_48.tiff -depth 8 image_48.tiff
# !magick image_49.tiff -depth 8 image_49.tiff
# !magick image_50.tiff -depth 8 image_50.tiff
# !magick image_51.tiff -depth 8 image_51.tiff
# !magick image_52.tiff -depth 8 image_52.tiff
# !magick image_53.tiff -depth 8 image_53.tiff
# !magick image_54.tiff -depth 8 image_54.tiff
# !magick image_55.tiff -depth 8 image_55.tiff
# !magick image_56.tiff -depth 8 image_56.tiff
# !magick image_57.tiff -depth 8 image_57.tiff
# !magick image_58.tiff -depth 8 image_58.tiff
# !magick image_59.tiff -depth 8 image_59.tiff
# !magick image_60.tiff -depth 8 image_60.tiff
# !magick image_61.tiff -depth 8 image_61.tiff
# !magick image_62.tiff -depth 8 image_62.tiff
# !magick image_63.tiff -depth 8 image_63.tiff
# !magick image_64.tiff -depth 8 image_64.tiff
# !magick image_65.tiff -depth 8 image_65.tiff
# !magick image_66.tiff -depth 8 image_66.tiff
# !magick image_67.tiff -depth 8 image_67.tiff
# !magick image_68.tiff -depth 8 image_68.tiff
# !magick image_69.tiff -depth 8 image_69.tiff
# !magick image_70.tiff -depth 8 image_70.tiff
# !magick image_71.tiff -depth 8 image_71.tiff
# !magick image_72.tiff -depth 8 image_72.tiff
# !magick image_73.tiff -depth 8 image_73.tiff
# !magick image_74.tiff -depth 8 image_74.tiff
# !magick image_75.tiff -depth 8 image_75.tiff
# !magick image_76.tiff -depth 8 image_76.tiff
# !magick image_77.tiff -depth 8 image_77.tiff
# !magick image_78.tiff -depth 8 image_78.tiff
# !magick image_79.tiff -depth 8 image_79.tiff
# !magick image_80.tiff -depth 8 image_80.tiff
# !magick image_81.tiff -depth 8 image_81.tiff
# !magick image_82.tiff -depth 8 image_82.tiff
# !magick image_83.tiff -depth 8 image_83.tiff
# !magick image_84.tiff -depth 8 image_84.tiff
# !magick image_85.tiff -depth 8 image_85.tiff
# !magick image_86.tiff -depth 8 image_86.tiff
# !magick image_87.tiff -depth 8 image_87.tiff
# !magick image_88.tiff -depth 8 image_88.tiff
# !magick image_89.tiff -depth 8 image_89.tiff
# !magick image_90.tiff -depth 8 image_90.tiff
# !magick image_91.tiff -depth 8 image_91.tiff
# !magick image_92.tiff -depth 8 image_92.tiff
# !magick image_93.tiff -depth 8 image_93.tiff
# !magick image_94.tiff -depth 8 image_94.tiff
# !magick image_95.tiff -depth 8 image_95.tiff
# !magick image_96.tiff -depth 8 image_96.tiff
# !magick image_97.tiff -depth 8 image_97.tiff
# !magick image_98.tiff -depth 8 image_98.tiff
# !magick image_99.tiff -depth 8 image_99.tiff
# !magick image_100.tiff -depth 8 image_100.tiff
# !magick image_101.tiff -depth 8 image_101.tiff
# !magick image_102.tiff -depth 8 image_102.tiff
# !magick image_103.tiff -depth 8 image_103.tiff
# !magick image_104.tiff -depth 8 image_104.tiff
# !magick image_105.tiff -depth 8 image_105.tiff
# !magick image_106.tiff -depth 8 image_106.tiff
# !magick image_107.tiff -depth 8 image_107.tiff

# %%
from PIL import Image

# %%
import pandas as pd

# %%
import os, os.path
from skimage import data
from skimage.data import page
from skimage.filters import  threshold_sauvola
from pytesseract import pytesseract
import numpy as np

# %%
filecounter= 0 

path = "C:/Users/himab/Documents/summer2020/RA_HNYC/work_files/bk-1880"
for f in os.listdir(path):

    if(f != '.ipynb_checkpoints' and f != 'brooklyn_nb.ipynb' and f != 'brookly n.ipynb' and f != 'output.hocr' and f != 'saved.tif' and f != 'newimage.tiff'):
        
        try:
            image=Image.open(f)
            print(f)
            #thresholding
            grayimage = image.convert('L')
            f_image = np.asarray(grayimage)
            t_sauvola = threshold_sauvola(f_image, window_size=23)
            binary_image = f_image > t_sauvola
            #saving binary image as a tif (required for obtaining hocr format from tesseract)
            thresholded_img = Image.fromarray(binary_image)
            thresholded_img.save("saved.tif")
            pytesseract.run_tesseract('saved.tif', 'output', lang=None, config="hocr", extension="hocr")
            x = !hocr-detect-columns --mode json output.hocr
            #save json file
            filecounter += 1
            with open('C://Users/himab/Documents/summer2020/RA_HNYC/work_files/bk-1880/tess_output/page{}.json'.format(filecounter), 'w',encoding="utf-8") as f:
                f.write(x.n)
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-c524f5b0a47b> in <module>
#       4 from skimage.data import page
#       5 from skimage.filters import  threshold_sauvola
# ----> 6 from pytesseract import pytesseract
#       7 import numpy as np
#       8
#
# ~\Anaconda3\envs\hnyc\lib\site-packages\pytesseract\__init__.py in <module>
# ----> 1 from .pytesseract import (  # noqa: F401
#       2     Output,
#       3     TesseractError,
#       4     TesseractNotFoundError,
#       5     TSVNotSupported,
#
# ~\Anaconda3\envs\hnyc\lib\site-packages\pytesseract\pytesseract.py in <module>
#      32 pandas_installed = find_loader('pandas') is not None
#      33 if pandas_installed:
# ---> 34     import pandas as pd
#      35
#      36 RGB_MODE = 'RGB'
#
# ~\Anaconda3\envs\hnyc\lib\site-packages\pandas\__init__.py in <module>
#     191 # GH 27101
# ...

# %%
from PIL import Image
import os, os.path
from skimage import data
from skimage.data import page
from skimage.filters import  threshold_sauvola
from pytesseract import pytesseract
import numpy as np


filecounter= 0 

path = "C:/Users/himab/Documents/summer2020/RA_HNYC/work_files/bkln-1850-data"
for f in os.listdir(path):

    if(f == 'bk-1880-test.tiff'):
            image=Image.open(f)
            display(image)
            #thresholding
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=LA size=612x792 at 0x2D0B4784D90>

# %%
grayimage = image.convert('L')
display(image)

#             f_image = np.asarray(grayimage)
#             t_sauvola = threshold_sauvola(f_image, window_size=23)
#             binary_image = f_image > t_sauvola
#             #saving binary image as a tif (required for obtaining hocr format from tesseract)
#             thresholded_img = Image.fromarray(binary_image)
            
#             thresholded_img.save("saved.tif")
#             pytesseract.run_tesseract('saved.tif', 'output', lang=None, config="hocr", extension="hocr")
#             x = !hocr-detect-columns --mode json output.hocr
#             #save json file
#             filecounter += 1
#             with open('C://Users/himab/Documents/summer2020/RA_HNYC/work_files/tes_output/BK_1880-81/page{}.json'.format(filecounter), 'w',encoding="utf-8") as f:
#                 f.write(x.n)
#         except:
#             print('hi')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=LA size=612x792 at 0x2D0B4784D90>

# %% [markdown]
# ## 1880 gna test data

# %%
# !magick bk-gna-1880-test.pdf bk-gna-1880-test.tiff

# %%
# !magick bk-gna-1880-test.tiff -depth 8 bk-gna-1880-test.tiff

# %%
from PIL import Image
import os, os.path
from skimage import data
from skimage.data import page
from skimage.filters import  threshold_sauvola
from pytesseract import pytesseract
import numpy as np


filecounter= 0 

path = "C:/Users/himab/Documents/summer2020/RA_HNYC/work_files/bkln-1850-data"
for f in os.listdir(path):

    if(f == 'bk-gna-1880-test.tiff'):
            image=Image.open(f)
            display(image)
            #thresholding
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=LA size=612x792 at 0x2D0B0D8CF70>

# %%
grayimage = image.convert('L')
# display(image)

f_image = np.asarray(grayimage)
t_sauvola = threshold_sauvola(f_image, window_size=23)
binary_image = f_image > t_sauvola
#saving binary image as a tif (required for obtaining hocr format from tesseract)
thresholded_img = Image.fromarray(binary_image)

thresholded_img.save("saved.tif")
pytesseract.run_tesseract('saved.tif', 'output', lang=None, config="hocr", extension="hocr")
x = !hocr-detect-columns --mode json output.hocr
#save json file
filecounter += 1
with open('C://Users/himab/Documents/summer2020/RA_HNYC/work_files/tes_output/BK_1880-81/page{}.json'.format(filecounter), 'w',encoding="utf-8") as f:
    f.write(x.n)
# x.n

# %%
# !magick bk-gna-1880-test.pdf bk-gna-1880-test1.tiff
