# %%
from PIL import Image

# %%
import pandas as pd

# %%
import os, os.path
from skimage import data
from skimage.data import page
from skimage.filters import  threshold_sauvola
from pytesseract import pytesseract
import numpy as np

# %%
filecounter= 0 

path = "C:/Users/himab/Documents/summer2020/RA_HNYC/work_files/bk-1880"
for f in os.listdir(path):

    if(f != '.ipynb_checkpoints' and f != 'brooklyn_nb.ipynb' and f != 'brooklyn_nb_final.ipynb' and f != 'bk-1880-test_%-0.tiff' and f != 'output.hocr' and f != 'saved.tif' and f != 'newimage.tiff'):
        
        try:
            image=Image.open(f)
            print(f)
            #thresholding
            grayimage = image.convert('L')
            f_image = np.asarray(grayimage)
            t_sauvola = threshold_sauvola(f_image, window_size=23)
            binary_image = f_image > t_sauvola
            #saving binary image as a tif (required for obtaining hocr format from tesseract)
            thresholded_img = Image.fromarray(binary_image)
            thresholded_img.save("saved.tif")
            pytesseract.run_tesseract('saved.tif', 'output', lang=None, config="hocr", extension="hocr")
            x = !hocr-detect-columns --mode json output.hocr
            #save json file
            filecounter += 1
            with open('C://Users/himab/Documents/summer2020/RA_HNYC/work_files/bk-1880/tess_output/page{}.json'.format(filecounter), 'w',encoding="utf-8") as f:
                f.write(x.n)
        except:
            pass
# Out:
# image_0.tiff
# image_1.tiff
# image_10.tiff
# image_100.tiff
# image_101.tiff
# image_102.tiff
# image_103.tiff
# image_104.tiff
# image_105.tiff
# image_106.tiff
# image_107.tiff
# image_11.tiff
# image_12.tiff
# image_13.tiff
# image_14.tiff
# image_15.tiff
# image_16.tiff
# image_17.tiff
# image_18.tiff
# image_19.tiff
# image_2.tiff
# image_20.tiff
# image_21.tiff
# image_22.tiff
# image_23.tiff
# image_24.tiff
# image_25.tiff
# image_26.tiff
# image_27.tiff
# image_28.tiff
# image_29.tiff
# image_3.tiff
# image_30.tiff
# image_31.tiff
# image_32.tiff
# image_33.tiff
# image_34.tiff
# image_35.tiff
# image_36.tiff
# image_37.tiff
# image_38.tiff
# image_39.tiff
# image_4.tiff
# image_40.tiff
# image_41.tiff
# image_42.tiff
# image_43.tiff
# image_44.tiff
# image_45.tiff
# image_46.tiff
# image_47.tiff
# image_48.tiff
# image_49.tiff
# image_5.tiff
# image_50.tiff
# image_51.tiff
# image_52.tiff
# image_53.tiff
# image_54.tiff
# image_55.tiff
# image_56.tiff
# image_57.tiff
# image_58.tiff
# image_59.tiff
# image_6.tiff
# image_60.tiff
# image_61.tiff
# image_62.tiff
# image_63.tiff
# image_64.tiff
# image_65.tiff
# image_66.tiff
# image_67.tiff
# image_68.tiff
# image_69.tiff
# image_7.tiff
# image_70.tiff
# image_71.tiff
# image_72.tiff
# image_73.tiff
# image_74.tiff
# image_75.tiff
# image_76.tiff
# image_77.tiff
# image_78.tiff
# image_79.tiff
# image_8.tiff
# image_80.tiff
# image_81.tiff
# image_82.tiff
# image_83.tiff
# image_84.tiff
# image_85.tiff
# image_86.tiff
# image_87.tiff
# image_88.tiff
# image_89.tiff
# image_9.tiff
# image_90.tiff
# image_91.tiff
# image_92.tiff
# image_93.tiff
# image_94.tiff
# image_95.tiff
# image_96.tiff
# image_97.tiff
# image_98.tiff
# image_99.tiff
